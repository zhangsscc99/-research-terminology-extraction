# %%
'''
Author: Yuling Gu
Date: Sept 27, 2018
Description:
This program implements Feng et al. 2004, "Accessor Variety Criteria
for Chinese Word Extraction". Computational Linguistics 30(1).
Using the accessor variety criteria as a filter, we filter out terms with
less then 3 unique left and right contexts.
Usage: python3 accessorvariety.py 
unfiltered_ouput.txt foreground.tchunk.filelist
Example : python3 accessorvariety.py ../../Downloads/outfile.txt chinese_term_extraction_binaryRelease/sample.pos.filelist


#unfiltered_output.txt

foreground.tchunk.filelist



'''
import os

tchunk = os.listdir('../move/output_foreground')

#tchunk = os.listdir('/Users/mac/Desktop/ngram/move/output_foreground')
#print(tchunk)




# %%
tchunk


def change_tchunk(filelist):
    newlist = []
    for i in range(len(filelist)):
        if filelist[i][-6:] == 'tchunk':
            newlist.append(filelist[i])
    return newlist


# %%
tchunk = change_tchunk(tchunk)

# %%
tchunk.sort()
tchunk
#tchunk=tchunk[:10]


# %%


# %%
def change_name(lst):
    for i in range(len(lst)):
        lst[i] = '../move/output_foreground/' + lst[i]
    return lst


change_name(tchunk)

# %%
len(tchunk)

# %%
#tchunk = tchunk[:10]
#print(tchunk)
# %%
#print(tchunk)
with open('../move/tchunkfile.txt', 'w') as f:
    for term in tchunk:
        f.write(term + '\n')

f.close()

import re
import sys



        
      




# !/usr/bin/env python3
import re
import sys

word_processed_by_av = []
word_avmorethan3=[]
def main(all_terms, conll):
    # open unfiltered file list (first argument)
    # 围棋.all_terms
    # input_file  = sys.argv[1]
    input_file = all_terms

    # list of files in CoNLL format
    # BIO data: conll
    # conll_filelist = sys.argv[2]
    conll_filelist = conll
    # print(conll_filelist)
    with open(conll_filelist, "r") as filenames:
        conll_files = filenames.readlines()

    with open(input_file, "r") as f:

        unfiltered = f.readlines()
    for term in unfiltered:
        left_context = []
        left_count = 0
        right_context = []
        right_count = 0
        term_word = term.split("\t")
        current_term = []
        for i in range(0, len(term_word) - 1):
            current_term.append(term_word[i])

        for conll_file in conll_files:
            # modify according to where the conll format files are
            conll_file = conll_file.strip("\n")
            with open(conll_file, "r") as f2:
                conll = f2.readlines()
                current_term_vec = current_term[0].split(" ")
                # print(current_term[0])
                for token in range(0, len(conll)):
                    word2_tag_BIO = conll[token].split("\t")
                    # term matched
                    if current_term[0] == word2_tag_BIO[0]:
                        left = conll[token - 1].split("\t")[0]
                        # if target word length 1
                        # AM 9/11/22
                        if (len(current_term_vec) == 1) and (len(conll) > (token + 1)):
                            right = conll[token + 1].split("\t")[0]
                        else:
                            right = conll[token + len(current_term_vec) - 1].split("\t")[0]
                        left = re.sub(r'[，。!\?\-\/\(\)\\]', '', left)
                        right = re.sub(r'[，。!\?\-\/\(\)\\"]', '', right)
                        if left != "" and left not in left_context:
                            left_context.append(left)
                        if right != "" and right not in right_context:
                            right_context.append(right)
            # check context count
            if (len(left_context) >= 3) and (len(right_context) >= 3):
                break  # if reach target, no need open another file

        if len(left_context) >= 3 and len(right_context) >= 3:
            print (term, len(left_context)+len(right_context),end = "\n")
            word_avmorethan3.append([term,len(left_context)+len(right_context)])
            #print(word_avmorethan3)


        #print(term, len(left_context), len(right_context), end="\n")
        #word_processed_by_av.append([term, len(left_context), len(right_context)])
        # print([term,,end='')
        # pass
    with open("../move/result5.txt",'w') as f:
        for item in word_avmorethan3:

            f.write("%s\n"%item)
    f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-2baa91388bd8> in <module>
#      21 import os
#      22
# ---> 23 tchunk = os.listdir('../move/output_foreground')
#      24
#      25 #tchunk = os.listdir('/Users/mac/Desktop/ngram/move/output_foreground')
#
# FileNotFoundError: [Errno 2] No such file or directory: '../move/output_foreground'

# %%
main('../move/围棋.all_terms','../move/tchunkfile.txt')

# %%
lst=[]
with open("result2.txt",'r') as f2:
    
    while True:
        
  
    # Get next line from file
        line = f2.readline()
        
  
    # if line is empty
    # end of file is reached
        
        if not line:break
        start=line.index('[')
        mid=line.index(',')
        end=line.index(']')
        #print(line[start+1:mid])
        
        lst.append([line[start+2:mid-1],line[mid+2:end]])
        

       
f2.close

lst
# Out:
# [['定段\\t33.77389335616284\\n', '14'],
#  ['江流儿\\t29.827760255414745\\n', '30'],
#  ['雷凌云\\t28.326954853828536\\n', '21'],
#  ['云子\\t28.231464085451435\\n', '26'],
#  ['雙人圍\\t25.322550451659833\\n', '12'],
#  ['江流\\t17.684440134695855\\n', '28'],
#  ['劫材\\t17.635460542859118\\n', '11'],
#  ['对局者\\t17.23174295954707\\n', '21'],
#  ['唐韋星\\t14.678756953271524\\n', '8'],
#  ['方圓社\\t12.458928161513633\\n', '39'],
#  ['棋鬼王\\t11.639643745607373\\n', '11'],
#  ['定段赛\\t11.60481482418406\\n', '8'],
#  ['轮于\\t11.235262464191884\\n', '13'],
#  ['天元战\\t11.020010767046843\\n', '11'],
#  ['本届\\t10.500781220979711\\n', '9'],
#  ['循环圈\\t10.454596039151141\\n', '8'],
#  ['預選\\t10.318280755502213\\n', '7'],
#  ['齐鲁晚\\t10.083823120261227\\n', '10'],
#  ['本身劫\\t10.068343599628644\\n', '8'],
#  ['碁聖\\t9.480074683417948\\n', '7'],
#  ['强败者\\t8.98733668268088\\n', '8'],
#  ['deepmind\\t8.961162865009241\\n', '10'],
#  ['御城棋\\t8.842864894524894\\n', '11'],
#  ['杯冠军\\t8.576798741934919\\n', '13'],
#  ['時代\\t8.489580850575923\\n', '10'],
#  ['年道\\t8.488110262340628\\n', '9'],
#  ['方胜\\t8.459305388487891\\n', '14'],
#  ['廣島\\t8.455967405197772\\n', '7'],
#  ['上届\\t8.455967405197772\\n', '6'],
#  ['免选\\t8.413110262340629\\n', '7'],
#  ['挑战者\\t7.967202117643071\\n', '8'],
#  ['黑嘉嘉\\t7.890481056676411\\n', '9'],
#  ['淡路修\\t7.712158350596804\\n', '7'],
#  ['天台\\t7.491724846862164\\n', '8'],
#  ['聂卫平\\t7.47979743277189\\n', '6'],
#  ['任中\\t7.4413924676285\\n', '9'],
#  ['山城宏\\t7.395789825731539\\n', '9'],
#  ['等级分\\t7.3850600276309\\n', '6'],
#  ['贴目\\t7.352975043336869\\n', '6'],
#  ['臺北市\\t7.2051210257047495\\n', '6'],
#  ['岩本\\t7.0671000738620435\\n', '8'],
#  ['甘肃\\t7.051292216779224\\n', '7'],
#  ['白昕卉\\t7.042795829241532\\n', '11'],
#  ['張凱馨\\t7.003771827646787\\n', '8'],
#  ['丈和\\t6.95720447707545\\n', '23'],
#  ['晋级\\t6.930873942977733\\n', '6'],
#  ['丹朱\\t6.9242072763110665\\n', '8'],
#  ['瀨越\\t6.9242072763110665\\n', '6'],
#  ['楊子\\t6.919762831866621\\n', '7'],
#  ['因碩\\t6.907064419168209\\n', '8'],
#  ['刘小光\\t6.666119494846931\\n', '7'],
#  ['轮败者\\t6.6001236510884524\\n', '10'],
#  ['1轮\\t6.474264026781707\\n', '8'],
#  ['区\\t6.471406979566945\\n', '16'],
#  ['男子组\\t6.3978357625714155\\n', '8'],
#  ['劫爭\\t6.189764697068608\\n', '13'],
#  ['韩元\\t6.1683451861845295\\n', '19'],
#  ['女子组\\t5.97586537641641\\n', '9'],
#  ['小林觉\\t5.516005796925643\\n', '9'],
#  ['擂台赛\\t5.502835758486294\\n', '8'],
#  ['赛棋手\\t5.470938564455519\\n', '6'],
#  ['黄河杯\\t5.455107236535833\\n', '8'],
#  ['女子棋\\t5.435757835745105\\n', '7'],
#  ['訓練\\t5.429439614387081\\n', '6'],
#  ['楊子萱\\t5.397059034163648\\n', '6'],
#  ['荒木氏\\t5.397059034163648\\n', '6'],
#  ['擂台\\t5.391250084861229\\n', '6'],
#  ['决赛第\\t5.358360232582192\\n', '6'],
#  ['强败者获\\t5.341190163667598\\n', '6'],
#  ['專案\\t5.3272500848612285\\n', '6'],
#  ['俘子\\t5.3272500848612285\\n', '6'],
#  ['柯潔\\t5.275340213729478\\n', '6'],
#  ['分至\\t5.207250084861228\\n', '6'],
#  ['本戰\\t5.174873873233186\\n', '6'],
#  ['过惕生\\t5.142343329141699\\n', '7'],
#  ['联棋\\t5.070211012775204\\n', '11'],
#  ['橋本\\t5.054384236648642\\n', '7'],
#  ['复赛\\t5.0203089736335444\\n', '9'],
#  ['圍棋界\\t4.961577910970018\\n', '7'],
#  ['城围\\t4.946976863006756\\n', '7'],
#  ['俞俐均\\t4.936786853371649\\n', '10'],
#  ['届中\\t4.89881148730894\\n', '6'],
#  ['通算\\t4.889973592613342\\n', '12'],
#  ['codice\\t4.862661858804335\\n', '6'],
#  ['聯\\t4.673905366595743\\n', '9'],
#  ['朝日新\\t4.6156697548895105\\n', '7'],
#  ['绝艺\\t4.61459043408781\\n', '6'],
#  ['天元\\t4.611316666220532\\n', '7'],
#  ['王座\\t4.543191826413907\\n', '6'],
#  ['邱峻\\t4.515291402248733\\n', '7'],
#  ['灵杯\\t4.447371954405653\\n', '8'],
#  ['棋圣\\t4.355032819543185\\n', '13'],
#  ['女流名人\\t4.335943805820268\\n', '6'],
#  ['黄龙士\\t4.3088445099204025\\n', '9'],
#  ['队获得\\t4.306789153227305\\n', '7'],
#  ['謝依旻\\t4.306789153227305\\n', '7'],
#  ['颗子\\t4.233179121750794\\n', '12'],
#  ['挑戰者\\t4.219413171136874\\n', '7'],
#  ['組織\\t4.218310069341603\\n', '13'],
#  ['中環盃\\t4.189904430187994\\n', '8'],
#  ['农心杯\\t4.183078094707658\\n', '6'],
#  ['赵南哲\\t4.155152176833557\\n', '7'],
#  ['新布石\\t4.1421200818256425\\n', '6'],
#  ['應昌\\t4.09079264757644\\n', '6'],
#  ['玩家\\t4.073050021624885\\n', '7'],
#  ['黑子\\t4.070580541727578\\n', '8'],
#  ['外勢\\t4.070580541727578\\n', '9'],
#  ['學習\\t4.041181115038325\\n', '9'],
#  ['深入\\t4.041181115038325\\n', '8'],
#  ['胜率\\t4.034396631956189\\n', '9'],
#  ['收官\\t3.9750324049875037\\n', '6'],
#  ['位棋\\t3.9656617717936715\\n', '6'],
#  ['资格赛\\t3.939682295382321\\n', '8'],
#  ['方棋子\\t3.920496247175879\\n', '10'],
#  ['全国性\\t3.894492983780942\\n', '9'],
#  ['白方\\t3.893886925364224\\n', '6'],
#  ['际象棋\\t3.8797505831784824\\n', '9'],
#  ['李世乭\\t3.8774509570198443\\n', '7'],
#  ['年為\\t3.868221454176411\\n', '8'],
#  ['人戰\\t3.8577376938047814\\n', '10'],
#  ['亚洲\\t3.811614603271333\\n', '6'],
#  ['队和\\t3.811614603271333\\n', '10'],
#  ['名誉\\t3.811614603271333\\n', '7'],
#  ['打劫\\t3.8094168010735308\\n', '10'],
#  ['理光\\t3.8094168010735308\\n', '9'],
#  ['霸王\\t3.806852698509428\\n', '7'],
#  ['飛刀\\t3.806852698509428\\n', '9'],
#  ['得到\\t3.8038223954791253\\n', '8'],
#  ['聂卫\\t3.8028972754906705\\n', '10'],
#  ['正夫\\t3.8001860318427614\\n', '8'],
#  ['本选赛\\t3.7990710968915007\\n', '6'],
#  ['只棋子\\t3.7912961795637257\\n', '6'],
#  ['半决赛\\t3.79070335599903\\n', '8'],
#  ['妖刀\\t3.7896521068573406\\n', '12'],
#  ['雙人\\t3.7830431746999045\\n', '7'],
#  ['家康\\t3.773519365176095\\n', '7'],
#  ['网棋\\t3.773519365176095\\n', '7'],
#  ['十一\\t3.773519365176095\\n', '7'],
#  ['執白\\t3.773519365176095\\n', '6'],
#  ['主将\\t3.7662977528930983\\n', '6'],
#  ['國流\\t3.760186031842762\\n', '8'],
#  ['目外\\t3.760186031842762\\n', '8'],
#  ['经过\\t3.7401860318427613\\n', '10'],
#  ['更具\\t3.7401860318427613\\n', '6'],
#  ['负\\t3.681007962198381\\n', '9'],
#  ['中华台北\\t3.648415173719302\\n', '8'],
#  ['腾讯\\t3.642949659947538\\n', '10'],
#  ['李昌镐\\t3.6173911330159028\\n', '6'],
#  ['中盘\\t3.5822447781325875\\n', '8'],
#  ['頭銜者\\t3.5777927284847184\\n', '10'],
#  ['年代表\\t3.5777927284847184\\n', '6'],
#  ['王座戰\\t3.5547480326014407\\n', '9'],
#  ['棋聖\\t3.5355008918088924\\n', '8'],
#  ['南韓首爾\\t3.5241539655847998\\n', '6'],
#  ['碁聖戰\\t3.5078963833315138\\n', '6'],
#  ['國手\\t3.505180987529545\\n', '9'],
#  ['混双赛\\t3.3941138065331193\\n', '6'],
#  ['江戶\\t3.3761474816392103\\n', '6'],
#  ['奖金为\\t3.3510920159214055\\n', '8'],
#  ['賽進行\\t3.3510920159214055\\n', '7'],
#  ['国女子\\t3.3510920159214055\\n', '6'],
#  ['決定戰\\t3.3510920159214055\\n', '7'],
#  ['網路圍\\t3.3510920159214055\\n', '6'],
#  ['金明训\\t3.3510920159214055\\n', '7'],
#  ['余棋手\\t3.3510920159214055\\n', '6'],
#  ['团体赛\\t3.3510920159214055\\n', '7'],
#  ['10万\\t3.3510920159214055\\n', '7'],
#  ['圍棋高\\t3.3510920159214055\\n', '6'],
#  ['朴志恩\\t3.3510920159214055\\n', '6'],
#  ['开局\\t3.350021007304047\\n', '6'],
#  ['职业\\t3.327146563115514\\n', '6'],
#  ['吴清源\\t3.29666947426844\\n', '10'],
#  ['海峰\\t3.277613534372701\\n', '7'],
#  ['级分\\t3.275085337507647\\n', '8'],
#  ['衢州市\\t3.2622673309864427\\n', '6'],
#  ['王晨星\\t3.2287330518444968\\n', '8'],
#  ['段胜\\t3.2122755496470288\\n', '6'],
#  ['視台\\t3.13928130782783\\n', '9'],
#  ['產生\\t3.13928130782783\\n', '6'],
#  ['正式\\t3.13928130782783\\n', '7'],
#  ['聖戰\\t3.13928130782783\\n', '10'],
#  ['王戰\\t3.13928130782783\\n', '11'],
#  ['排名\\t3.13928130782783\\n', '7'],
#  ['賽制\\t3.13928130782783\\n', '10'],
#  ['抽签\\t3.13928130782783\\n', '6'],
#  ['金荣\\t3.13928130782783\\n', '6'],
#  ['国手\\t3.13928130782783\\n', '8'],
#  ['分先\\t3.13928130782783\\n', '6'],
#  ['最強\\t3.13928130782783\\n', '6'],
#  ['中方\\t3.13928130782783\\n', '7'],
#  ['导致\\t3.13928130782783\\n', '8'],
#  ['曾经\\t3.13928130782783\\n', '7'],
#  ['担任\\t3.13928130782783\\n', '6'],
#  ['9日\\t3.13928130782783\\n', '7'],
#  ['當作\\t3.13928130782783\\n', '6'],
#  ['豐田\\t3.13928130782783\\n', '6'],
#  ['座戰\\t3.13928130782783\\n', '6'],
#  ['屆本\\t3.13928130782783\\n', '6'],
#  ['击败\\t3.13928130782783\\n', '6'],
#  ['组合\\t3.13928130782783\\n', '7'],
#  ['来自\\t3.13928130782783\\n', '6'],
#  ['下棋\\t3.13928130782783\\n', '6'],
#  ['武汉\\t3.13928130782783\\n', '6'],
#  ['聯盟\\t3.13928130782783\\n', '10'],
#  ['成绩\\t3.13928130782783\\n', '8'],
#  ['引起\\t3.13928130782783\\n', '6'],
#  ['只能\\t3.13928130782783\\n', '6'],
#  ['负李\\t3.13928130782783\\n', '6'],
#  ['年底\\t3.13928130782783\\n', '7'],
#  ['下午\\t3.13928130782783\\n', '9'],
#  ['單敗\\t3.13928130782783\\n', '6'],
#  ['耀烨\\t3.13928130782783\\n', '6'],
#  ['重庆\\t3.13928130782783\\n', '8'],
#  ['項目\\t3.136324903404487\\n', '12'],
#  ['手棋\\t3.129590575834905\\n', '7'],
#  ['棋王赛\\t3.1204804941865714\\n', '7'],
#  ['禁止\\t3.0815942982713973\\n', '6'],
#  ['為日本\\t3.0770815555213575\\n', '7'],
#  ['歐洲\\t3.0691786078656005\\n', '11'],
#  ['黑龙江\\t3.068465601935877\\n', '8'],
#  ['羋昱廷\\t3.060984971991335\\n', '6'],
#  ['晏天章\\t3.060984971991335\\n', '8'],
#  ['提子\\t3.0400399209503384\\n', '12'],
#  ['江苏\\t3.0235149729280377\\n', '6'],
#  ['混双\\t3.0137849619297135\\n', '8'],
#  ['白子\\t3.012520049974812\\n', '6'],
#  ['棋經\\t2.995007404808569\\n', '6'],
#  ['选手\\t2.982393164359433\\n', '7'],
#  ['黄龙\\t2.9752653842075416\\n', '7'],
#  ['男棋手\\t2.9470975200175897\\n', '6'],
#  ['背景\\t2.8966647793747264\\n', '8'],
#  ['循环\\t2.8867593738622213\\n', '6'],
#  ['日\\t2.866209811416816\\n', '9'],
#  ['国际象\\t2.8656479783783384\\n', '7'],
#  ['杯世界\\t2.8335979941940503\\n', '6'],
#  ['国参加\\t2.8335979941940503\\n', '6'],
#  ['獲勝者\\t2.8335979941940503\\n', '6'],
#  ['预选\\t2.8163105225324156\\n', '13'],
#  ['人類\\t2.8153085669689375\\n', '6'],
#  ['着法\\t2.8144912917657354\\n', '7'],
#  ['主办\\t2.722557696215822\\n', '8'],
#  ['围棋赛\\t2.7029140295748006\\n', '8'],
#  ['申旻埈\\t2.6900805862539032\\n', '8'],
#  ['崔哲瀚\\t2.683494694997519\\n', '9'],
#  ['连胜\\t2.6765571221324382\\n', '11'],
#  ['名人战\\t2.67481956616779\\n', '7'],
#  ['亞軍\\t2.6474308330404517\\n', '9'],
#  ['步棋\\t2.6460927308299507\\n', '10'],
#  ['镇围棋\\t2.6326778710572736\\n', '6'],
#  ['个人\\t2.632149088131048\\n', '6'],
#  ['组\\t2.6252006572029614\\n', '36'],
#  ['王积薪\\t2.6073928539909637\\n', '8'],
#  ['家家督\\t2.6073928539909637\\n', '6'],
#  ['目半\\t2.602308177104357\\n', '8'],
#  ['為名人\\t2.590536175946757\\n', '10'],
#  ['还棋头\\t2.590536175946757\\n', '7'],
#  ['vs\\t2.5785227286538235\\n', '10'],
#  ['预选赛\\t2.5745053068542076\\n', '7'],
#  ['对局\\t2.5587651102065387\\n', '8'],
#  ['黃士\\t2.5587651102065387\\n', '9'],
#  ['推广\\t2.5562819242919703\\n', '9'],
#  ['挑战\\t2.5483940015199242\\n', '6'],
#  ['人以\\t2.546915039480438\\n', '7'],
#  ['姜堰\\t2.5466654834054885\\n', '7'],
#  ['数据\\t2.5406156700049634\\n', '8'],
#  ['分析\\t2.535665822677261\\n', '7'],
#  ['人围\\t2.5314640185387014\\n', '6'],
#  ['交流\\t2.526287164582667\\n', '10'],
#  ['軟體\\t2.518417095886986\\n', '6'],
#  ['方圓\\t2.51819577328537\\n', '16'],
#  ['跡目\\t2.51819577328537\\n', '8'],
#  ['年日本\\t2.5108732055465524\\n', '10'],
#  ['衢州\\t2.5079466776421273\\n', '6'],
#  ['亞藝盃\\t2.506252785725724\\n', '6'],
#  ['其它\\t2.5017240124301585\\n', '11'],
#  ['网选\\t2.4933882628164596\\n', '8'],
#  ['负于\\t2.4933882628164596\\n', '8'],
#  ['勝制\\t2.4933882628164596\\n', '8'],
#  ['獲得\\t2.4933882628164596\\n', '8'],
#  ['此頭銜\\t2.4900756026291306\\n', '6'],
#  ['杯本赛\\t2.4900756026291306\\n', '6'],
#  ['名人賽\\t2.4839850400664982\\n', '11'],
#  ['关东\\t2.4762676547448317\\n', '6'],
#  ['團隊\\t2.4762676547448317\\n', '6'],
#  ['棋品\\t2.4498684689970855\\n', '6'],
#  ['道策\\t2.4498684689970855\\n', '9'],
#  ['则是\\t2.4317190287955097\\n', '6'],
#  ['弈秋\\t2.408384034250627\\n', '8'],
#  ['複雜\\t2.408384034250627\\n', '8'],
#  ['小飛\\t2.408384034250627\\n', '7'],
#  ['透過\\t2.375996170749284\\n', '9'],
#  ['杯围棋\\t2.357945319298783\\n', '6'],
#  ['数学\\t2.354688234376265\\n', '6'],
#  ['围棋最\\t2.3525358094002997\\n', '6'],
#  ['基金會\\t2.3521672493852384\\n', '8'],
#  ['中國圍\\t2.351777009369291\\n', '6'],
#  ['对抗赛\\t2.3499558892948693\\n', '11'],
#  ['际围棋\\t2.3499558892948693\\n', '6'],
#  ['棋世界\\t2.3381186088111297\\n', '6'],
#  ['本棋院\\t2.3364113087413596\\n', '6'],
#  ['服务器\\t2.334476368662287\\n', '6'],
#  ['国家队\\t2.334476368662287\\n', '7'],
#  ['是围棋\\t2.332265008571918\\n', '8'],
#  ['围棋网\\t2.3267366083459957\\n', '6'],
#  ['自我訓練\\t2.3227182597230907\\n', '7'],
#  ['淘汰赛\\t2.3189968480297045\\n', '6'],
#  ['棋院和\\t2.3189968480297045\\n', '6'],
#  ['内围棋\\t2.3138370078188437\\n', '6'],
#  ['重要性\\t2.3138370078188437\\n', '6'],
#  ['世本因\\t2.307387207555268\\n', '6'],
#  ['个人赛\\t2.307387207555268\\n', '8'],
#  ['為本因\\t2.307387207555268\\n', '6'],
#  ['選拔賽\\t2.2990946072163845\\n', '8'],
#  ['段位的\\t2.2990946072163845\\n', '6'],
#  ['输给了\\t2.2990946072163845\\n', '6'],
#  ['市围棋\\t2.2880378067645397\\n', '6'],
#  ['刀定式\\t2.2880378067645397\\n', '7'],
#  ['组成的\\t2.2880378067645397\\n', '6'],
#  ['俱乐部\\t2.2880378067645397\\n', '6'],
#  ['被视为\\t2.2880378067645397\\n', '6'],
#  ['研究的\\t2.2880378067645397\\n', '7'],
#  ['將棋界\\t2.2880378067645397\\n', '6'],
#  ['赵晨宇\\t2.27784243805275\\n', '6'],
#  ['被叫做\\t2.2725582861319573\\n', '6'],
#  ['电王战\\t2.2725582861319573\\n', '6'],
#  ['假眼活\\t2.2725582861319573\\n', '6'],
#  ['段以\\t2.26837406698133\\n', '7'],
#  ['桐山杯\\t2.253368236864921\\n', '11'],
#  ['方式\\t2.253180849531457\\n', '7'],
#  ['之一\\t2.2516869186257615\\n', '31'],
#  ['体育\\t2.2515300558806635\\n', '9'],
#  ['名单\\t2.249773958319688\\n', '13'],
#  ['位提白\\t2.2493390051830837\\n', '6'],
#  ['朴鋕恩\\t2.2493390051830837\\n', '6'],
#  ['方用时\\t2.2493390051830837\\n', '6'],
#  ['规则\\t2.2487192450698528\\n', '9'],
#  ['元战\\t2.2487192450698528\\n', '6'],
#  ['制度\\t2.2484189447695524\\n', '14'],
#  ['工智\\t2.2481014844520923\\n', '7'],
#  ['業圍\\t2.2477653499983106\\n', '6'],
#  ['因坊\\t2.2477653499983106\\n', '8'],
#  ['国棋\\t2.2477653499983106\\n', '7'],
#  ['之间\\t2.246626830074212\\n', '6'],
#  ['氏杯\\t2.2461967225473303\\n', '8'],
#  ['国业\\t2.2457369524323876\\n', '10'],
#  ['酒店\\t2.242863389213997\\n', '6'],
#  ['運算\\t2.2421387515328375\\n', '9'],
#  ['單位\\t2.2413482376988454\\n', '7'],
#  ['定式\\t2.2404824368330445\\n', '10'],
#  ['最高\\t2.2404824368330445\\n', '10'],
#  ['全國\\t2.2404824368330445\\n', '6'],
#  ['本学\\t2.2395300558806635\\n', '6'],
#  ['传说\\t2.2395300558806635\\n', '7'],
#  ['網站\\t2.2395300558806635\\n', '7'],
#  ['最佳\\t2.238477424301716\\n', '7'],
#  ['实业\\t2.238477424301716\\n', '6'],
#  ['国职\\t2.2373078336584413\\n', '7'],
#  ['院和\\t2.2360006441159577\\n', '6'],
#  ['南京\\t2.2360006441159577\\n', '6'],
#  ['高段\\t2.2360006441159577\\n', '7'],
#  ['支援\\t2.2360006441159577\\n', '6'],
#  ['政府\\t2.2360006441159577\\n', '7'],
#  ['同樣\\t2.2360006441159577\\n', '6'],
#  ['能力\\t2.2345300558806636\\n', '8'],
#  ['表团\\t2.2345300558806636\\n', '10'],
#  ['国流\\t2.2345300558806636\\n', '11'],
#  ['棋牌\\t2.232863389213997\\n', '7'],
#  ['參數\\t2.232863389213997\\n', '7'],
#  ['全部\\t2.232863389213997\\n', '7'],
#  ['模仿\\t2.232863389213997\\n', '6'],
#  ['团队\\t2.230958627309235\\n', '6'],
#  ['三轮\\t2.230958627309235\\n', '6'],
#  ['佔角\\t2.230958627309235\\n', '6'],
#  ['對戰\\t2.228760825111433\\n', '8'],
#  ['讀賣\\t2.228760825111433\\n', '7'],
#  ['元老\\t2.228760825111433\\n', '8'],
#  ['應用\\t2.228760825111433\\n', '11'],
#  ['实际\\t2.228760825111433\\n', '7'],
#  ['再次\\t2.228760825111433\\n', '6'],
#  ['中学\\t2.228760825111433\\n', '6'],
#  ['网上\\t2.228760825111433\\n', '6'],
#  ['卫平\\t2.228760825111433\\n', '12'],
#  ['則因\\t2.228760825111433\\n', '6'],
#  ['中部\\t2.2261967225473303\\n', '7'],
#  ['顶尖\\t2.2261967225473303\\n', '8'],
#  ['系列\\t2.2261967225473303\\n', '6'],
#  ['原因\\t2.2261967225473303\\n', '6'],
#  ['国象\\t2.2261967225473303\\n', '8'],
#  ['这种\\t2.2261967225473303\\n', '9'],
#  ['邀请\\t2.2261967225473303\\n', '8'],
#  ['赛于\\t2.2231664195170273\\n', '18'],
#  ['计数\\t2.2231664195170273\\n', '7'],
#  ['九段\\t2.2231664195170273\\n', '7'],
#  ['設定\\t2.2231664195170273\\n', '8'],
#  ['各地\\t2.2231664195170273\\n', '7'],
#  ['為台\\t2.2231664195170273\\n', '6'],
#  ['李东勋\\t2.220096037239781\\n', '6'],
#  ['预赛\\t2.2195300558806634\\n', '6'],
#  ['长期\\t2.2195300558806634\\n', '6'],
#  ['卡斯\\t2.2195300558806634\\n', '6'],
#  ['貼目\\t2.2195300558806634\\n', '8'],
#  ['比對\\t2.2195300558806634\\n', '6'],
#  ['真眼\\t2.2195300558806634\\n', '10'],
#  ['之莹\\t2.2195300558806634\\n', '6'],
#  ['工作\\t2.2195300558806634\\n', '8'],
#  ['富士\\t2.2195300558806634\\n', '6'],
#  ['通过\\t2.215085611436219\\n', '12'],
#  ['執黑\\t2.215085611436219\\n', '6'],
#  ['圣战\\t2.215085611436219\\n', '9'],
#  ['大小\\t2.215085611436219\\n', '6'],
#  ['读秒\\t2.215085611436219\\n', '9'],
#  ['世代\\t2.215085611436219\\n', '6'],
#  ['裁判\\t2.215085611436219\\n', '6'],
#  ['程度\\t2.215085611436219\\n', '6'],
#  ['卡尔\\t2.215085611436219\\n', '6'],
#  ['台赛\\t2.215085611436219\\n', '7'],
#  ['棋協\\t2.215085611436219\\n', '6'],
#  ['日本圍\\t2.2106402036016273\\n', '7'],
#  ['12万\\t2.2106402036016273\\n', '6'],
#  ['实力\\t2.2095300558806636\\n', '7'],
#  ['安節\\t2.2095300558806636\\n', '9'],
#  ['陕西\\t2.2095300558806636\\n', '6'],
#  ['全运\\t2.2095300558806636\\n', '6'],
#  ['显著\\t2.2095300558806636\\n', '9'],
#  ['智能\\t2.2095300558806636\\n', '8'],
#  ['參考\\t2.2095300558806636\\n', '6'],
#  ['当时\\t2.2095300558806636\\n', '7'],
#  ['宣布\\t2.2095300558806636\\n', '8'],
#  ['网格\\t2.2095300558806636\\n', '8'],
#  ['坐标\\t2.2095300558806636\\n', '8'],
#  ['棋艺\\t2.2095300558806636\\n', '7'],
#  ['循環\\t2.2095300558806636\\n', '6'],
#  ['極其\\t2.2095300558806636\\n', '6'],
#  ['世襲\\t2.2095300558806636\\n', '6'],
#  ['達成\\t2.2023871987378065\\n', '8'],
#  ['日程\\t2.2023871987378065\\n', '6'],
#  ['每年\\t2.2023871987378065\\n', '9'],
#  ['東京\\t2.2023871987378065\\n', '6'],
#  ['专家\\t2.2023871987378065\\n', '9'],
#  ['规定\\t2.2023871987378065\\n', '6'],
#  ['方一\\t2.2023871987378065\\n', '6'],
#  ['本薰\\t2.2023871987378065\\n', '6'],
#  ['提升\\t2.2023871987378065\\n', '9'],
#  ['之子\\t2.2023871987378065\\n', '7'],
#  ['占据\\t2.2023871987378065\\n', '7'],
#  ['1月1日\\t2.1934701346870327\\n', '7'],
#  ['江维\\t2.192863389213997\\n', '6'],
#  ['升降\\t2.192863389213997\\n', '6'],
#  ['连续\\t2.192863389213997\\n', '8'],
#  ['佛乘\\t2.192863389213997\\n', '6'],
#  ['德川\\t2.192863389213997\\n', '6'],
#  ['报名\\t2.192863389213997\\n', '6'],
#  ['利益\\t2.192863389213997\\n', '8'],
#  ['赛前\\t2.179530055880664\\n', '6'],
#  ['连接\\t2.179530055880664\\n', '6'],
#  ['先前\\t2.179530055880664\\n', '6'],
#  ['东京\\t2.179530055880664\\n', '6'],
#  ['创办\\t2.179530055880664\\n', '11'],
#  ['手割\\t2.179530055880664\\n', '6'],
#  ['打算\\t2.179530055880664\\n', '6'],
#  ['實做\\t2.179530055880664\\n', '7'],
#  ['可能\\t2.179530055880664\\n', '10'],
#  ['变得\\t2.179530055880664\\n', '10'],
#  ['歷史\\t2.179530055880664\\n', '6'],
#  ['坊門\\t2.179530055880664\\n', '6'],
#  ['利用\\t2.1629353671300158\\n', '6'],
#  ['十二\\t2.159530055880664\\n', '6'],
#  ['台北\\t2.159530055880664\\n', '6'],
#  ['成员\\t2.159530055880664\\n', '6'],
#  ['消劫\\t2.159530055880664\\n', '9'],
#  ['领域\\t2.159530055880664\\n', '7'],
#  ['之父\\t2.159530055880664\\n', '6'],
#  ['争夺\\t2.159530055880664\\n', '6'],
#  ['2万\\t2.159530055880664\\n', '7'],
#  ['得第\\t2.159530055880664\\n', '6'],
#  ['开发\\t2.159530055880664\\n', '13'],
#  ['佐為\\t2.159530055880664\\n', '10'],
#  ['己方\\t2.159530055880664\\n', '6'],
#  ['马晓春\\t2.15550052574024\\n', '8'],
#  ['外卡\\t2.1486287590338646\\n', '6'],
#  ['後黑\\t2.147058951158271\\n', '7'],
#  ['29日\\t2.1332426004387153\\n', '6'],
#  ['加以\\t2.12619672254733\\n', '6'],
#  ['知得\\t2.12619672254733\\n', '9'],
#  ['高校\\t2.12619672254733\\n', '6'],
#  ['很多\\t2.12619672254733\\n', '6'],
#  ['受到\\t2.12619672254733\\n', '8'],
#  ['相鄰\\t2.12619672254733\\n', '6'],
#  ['小组\\t2.12619672254733\\n', '6'],
#  ['打入\\t2.12619672254733\\n', '8'],
#  ['出场\\t2.12619672254733\\n', '9'],
#  ['彼此\\t2.12619672254733\\n', '8'],
#  ['分數\\t2.12619672254733\\n', '6'],
#  ['停止\\t2.12619672254733\\n', '6'],
#  ['胜出\\t2.12619672254733\\n', '8'],
#  ['局\\t2.119548737021415\\n', '8'],
#  ['为\\t2.1078994267159077\\n', '9'],
#  ['距離\\t2.0999308818588323\\n', '7'],
#  ['挑战赛\\t2.096449166859063\\n', '9'],
#  ['点\\t2.0912950576607336\\n', '6'],
#  ['李小溪\\t2.0603618870890896\\n', '6'],
#  ['周俊勳\\t2.0603618870890896\\n', '7'],
#  ['月\\t2.0595958076463106\\n', '7'],
#  ['3日\\t2.0595300558806637\\n', '6'],
#  ['6日\\t2.0595300558806637\\n', '8'],
#  ['将于\\t2.0595300558806637\\n', '6'],
#  ['聞社\\t2.0595300558806637\\n', '7'],
#  ['創立\\t2.0595300558806637\\n', '7'],
#  ['4日\\t2.0595300558806637\\n', '6'],
#  ['定石\\t2.0595300558806637\\n', '6'],
#  ['下到\\t2.0595300558806637\\n', '6'],
#  ['棋以\\t2.0595300558806637\\n', '6'],
#  ['釋出\\t2.0595300558806637\\n', '8'],
#  ['赛制\\t2.0595300558806637\\n', '10'],
#  ['种子\\t2.0293491349685002\\n', '7'],
#  ['香港\\t1.987771308972087\\n', '6'],
#  ['腾讯野\\t1.9419804967160113\\n', '6'],
#  ['思考\\t1.9377348247068322\\n', '6'],
#  ['小時\\t1.924849586552474\\n', '8'],
#  ['单败淘\\t1.9059496620512202\\n', '6'],
#  ['放送\\t1.9001494666507635\\n', '6'],
#  ['获胜者\\t1.8926156689798255\\n', '7'],
#  ['复杂性\\t1.877873268377366\\n', '10'],
#  ['同时\\t1.8771331698967237\\n', '8'],
#  ['互相\\t1.8660220587856127\\n', '8'],
#  ['方各\\t1.8660220587856127\\n', '6'],
#  ['职业棋手\\t1.8659496811311729\\n', '7'],
#  ['棋戰\\t1.8571331698967237\\n', '7'],
#  ['人数\\t1.8512072439707978\\n', '7'],
#  ['技巧\\t1.8512072439707978\\n', '8'],
#  ['附近\\t1.8437998365633903\\n', '7'],
#  ['則是\\t1.8437998365633903\\n', '6'],
#  ['女流\\t1.8408305224783237\\n', '6'],
#  ['际象\\t1.837756971987747\\n', '6'],
#  ['平面\\t1.8342760270395808\\n', '6'],
#  ['这样\\t1.8342760270395808\\n', '8'],
#  ['直线\\t1.8342760270395808\\n', '6'],
#  ['阶段\\t1.8264024568175126\\n', '6'],
#  ['虽然\\t1.8215776143411682\\n', '7'],
#  ['夺得\\t1.8215776143411682\\n', '6'],
#  ['名棋手\\t1.8038100630253031\\n', '7'],
#  ['意思\\t1.8037998365633903\\n', '7'],
#  ['包圍\\t1.8037998365633903\\n', '9'],
#  ['段位制\\t1.7789388327067355\\n', '10'],
#  ['超過\\t1.7771331698967237\\n', '6'],
#  ['改稱\\t1.7771331698967237\\n', '6'],
#  ['正官庄杯\\t1.7766904613660914\\n', '7'],
#  ['世纪\\t1.7579705594417299\\n', '9'],
#  ['圍棋賽\\t1.754993423460075\\n', '7'],
#  ['强战\\t1.7464889817390823\\n', '6'],
#  ['樊麾\\t1.7437559079068223\\n', '11'],
#  ['必須\\t1.7326887254522791\\n', '6'],
#  ['formula\\t1.723504625532258\\n', '6'],
#  ['范西屏\\t1.7094553128457937\\n', '7'],
#  ['国手战\\t1.7058588734708602\\n', '6'],
#  ['互联网\\t1.699102872847343\\n', '9'],
#  ['扇興杯\\t1.6911185084740956\\n', '6'],
#  ['名人戰\\t1.6911185084740956\\n', '6'],
#  ['对围棋\\t1.6911185084740956\\n', '6'],
#  ['豐田杯\\t1.6911185084740956\\n', '6'],
#  ['通常\\t1.690569062835671\\n', '9'],
#  ['舉辦\\t1.6852640446505547\\n', '9'],
#  ['主要\\t1.6837508810174893\\n', '8'],
#  ['手合\\t1.6832470262260224\\n', '7'],
#  ['国棋手\\t1.669826870145436\\n', '7'],
#  ['周俊\\t1.66605182017215\\n', '7'],
#  ['真露杯\\t1.6551888687944825\\n', '7'],
#  ['中環\\t1.6386535174377295\\n', '7'],
#  ['数子\\t1.6338276800242804\\n', '9'],
#  ['得天元\\t1.6112748647416217\\n', '6'],
#  ['赞助商\\t1.6112748647416217\\n', '6'],
#  ['3月4日\\t1.5811356481346013\\n', '6'],
#  ['周俊勋\\t1.5407096217549345\\n', '7'],
#  ['數子法\\t1.5407096217549345\\n', '6'],
#  ['杭州\\t1.5368471846089802\\n', '8'],
#  ['世乭\\t1.5308401629937483\\n', '6'],
#  ['資料\\t1.5269057834281834\\n', '6'],
#  ['棋赛\\t1.5265017584938583\\n', '6'],
#  ['工程\\t1.5252085802294681\\n', '6'],
#  ['淘汰\\t1.5252085802294681\\n', '6'],
#  ['棋賽\\t1.5096904410567853\\n', '8'],
#  ['赛事\\t1.5096904410567853\\n', '10'],
#  ['广州\\t1.5096904410567853\\n', '9'],
#  ['對弈中\\t1.5065393790498312\\n', '7'],
#  ['厚勢\\t1.5006345674130859\\n', '10'],
#  ['安排\\t1.4952807403964372\\n', '8'],
#  ['生涯\\t1.490292767090932\\n', '7'],
#  ['2轮\\t1.490292767090932\\n', '8'],
#  ['宇宙流\\t1.4850633487700247\\n', '7'],
#  ['上海\\t1.4844734649011757\\n', '6'],
#  ['对于\\t1.4801219577515723\\n', '9'],
#  ['胜负\\t1.4624025766396564\\n', '8'],
#  ['名将\\t1.4592564887455663\\n', '7'],
#  ['专业\\t1.4515322287332832\\n', '6'],
#  ['快棋\\t1.4466480006677616\\n', '6'],
#  ['获得\\t1.4466480006677616\\n', '6'],
#  ['存在\\t1.4466480006677616\\n', '6'],
#  ['立於\\t1.4395877241329549\\n', '6'],
#  ['举办的\\t1.4356188485301786\\n', '6'],
#  ['年間\\t1.4088225364343476\\n', '7'],
#  ['年年\\t1.4088225364343476\\n', '6'],
#  ['山东\\t1.4088225364343476\\n', '6'],
#  ['方可\\t1.3959828360757185\\n', '7'],
#  ['元和\\t1.3959828360757185\\n', '7'],
#  ['辜梓豪\\t1.381794648526073\\n', '9'],
#  ['同名\\t1.3785621650476163\\n', '6'],
#  ['罗玄\\t1.3785621650476163\\n', '7'],
#  ['方捷\\t1.3785621650476163\\n', '7'],
#  ['淘汰賽\\t1.3738530991808355\\n', '9'],
#  ['局棋\\t1.3650903155910217\\n', '6'],
#  ['陈浩\\t1.3640374875811636\\n', '9'],
#  ['男子\\t1.3518465794626116\\n', '7'],
#  ['结果\\t1.337247487452804\\n', '6'],
#  ['位\\t1.333869742879667\\n', '6'],
#  ['丁烈\\t1.333171607967519\\n', '6'],
#  ['運用\\t1.3293099760828708\\n', '11'],
#  ['围棋名人战\\t1.3268950925882852\\n', '6'],
#  ['林海峰\\t1.2976336455726383\\n', '7'],
#  ['贊助\\t1.2719774967514774\\n', '10'],
#  ['人机\\t1.270218891581867\\n', '6'],
#  ['世界第\\t1.262699729335548\\n', '7'],
#  ['加藤\\t1.2617867144832307\\n', '6'],
#  ['日和\\t1.2575206795006908\\n', '6'],
#  ['年獲\\t1.2575206795006908\\n', '6'],
#  ['选拔\\t1.251980866548744\\n', '6'],
#  ['讀賣新聞\\t1.247764817214702\\n', '6'],
#  ['職業圍棋\\t1.2453501269765912\\n', '7'],
#  ['小林光\\t1.2448522565878797\\n', '17'],
#  ['年日\\t1.2352999537438025\\n', '9'],
#  ['計算\\t1.2345934886662078\\n', '6'],
#  ['日围棋\\t1.1947598688898002\\n', '6'],
#  ['围棋大\\t1.1931662155169143\\n', '6'],
#  ['对弈\\t1.1869119466115952\\n', '12'],
#  ['錦標賽\\t1.1809269576131491\\n', '6'],
#  ['丁明君\\t1.1754281605839212\\n', '6'],
#  ['赛冠军\\t1.1723038440900417\\n', '14'],
#  ['伺服器\\t1.1688819736443645\\n', '6'],
#  ['届比\\t1.1652097747761685\\n', '7'],
#  ['综合\\t1.1632015721908684\\n', '9'],
#  ['業棋士\\t1.1609576420859535\\n', '7'],
#  ['国务\\t1.1592888837090691\\n', '7'],
#  ['为围棋\\t1.156335115343547\\n', '6'],
#  ['张馨月\\t1.1511687619255635\\n', '6'],
#  ['女子围\\t1.145356614330332\\n', '7'],
#  ['年度\\t1.133269505305103\\n', '9'],
#  ['无锡市\\t1.131241398741912\\n', '6'],
#  ['程式碼\\t1.131241398741912\\n', '7'],
#  ['顾水如\\t1.1225551122259618\\n', '6'],
#  ['出线\\t1.1221183431319748\\n', '12'],
#  ['棋水平\\t1.1124211112906863\\n', '6'],
#  ['公開賽\\t1.1124211112906863\\n', '8'],
#  ['年取\\t1.112206198978083\\n', '6'],
#  ['數子\\t1.1047329532377073\\n', '6'],
#  ['本赛第\\t1.1021048566379197\\n', '7'],
#  ['分散式\\t1.1004445647308154\\n', '6'],
#  ['指围棋\\t1.1004445647308154\\n', '7'],
#  ['围棋队\\t1.1004445647308154\\n', '8'],
#  ['网络\\t1.0943212552418722\\n', '9'],
#  ['對弈\\t1.0916012673942381\\n', '8'],
#  ['国规则\\t1.08607270885897\\n', '6'],
#  ['為台灣\\t1.08607270885897\\n', '8'],
#  ['使用者\\t1.085041348831386\\n', '6'],
#  ['关西\\t1.078865100164157\\n', '10'],
#  ['目的\\t1.0715251688042118\\n', '10'],
#  ['改名為\\t1.0685071072378256\\n', '7'],
#  ['優勝者\\t1.0567377490481857\\n', '7'],
#  ['為了\\t1.0542469240485617\\n', '9'],
#  ['版本\\t1.0408456550189389\\n', '7'],
#  ['团体\\t1.0372551033712054\\n', '6'],
#  ['段位\\t1.0362327935270592\\n', '7'],
#  ['周睿\\t1.0315046104978824\\n', '13'],
#  ['决赛中\\t1.027973657420119\\n', '6'],
#  ['落子\\t1.0271025090569246\\n', '8'],
#  ['資源\\t1.0236243054492544\\n', '7'],
#  ['程式\\t1.0216845380526693\\n', '6'],
#  ['电视\\t1.019589589264357\\n', '6'],
#  ['弟子\\t1.019589589264357\\n', '11'],
#  ['為圍棋\\t1.0183196740345564\\n', '6'],
#  ['小光\\t1.0092146047889061\\n', '19'],
#  ['抗賽\\t1.0092146047889061\\n', '6'],
#  ['家督\\t1.0059724221403277\\n', '6'],
#  ['白棋\\t1.0023889571076885\\n', '6'],
#  ['券杯\\t0.998407329293645\\n', '7'],
#  ['實利\\t0.998407329293645\\n', '6'],
#  ['晚报\\t0.9939572746779494\\n', '6'],
#  ['安井\\t0.9939572746779494\\n', '6'],
#  ['秀和\\t0.9939572746779494\\n', '14'],
#  ['限公\\t0.9889509632352916\\n', '8'],
#  ['名譽\\t0.9889509632352916\\n', '7'],
#  ['發行\\t0.9858263610159633\\n', '9'],
#  ['挑戰\\t0.9856846542854361\\n', '7'],
#  ['蒙地\\t0.9832771436002793\\n', '8'],
#  ['新布局\\t0.980679099132104\\n', '6'],
#  ['大赛\\t0.9767927783031226\\n', '6'],
#  ['武宮\\t0.9767927783031226\\n', '7'],
#  ['报道\\t0.9767927783031226\\n', '6'],
#  ['直播\\t0.969310818344865\\n', '9'],
#  ['獲勝\\t0.9605818650602308\\n', '7'],
#  ['和韩\\t0.9605818650602308\\n', '7'],
#  ['協會\\t0.9605818650602308\\n', '6'],
#  ['團體\\t0.9605818650602308\\n', '6'],
#  ['采取\\t0.9605818650602308\\n', '6'],
#  ['中日\\t0.9605818650602308\\n', '10'],
#  ['才能\\t0.9605818650602308\\n', '11'],
#  ['守角\\t0.950265829360209\\n', '9'],
#  ['现代\\t0.950265829360209\\n', '6'],
#  ['浙江\\t0.9489918680795542\\n', '9'],
#  ['之間\\t0.9378865865201825\\n', '10'],
#  ['赛区\\t0.9378865865201825\\n', '10'],
#  ['已經\\t0.9378865865201825\\n', '6'],
#  ['造成\\t0.9378865865201825\\n', '7'],
#  ['例子\\t0.9378865865201825\\n', '6'],
#  ['当今\\t0.9378865865201825\\n', '6'],
#  ['高目\\t0.9378865865201825\\n', '7'],
#  ['棋圣战\\t0.9329987602203045\\n', '9'],
#  ['日本队\\t0.9279822942686714\\n', '6'],
#  ['郭闻潮\\t0.9279822942686714\\n', '6'],
#  ['方先\\t0.9227564008268166\\n', '7'],
#  ['小时\\t0.9227564008268166\\n', '7'],
#  ['棋坛\\t0.9227564008268166\\n', '6'],
#  ['策略\\t0.9227564008268166\\n', '6'],
#  ['曹薰\\t0.9227564008268166\\n', '6'],
#  ['本身\\t0.9227564008268166\\n', '6'],
#  ['男女\\t0.9227564008268166\\n', '6'],
#  ['星位\\t0.9202451221273162\\n', '7'],
#  ['丁浩\\t0.908372899698648\\n', '7'],
#  ['全国\\t0.9038436687101098\\n', '8'],
#  ['征子\\t0.9038436687101098\\n', '6'],
#  ['原子\\t0.9038436687101098\\n', '6'],
#  ['发生\\t0.9038436687101098\\n', '8'],
#  ['整個\\t0.9038436687101098\\n', '7'],
#  ['參加\\t0.9038436687101098\\n', '9'],
#  ['目數\\t0.9038436687101098\\n', '7'],
#  ['個黑\\t0.9038436687101098\\n', '6'],
#  ['秀策\\t0.8986428722760144\\n', '6'],
#  ['方用\\t0.8944015236151615\\n', '6'],
#  ['弈城\\t0.8888392612055692\\n', '7'],
#  ['棋盘\\t0.8814501719079235\\n', '17'],
#  ['首次\\t0.879527298845772\\n', '9'],
#  ['长考\\t0.879527298845772\\n', '7'],
#  ['秀行\\t0.879527298845772\\n', '6'],
#  ['风格\\t0.879527298845772\\n', '6'],
#  ['電腦圍\\t0.877114042037215\\n', '8'],
#  ['亚军\\t0.8752707346464161\\n', '7'],
#  ['业围\\t0.8732298980458058\\n', '7'],
#  ['比目法\\t0.8686742541692414\\n', '11'],
#  ['日本的\\t0.848937086973522\\n', '6'],
#  ['9x9\\t0.848937086973522\\n', '8'],
#  ['类似\\t0.8471054723599885\\n', '9'],
#  ['三三\\t0.8471054723599885\\n', '7'],
#  ['手数\\t0.8471054723599885\\n', '6'],
#  ['連接\\t0.8471054723599885\\n', '6'],
#  ['官方\\t0.8471054723599885\\n', '6'],
#  ['繼承\\t0.8471054723599885\\n', '7'],
#  ['作戰\\t0.8471054723599885\\n', '6'],
#  ['国棋院\\t0.8401276390463158\\n', '10'],
#  ['黑方\\t0.8391417444320871\\n', '7'],
#  ['業餘\\t0.8379954432748877\\n', '6'],
#  ['個角\\t0.8365533354965274\\n', '7'],
#  ['许嘉阳\\t0.8321160157667659\\n', '6'],
#  ['分為\\t0.8017149152798915\\n', '6'],
#  ['王世\\t0.8017149152798915\\n', '6'],
#  ['國內\\t0.7767605678181184\\n', '8'],
#  ['崔精\\t0.7761296169957612\\n', '8'],
#  ['国围\\t0.7756610280189682\\n', '6'],
#  ['機會\\t0.7744637987170401\\n', '7'],
#  ['陳耀燁\\t0.7720462491639185\\n', '7'],
#  ['職業棋\\t0.7579198629753516\\n', '6'],
#  ['职业围棋\\t0.7508603297074032\\n', '7'],
#  ['范胤\\t0.7462412819990912\\n', '6'],
#  ['世界最\\t0.7404964805897652\\n', '6'],
#  ['芮乃伟\\t0.7315651160262839\\n', '7'],
#  ['官子\\t0.7179597740085963\\n', '6'],
#  ['李昌鎬\\t0.7076634851893112\\n', '8'],
#  ['演算法\\t0.6936338608622409\\n', '8'],
#  ['朴文垚\\t0.6889494912631855\\n', '7'],
#  ['浙江省\\t0.6863220381790159\\n', '8'],
#  ['屆起\\t0.6860596257358753\\n', '11'],
#  ['阿含\\t0.6717659533533029\\n', '9'],
#  ['決賽\\t0.6716444041932543\\n', '9'],
#  ['按照\\t0.6682988690354127\\n', '11'],
#  ['少年\\t0.665636830462065\\n', '6'],
#  ['赵治勋\\t0.660238047388655\\n', '6'],
#  ['本年度\\t0.660238047388655\\n', '6'],
#  ['终局\\t0.6588282469000506\\n', '6'],
#  ['決定\\t0.652646051542123\\n', '6'],
#  ['情況下\\t0.6497697287449977\\n', '6'],
#  ['棋局\\t0.6494374917500148\\n', '7'],
#  ['情况\\t0.6469434544331818\\n', '10'],
#  ['處理\\t0.6420686565935532\\n', '7'],
#  ['全局\\t0.6420686565935532\\n', '7'],
#  ['执黑\\t0.6349746951453168\\n', '8'],
#  ['林家\\t0.6321643081340942\\n', '7'],
#  ['交叉\\t0.631955015901031\\n', '7'],
#  ['擊敗\\t0.6315939126519923\\n', '11'],
#  ['變成\\t0.6315939126519923\\n', '6'],
#  ['木谷\\t0.6240303785069161\\n', '6'],
#  ['强赛\\t0.6235445727506144\\n', '7'],
#  ['戰鬥\\t0.6192399567683219\\n', '7'],
#  ['任何\\t0.6192146698119658\\n', '8'],
#  ['內容\\t0.604359578403934\\n', '6'],
#  ['日本棋院\\t0.6015176362311536\\n', '6'],
#  ['日至\\t0.6013903866756733\\n', '6'],
#  ['國際\\t0.5890102177937593\\n', '6'],
#  ['广西\\t0.5882025550169692\\n', '6'],
#  ['曹大元\\t0.5870688148234287\\n', '6'],
#  ['應對\\t0.5862033555718951\\n', '7'],
#  ['尤其\\t0.5862033555718951\\n', '6'],
#  ['整个\\t0.5805431708980526\\n', '10'],
#  ['职业棋\\t0.5800439979262757\\n', '8'],
#  ['国内\\t0.5660306536201061\\n', '6'],
#  ['改名\\t0.5660306536201061\\n', '6'],
#  ['發生\\t0.5635080770318466\\n', '7'],
#  ['叫吃\\t0.5600516551100212\\n', '10'],
#  ['冠亚军\\t0.5594009672452669\\n', '6'],
#  ['全日本\\t0.5571555649523696\\n', '7'],
#  ['織田\\t0.5460759423629291\\n', '6'],
#  ['藤泽\\t0.528021679796912\\n', '8'],
#  ['广东\\t0.528021679796912\\n', '6'],
#  ['海峰棋院\\t0.5135450792584197\\n', '10'],
#  ['三子\\t0.5082824073308734\\n', '8'],
#  ['局面\\t0.4963737889798576\\n', '9'],
#  ['重要\\t0.48863056147105643\\n', '7'],
#  ['年围\\t0.48863056147105643\\n', '6'],
#  ['西洋棋\\t0.470085436855488\\n', '6'],
#  ['棋聖戰\\t0.4654890561902583\\n', '7'],
#  ['富士通杯\\t0.45982070987297363\\n', '8'],
#  ['非常\\t0.44778051283683595\\n', '8'],
#  ['董彦\\t0.44778051283683595\\n', '9'],
#  ['對手\\t0.4464218412091605\\n', '6'],
#  ['選手\\t0.4235409641520923\\n', '8'],
#  ['韓國棋院\\t0.42144198846661973\\n', '6'],
#  ['帳號\\t0.4196961044008092\\n', '7'],
#  ['以後\\t0.4196961044008092\\n', '6'],
#  ['公开\\t0.40192129505220286\\n', '6'],
#  ['圍棋棋\\t0.3968139457996821\\n', '8'],
#  ['棋协会\\t0.3966390712066099\\n', '6'],
#  ['關西棋院\\t0.39365630692051257\\n', '7'],
#  ['職業圍\\t0.39101463954688465\\n', '6'],
#  ['种子选\\t0.3887765578226141\\n', '6'],
#  ['中盤\\t0.3881665807855066\\n', '10'],
#  ['队以\\t0.38207716582743445\\n', '6'],
#  ['中日韩\\t0.3613737409214747\\n', '6'],
#  ['杭州市\\t0.3613737409214747\\n', '6'],
#  ['推出\\t0.3514873427409839\\n', '7'],
#  ['等级\\t0.35070854204554314\\n', '8'],
#  ['將棋\\t0.338531352656296\\n', '8'],
#  ['變化\\t0.33436619890936947\\n', '6'],
#  ['棋具\\t0.31135600062029944\\n', '7'],
#  ['棋協會\\t0.29867183998310753\\n', '8'],
#  ['陈祖德\\t0.2805348291071894\\n', '13'],
#  ['年因\\t0.2791243922597262\\n', '6'],
#  ['严欢\\t0.26804029884626535\\n', '6'],
#  ['位置\\t0.257032662335161\\n', '8'],
#  ['江铸久\\t0.2544653131494533\\n', '8'],
#  ['联合\\t0.2406196963660544\\n', '10'],
#  ['为世界\\t0.23095378696967062\\n', '7'],
#  ['对局费\\t0.23082953827135033\\n', '7'],
#  ['围棋规则\\t0.22698535633608619\\n', '6'],
#  ['执白\\t0.22166054298532611\\n', '7'],
#  ['李康\\t0.21999827758435642\\n', '6'],
#  ['結果\\t0.2151288872312891\\n', '7'],
#  ['活棋\\t0.2151288872312891\\n', '6'],
#  ['决赛\\t0.21365572292286505\\n', '12'],
#  ['胡耀宇\\t0.20014532491897508\\n', '6'],
#  ['國際賽\\t0.19834879848171993\\n', '6'],
#  ['了围棋\\t0.19834879848171993\\n', '6'],
#  ['應氏\\t0.19685178711510376\\n', '7'],
#  ['三段\\t0.19685178711510376\\n', '6'],
#  ['這種\\t0.19083369959309804\\n', '7'],
#  ['番棋\\t0.1883303394216141\\n', '6'],
#  ['赞助\\t0.1841821291740392\\n', '15'],
#  ['传统\\t0.17679149537508476\\n', '6'],
#  ['影响\\t0.16853137524684147\\n', '9'],
#  ['城市\\t0.16853137524684147\\n', '6'],
#  ['国家体\\t0.16613800326955197\\n', '6'],
#  ['掛角\\t0.15923874010256822\\n', '7'],
#  ['秀哉\\t0.15923874010256822\\n', '6'],
#  ['奖金\\t0.15740312864443995\\n', '7'],
#  ['特定\\t0.1487070869390582\\n', '6'],
#  ['局部\\t0.1487070869390582\\n', '6'],
#  ['年舉\\t0.1457703407917521\\n', '7'],
#  ['棋战\\t0.13667091189504676\\n', '7'],
#  ['古灵益\\t0.11632794403575875\\n', '6'],
#  ['階段\\t0.11169792261440481\\n', '8'],
#  ['年台\\t0.10658047428501816\\n', '6'],
#  ['達到\\t0.10658047428501816\\n', '10'],
#  ['地區\\t0.10658047428501816\\n', '6'],
#  ['自己的\\t0.10356292484461094\\n', '8'],
#  ['比赛中\\t0.10040118066099646\\n', '10'],
#  ['为围\\t0.08743201398772749\\n', '6'],
#  ['实战\\t0.08743201398772749\\n', '7'],
#  ['兒子\\t0.08743201398772749\\n', '6'],
#  ['停辦\\t0.06968455762120462\\n', '13'],
#  ['比賽中\\t0.06676873620931312\\n', '7'],
#  ['算砂\\t0.03636945319495133\\n', '6'],
#  ['秀甫\\t0.03636945319495133\\n', '6'],
#  ['李喆\\t0.02903784770710338\\n', '6'],
#  ['公開\\t0.02080813136320636\\n', '6'],
#  ['公司\\t0.0023175312145612414\\n', '7'],
#  ['黑貼\\t0.0012639426499182482\\n', '7'],
#  ['大飛\\t0.0012639426499182482\\n', '8'],
#  ['张璇\\t-0.043871713765124665\\n', '7'],
#  ['本局\\t-0.043871713765124665\\n', '6'],
#  ['依照\\t-0.04570129750901511\\n', '6'],
#  ['職業棋手\\t-0.04772018832068814\\n', '7'],
#  ['技术\\t-0.05363723709847315\\n', '10'],
#  ['初段\\t-0.05411084918264747\\n', '11'],
#  ['读秒的\\t-0.05553106179680761\\n', '6'],
#  ['類似\\t-0.0587282386176001\\n', '6'],
#  ['中国\\t-0.06812895287052725\\n', '14'],
#  ['发展\\t-0.07383781059891206\\n', '8'],
#  ['日本围\\t-0.07746660266125238\\n', '7'],
#  ['李世石\\t-0.08256874289794358\\n', '9'],
#  ['云南\\t-0.08537941960458723\\n', '6'],
#  ['安冬旭\\t-0.0914767694070705\\n', '6'],
#  ['奧林匹亞\\t-0.09749923654523901\\n', '6'],
#  ['安井家\\t-0.10188738553693244\\n', '6'],
#  ['韩国\\t-0.10221634213947756\\n', '9'],
#  ['形態\\t-0.10405258898518188\\n', '6'],
#  ['年改\\t-0.10405258898518188\\n', '7'],
#  ['年共\\t-0.10405258898518188\\n', '6'],
#  ['象棋\\t-0.10583052900423998\\n', '6'],
#  ['多数\\t-0.11245655405563341\\n', '8'],
#  ['大学\\t-0.11818902783657394\\n', '7'],
#  ['北京\\t-0.11877233779523899\\n', '7'],
#  ['成為\\t-0.1195496062523922\\n', '10'],
#  ['分鐘\\t-0.130269250993311\\n', '12'],
#  ['某些\\t-0.13245605955900897\\n', '7'],
#  ['棋手在\\t-0.1325346383191805\\n', '6'],
#  ['周泓余\\t-0.1325346383191805\\n', '6'],
#  ['范廷鈺\\t-0.1325346383191805\\n', '7'],
#  ['是日本\\t-0.13754465010952266\\n', '7'],
#  ['重視\\t-0.13800451061137964\\n', '6'],
#  ['勝率\\t-0.14009941784298136\\n', '6'],
#  ['頭銜\\t-0.1413610497144635\\n', '9'],
#  ['台灣圍棋\\t-0.14635502623605007\\n', '8'],
#  ['届应\\t-0.14873941756483294\\n', '6'],
#  ['参赛\\t-0.15094471207394455\\n', '13'],
#  ['柁嘉熹\\t-0.17929466208181433\\n', '6'],
#  ['年以\\t-0.18113941652177706\\n', '6'],
#  ['年代\\t-0.18113941652177706\\n', '11'],
#  ['佟禹林\\t-0.18547459717831155\\n', '6'],
#  ['是台灣\\t-0.20419497512240914\\n', '8'],
#  ['黑白\\t-0.205141538351764\\n', '7'],
#  ['時候\\t-0.2188411607054772\\n', '6'],
#  ['金志锡\\t-0.21892341755454914\\n', '6'],
#  ['然而\\t-0.2284932611511566\\n', '8'],
#  ['保留\\t-0.2284932611511566\\n', '10'],
#  ['是圍棋\\t-0.22990092849299112\\n', '6'],
#  ['實力\\t-0.2619633833428704\\n', '9'],
#  ['此時\\t-0.2634987506863648\\n', '8'],
#  ['連勝\\t-0.2744121407917673\\n', '6'],
#  ['人民\\t-0.30341774518044834\\n', '6'],
#  ['關西\\t-0.315920297790995\\n', '6'],
#  ['成績\\t-0.3224661702092764\\n', '6'],
#  ['職業棋士\\t-0.3265238698034124\\n', '7'],
#  ['網路\\t-0.3297254366412148\\n', '9'],
#  ['黑棋\\t-0.34003966241092554\\n', '13'],
#  ['孔杰\\t-0.3463782498821466\\n', '6'],
#  ['宋容慧\\t-0.34772814530947815\\n', '8'],
#  ['出現\\t-0.35520294149788023\\n', '6'],
#  ['要求\\t-0.35954082029675005\\n', '7'],
#  ['围棋协会\\t-0.36315892534356264\\n', '6'],
#  ['或者\\t-0.3681108039470538\\n', '9'],
#  ['圍棋協\\t-0.3698401204423024\\n', '6'],
#  ['棋形\\t-0.3773188054798432\\n', '17'],
#  ['雖然\\t-0.37739816237920976\\n', '6'],
#  ['遊戲\\t-0.384081759604339\\n', '6'],
#  ['睦镇硕\\t-0.39091799397300814\\n', '6'],
#  ['抗赛\\t-0.39189202755405095\\n', '7'],
#  ['三番棋\\t-0.398346252135681\\n', '8'],
#  ['先手\\t-0.40649803467778156\\n', '11'],
#  ['是由\\t-0.41454143391072584\\n', '6'],
#  ['野狐\\t-0.41454143391072584\\n', '7'],
#  ['特殊\\t-0.41454143391072584\\n', '6'],
#  ['蔡竞\\t-0.4354345241472035\\n', '6'],
#  ['首轮\\t-0.4408874363459059\\n', '11'],
#  ['進入\\t-0.4437254329712026\\n', '6'],
#  ['丁伟\\t-0.4437254329712026\\n', '6'],
#  ['日文\\t-0.4437254329712026\\n', '7'],
#  ['模樣\\t-0.4437254329712026\\n', '13'],
#  ['後因\\t-0.4437254329712026\\n', '7'],
#  ['段和\\t-0.4473780639450083\\n', '6'],
#  ['選擇\\t-0.4488213061539959\\n', '7'],
#  ['木谷實\\t-0.46185296990558167\\n', '7'],
#  ['讓子\\t-0.46271992681639107\\n', '8'],
#  ['彭荃\\t-0.46292543235309513\\n', '6'],
#  ['價值\\t-0.4664718722751511\\n', '6'],
#  ['年舉辦\\t-0.4724621945384643\\n', '7'],
#  ['王磊\\t-0.474125431992533\\n', '6'],
#  ['当时中\\t-0.5035818380188408\\n', '7'],
#  ['届起\\t-0.5040375429902417\\n', '7'],
#  ['国队\\t-0.5166854306223951\\n', '9'],
#  ['职业围\\t-0.540903519996036\\n', '6'],
#  ['常昊\\t-0.5419684022120608\\n', '7'],
#  ['唐奕\\t-0.5559715832038064\\n', '8'],
#  ['坂田\\t-0.5559715832038064\\n', '7'],
#  ['研究\\t-0.5769134399939638\\n', '6'],
#  ['本賽\\t-0.5805254285671884\\n', '6'],
#  ...]

# %%
def change_form(lst):
    for i in range(len(lst)):
        end=lst[i][0].index('\\')
        lst[i][0]=lst[i][0][:end]
    return lst
change_form(lst)
# Out:
# [['定段', '14'],
#  ['江流儿', '30'],
#  ['雷凌云', '21'],
#  ['云子', '26'],
#  ['雙人圍', '12'],
#  ['江流', '28'],
#  ['劫材', '11'],
#  ['对局者', '21'],
#  ['唐韋星', '8'],
#  ['方圓社', '39'],
#  ['棋鬼王', '11'],
#  ['定段赛', '8'],
#  ['轮于', '13'],
#  ['天元战', '11'],
#  ['本届', '9'],
#  ['循环圈', '8'],
#  ['預選', '7'],
#  ['齐鲁晚', '10'],
#  ['本身劫', '8'],
#  ['碁聖', '7'],
#  ['强败者', '8'],
#  ['deepmind', '10'],
#  ['御城棋', '11'],
#  ['杯冠军', '13'],
#  ['時代', '10'],
#  ['年道', '9'],
#  ['方胜', '14'],
#  ['廣島', '7'],
#  ['上届', '6'],
#  ['免选', '7'],
#  ['挑战者', '8'],
#  ['黑嘉嘉', '9'],
#  ['淡路修', '7'],
#  ['天台', '8'],
#  ['聂卫平', '6'],
#  ['任中', '9'],
#  ['山城宏', '9'],
#  ['等级分', '6'],
#  ['贴目', '6'],
#  ['臺北市', '6'],
#  ['岩本', '8'],
#  ['甘肃', '7'],
#  ['白昕卉', '11'],
#  ['張凱馨', '8'],
#  ['丈和', '23'],
#  ['晋级', '6'],
#  ['丹朱', '8'],
#  ['瀨越', '6'],
#  ['楊子', '7'],
#  ['因碩', '8'],
#  ['刘小光', '7'],
#  ['轮败者', '10'],
#  ['1轮', '8'],
#  ['区', '16'],
#  ['男子组', '8'],
#  ['劫爭', '13'],
#  ['韩元', '19'],
#  ['女子组', '9'],
#  ['小林觉', '9'],
#  ['擂台赛', '8'],
#  ['赛棋手', '6'],
#  ['黄河杯', '8'],
#  ['女子棋', '7'],
#  ['訓練', '6'],
#  ['楊子萱', '6'],
#  ['荒木氏', '6'],
#  ['擂台', '6'],
#  ['决赛第', '6'],
#  ['强败者获', '6'],
#  ['專案', '6'],
#  ['俘子', '6'],
#  ['柯潔', '6'],
#  ['分至', '6'],
#  ['本戰', '6'],
#  ['过惕生', '7'],
#  ['联棋', '11'],
#  ['橋本', '7'],
#  ['复赛', '9'],
#  ['圍棋界', '7'],
#  ['城围', '7'],
#  ['俞俐均', '10'],
#  ['届中', '6'],
#  ['通算', '12'],
#  ['codice', '6'],
#  ['聯', '9'],
#  ['朝日新', '7'],
#  ['绝艺', '6'],
#  ['天元', '7'],
#  ['王座', '6'],
#  ['邱峻', '7'],
#  ['灵杯', '8'],
#  ['棋圣', '13'],
#  ['女流名人', '6'],
#  ['黄龙士', '9'],
#  ['队获得', '7'],
#  ['謝依旻', '7'],
#  ['颗子', '12'],
#  ['挑戰者', '7'],
#  ['組織', '13'],
#  ['中環盃', '8'],
#  ['农心杯', '6'],
#  ['赵南哲', '7'],
#  ['新布石', '6'],
#  ['應昌', '6'],
#  ['玩家', '7'],
#  ['黑子', '8'],
#  ['外勢', '9'],
#  ['學習', '9'],
#  ['深入', '8'],
#  ['胜率', '9'],
#  ['收官', '6'],
#  ['位棋', '6'],
#  ['资格赛', '8'],
#  ['方棋子', '10'],
#  ['全国性', '9'],
#  ['白方', '6'],
#  ['际象棋', '9'],
#  ['李世乭', '7'],
#  ['年為', '8'],
#  ['人戰', '10'],
#  ['亚洲', '6'],
#  ['队和', '10'],
#  ['名誉', '7'],
#  ['打劫', '10'],
#  ['理光', '9'],
#  ['霸王', '7'],
#  ['飛刀', '9'],
#  ['得到', '8'],
#  ['聂卫', '10'],
#  ['正夫', '8'],
#  ['本选赛', '6'],
#  ['只棋子', '6'],
#  ['半决赛', '8'],
#  ['妖刀', '12'],
#  ['雙人', '7'],
#  ['家康', '7'],
#  ['网棋', '7'],
#  ['十一', '7'],
#  ['執白', '6'],
#  ['主将', '6'],
#  ['國流', '8'],
#  ['目外', '8'],
#  ['经过', '10'],
#  ['更具', '6'],
#  ['负', '9'],
#  ['中华台北', '8'],
#  ['腾讯', '10'],
#  ['李昌镐', '6'],
#  ['中盘', '8'],
#  ['頭銜者', '10'],
#  ['年代表', '6'],
#  ['王座戰', '9'],
#  ['棋聖', '8'],
#  ['南韓首爾', '6'],
#  ['碁聖戰', '6'],
#  ['國手', '9'],
#  ['混双赛', '6'],
#  ['江戶', '6'],
#  ['奖金为', '8'],
#  ['賽進行', '7'],
#  ['国女子', '6'],
#  ['決定戰', '7'],
#  ['網路圍', '6'],
#  ['金明训', '7'],
#  ['余棋手', '6'],
#  ['团体赛', '7'],
#  ['10万', '7'],
#  ['圍棋高', '6'],
#  ['朴志恩', '6'],
#  ['开局', '6'],
#  ['职业', '6'],
#  ['吴清源', '10'],
#  ['海峰', '7'],
#  ['级分', '8'],
#  ['衢州市', '6'],
#  ['王晨星', '8'],
#  ['段胜', '6'],
#  ['視台', '9'],
#  ['產生', '6'],
#  ['正式', '7'],
#  ['聖戰', '10'],
#  ['王戰', '11'],
#  ['排名', '7'],
#  ['賽制', '10'],
#  ['抽签', '6'],
#  ['金荣', '6'],
#  ['国手', '8'],
#  ['分先', '6'],
#  ['最強', '6'],
#  ['中方', '7'],
#  ['导致', '8'],
#  ['曾经', '7'],
#  ['担任', '6'],
#  ['9日', '7'],
#  ['當作', '6'],
#  ['豐田', '6'],
#  ['座戰', '6'],
#  ['屆本', '6'],
#  ['击败', '6'],
#  ['组合', '7'],
#  ['来自', '6'],
#  ['下棋', '6'],
#  ['武汉', '6'],
#  ['聯盟', '10'],
#  ['成绩', '8'],
#  ['引起', '6'],
#  ['只能', '6'],
#  ['负李', '6'],
#  ['年底', '7'],
#  ['下午', '9'],
#  ['單敗', '6'],
#  ['耀烨', '6'],
#  ['重庆', '8'],
#  ['項目', '12'],
#  ['手棋', '7'],
#  ['棋王赛', '7'],
#  ['禁止', '6'],
#  ['為日本', '7'],
#  ['歐洲', '11'],
#  ['黑龙江', '8'],
#  ['羋昱廷', '6'],
#  ['晏天章', '8'],
#  ['提子', '12'],
#  ['江苏', '6'],
#  ['混双', '8'],
#  ['白子', '6'],
#  ['棋經', '6'],
#  ['选手', '7'],
#  ['黄龙', '7'],
#  ['男棋手', '6'],
#  ['背景', '8'],
#  ['循环', '6'],
#  ['日', '9'],
#  ['国际象', '7'],
#  ['杯世界', '6'],
#  ['国参加', '6'],
#  ['獲勝者', '6'],
#  ['预选', '13'],
#  ['人類', '6'],
#  ['着法', '7'],
#  ['主办', '8'],
#  ['围棋赛', '8'],
#  ['申旻埈', '8'],
#  ['崔哲瀚', '9'],
#  ['连胜', '11'],
#  ['名人战', '7'],
#  ['亞軍', '9'],
#  ['步棋', '10'],
#  ['镇围棋', '6'],
#  ['个人', '6'],
#  ['组', '36'],
#  ['王积薪', '8'],
#  ['家家督', '6'],
#  ['目半', '8'],
#  ['為名人', '10'],
#  ['还棋头', '7'],
#  ['vs', '10'],
#  ['预选赛', '7'],
#  ['对局', '8'],
#  ['黃士', '9'],
#  ['推广', '9'],
#  ['挑战', '6'],
#  ['人以', '7'],
#  ['姜堰', '7'],
#  ['数据', '8'],
#  ['分析', '7'],
#  ['人围', '6'],
#  ['交流', '10'],
#  ['軟體', '6'],
#  ['方圓', '16'],
#  ['跡目', '8'],
#  ['年日本', '10'],
#  ['衢州', '6'],
#  ['亞藝盃', '6'],
#  ['其它', '11'],
#  ['网选', '8'],
#  ['负于', '8'],
#  ['勝制', '8'],
#  ['獲得', '8'],
#  ['此頭銜', '6'],
#  ['杯本赛', '6'],
#  ['名人賽', '11'],
#  ['关东', '6'],
#  ['團隊', '6'],
#  ['棋品', '6'],
#  ['道策', '9'],
#  ['则是', '6'],
#  ['弈秋', '8'],
#  ['複雜', '8'],
#  ['小飛', '7'],
#  ['透過', '9'],
#  ['杯围棋', '6'],
#  ['数学', '6'],
#  ['围棋最', '6'],
#  ['基金會', '8'],
#  ['中國圍', '6'],
#  ['对抗赛', '11'],
#  ['际围棋', '6'],
#  ['棋世界', '6'],
#  ['本棋院', '6'],
#  ['服务器', '6'],
#  ['国家队', '7'],
#  ['是围棋', '8'],
#  ['围棋网', '6'],
#  ['自我訓練', '7'],
#  ['淘汰赛', '6'],
#  ['棋院和', '6'],
#  ['内围棋', '6'],
#  ['重要性', '6'],
#  ['世本因', '6'],
#  ['个人赛', '8'],
#  ['為本因', '6'],
#  ['選拔賽', '8'],
#  ['段位的', '6'],
#  ['输给了', '6'],
#  ['市围棋', '6'],
#  ['刀定式', '7'],
#  ['组成的', '6'],
#  ['俱乐部', '6'],
#  ['被视为', '6'],
#  ['研究的', '7'],
#  ['將棋界', '6'],
#  ['赵晨宇', '6'],
#  ['被叫做', '6'],
#  ['电王战', '6'],
#  ['假眼活', '6'],
#  ['段以', '7'],
#  ['桐山杯', '11'],
#  ['方式', '7'],
#  ['之一', '31'],
#  ['体育', '9'],
#  ['名单', '13'],
#  ['位提白', '6'],
#  ['朴鋕恩', '6'],
#  ['方用时', '6'],
#  ['规则', '9'],
#  ['元战', '6'],
#  ['制度', '14'],
#  ['工智', '7'],
#  ['業圍', '6'],
#  ['因坊', '8'],
#  ['国棋', '7'],
#  ['之间', '6'],
#  ['氏杯', '8'],
#  ['国业', '10'],
#  ['酒店', '6'],
#  ['運算', '9'],
#  ['單位', '7'],
#  ['定式', '10'],
#  ['最高', '10'],
#  ['全國', '6'],
#  ['本学', '6'],
#  ['传说', '7'],
#  ['網站', '7'],
#  ['最佳', '7'],
#  ['实业', '6'],
#  ['国职', '7'],
#  ['院和', '6'],
#  ['南京', '6'],
#  ['高段', '7'],
#  ['支援', '6'],
#  ['政府', '7'],
#  ['同樣', '6'],
#  ['能力', '8'],
#  ['表团', '10'],
#  ['国流', '11'],
#  ['棋牌', '7'],
#  ['參數', '7'],
#  ['全部', '7'],
#  ['模仿', '6'],
#  ['团队', '6'],
#  ['三轮', '6'],
#  ['佔角', '6'],
#  ['對戰', '8'],
#  ['讀賣', '7'],
#  ['元老', '8'],
#  ['應用', '11'],
#  ['实际', '7'],
#  ['再次', '6'],
#  ['中学', '6'],
#  ['网上', '6'],
#  ['卫平', '12'],
#  ['則因', '6'],
#  ['中部', '7'],
#  ['顶尖', '8'],
#  ['系列', '6'],
#  ['原因', '6'],
#  ['国象', '8'],
#  ['这种', '9'],
#  ['邀请', '8'],
#  ['赛于', '18'],
#  ['计数', '7'],
#  ['九段', '7'],
#  ['設定', '8'],
#  ['各地', '7'],
#  ['為台', '6'],
#  ['李东勋', '6'],
#  ['预赛', '6'],
#  ['长期', '6'],
#  ['卡斯', '6'],
#  ['貼目', '8'],
#  ['比對', '6'],
#  ['真眼', '10'],
#  ['之莹', '6'],
#  ['工作', '8'],
#  ['富士', '6'],
#  ['通过', '12'],
#  ['執黑', '6'],
#  ['圣战', '9'],
#  ['大小', '6'],
#  ['读秒', '9'],
#  ['世代', '6'],
#  ['裁判', '6'],
#  ['程度', '6'],
#  ['卡尔', '6'],
#  ['台赛', '7'],
#  ['棋協', '6'],
#  ['日本圍', '7'],
#  ['12万', '6'],
#  ['实力', '7'],
#  ['安節', '9'],
#  ['陕西', '6'],
#  ['全运', '6'],
#  ['显著', '9'],
#  ['智能', '8'],
#  ['參考', '6'],
#  ['当时', '7'],
#  ['宣布', '8'],
#  ['网格', '8'],
#  ['坐标', '8'],
#  ['棋艺', '7'],
#  ['循環', '6'],
#  ['極其', '6'],
#  ['世襲', '6'],
#  ['達成', '8'],
#  ['日程', '6'],
#  ['每年', '9'],
#  ['東京', '6'],
#  ['专家', '9'],
#  ['规定', '6'],
#  ['方一', '6'],
#  ['本薰', '6'],
#  ['提升', '9'],
#  ['之子', '7'],
#  ['占据', '7'],
#  ['1月1日', '7'],
#  ['江维', '6'],
#  ['升降', '6'],
#  ['连续', '8'],
#  ['佛乘', '6'],
#  ['德川', '6'],
#  ['报名', '6'],
#  ['利益', '8'],
#  ['赛前', '6'],
#  ['连接', '6'],
#  ['先前', '6'],
#  ['东京', '6'],
#  ['创办', '11'],
#  ['手割', '6'],
#  ['打算', '6'],
#  ['實做', '7'],
#  ['可能', '10'],
#  ['变得', '10'],
#  ['歷史', '6'],
#  ['坊門', '6'],
#  ['利用', '6'],
#  ['十二', '6'],
#  ['台北', '6'],
#  ['成员', '6'],
#  ['消劫', '9'],
#  ['领域', '7'],
#  ['之父', '6'],
#  ['争夺', '6'],
#  ['2万', '7'],
#  ['得第', '6'],
#  ['开发', '13'],
#  ['佐為', '10'],
#  ['己方', '6'],
#  ['马晓春', '8'],
#  ['外卡', '6'],
#  ['後黑', '7'],
#  ['29日', '6'],
#  ['加以', '6'],
#  ['知得', '9'],
#  ['高校', '6'],
#  ['很多', '6'],
#  ['受到', '8'],
#  ['相鄰', '6'],
#  ['小组', '6'],
#  ['打入', '8'],
#  ['出场', '9'],
#  ['彼此', '8'],
#  ['分數', '6'],
#  ['停止', '6'],
#  ['胜出', '8'],
#  ['局', '8'],
#  ['为', '9'],
#  ['距離', '7'],
#  ['挑战赛', '9'],
#  ['点', '6'],
#  ['李小溪', '6'],
#  ['周俊勳', '7'],
#  ['月', '7'],
#  ['3日', '6'],
#  ['6日', '8'],
#  ['将于', '6'],
#  ['聞社', '7'],
#  ['創立', '7'],
#  ['4日', '6'],
#  ['定石', '6'],
#  ['下到', '6'],
#  ['棋以', '6'],
#  ['釋出', '8'],
#  ['赛制', '10'],
#  ['种子', '7'],
#  ['香港', '6'],
#  ['腾讯野', '6'],
#  ['思考', '6'],
#  ['小時', '8'],
#  ['单败淘', '6'],
#  ['放送', '6'],
#  ['获胜者', '7'],
#  ['复杂性', '10'],
#  ['同时', '8'],
#  ['互相', '8'],
#  ['方各', '6'],
#  ['职业棋手', '7'],
#  ['棋戰', '7'],
#  ['人数', '7'],
#  ['技巧', '8'],
#  ['附近', '7'],
#  ['則是', '6'],
#  ['女流', '6'],
#  ['际象', '6'],
#  ['平面', '6'],
#  ['这样', '8'],
#  ['直线', '6'],
#  ['阶段', '6'],
#  ['虽然', '7'],
#  ['夺得', '6'],
#  ['名棋手', '7'],
#  ['意思', '7'],
#  ['包圍', '9'],
#  ['段位制', '10'],
#  ['超過', '6'],
#  ['改稱', '6'],
#  ['正官庄杯', '7'],
#  ['世纪', '9'],
#  ['圍棋賽', '7'],
#  ['强战', '6'],
#  ['樊麾', '11'],
#  ['必須', '6'],
#  ['formula', '6'],
#  ['范西屏', '7'],
#  ['国手战', '6'],
#  ['互联网', '9'],
#  ['扇興杯', '6'],
#  ['名人戰', '6'],
#  ['对围棋', '6'],
#  ['豐田杯', '6'],
#  ['通常', '9'],
#  ['舉辦', '9'],
#  ['主要', '8'],
#  ['手合', '7'],
#  ['国棋手', '7'],
#  ['周俊', '7'],
#  ['真露杯', '7'],
#  ['中環', '7'],
#  ['数子', '9'],
#  ['得天元', '6'],
#  ['赞助商', '6'],
#  ['3月4日', '6'],
#  ['周俊勋', '7'],
#  ['數子法', '6'],
#  ['杭州', '8'],
#  ['世乭', '6'],
#  ['資料', '6'],
#  ['棋赛', '6'],
#  ['工程', '6'],
#  ['淘汰', '6'],
#  ['棋賽', '8'],
#  ['赛事', '10'],
#  ['广州', '9'],
#  ['對弈中', '7'],
#  ['厚勢', '10'],
#  ['安排', '8'],
#  ['生涯', '7'],
#  ['2轮', '8'],
#  ['宇宙流', '7'],
#  ['上海', '6'],
#  ['对于', '9'],
#  ['胜负', '8'],
#  ['名将', '7'],
#  ['专业', '6'],
#  ['快棋', '6'],
#  ['获得', '6'],
#  ['存在', '6'],
#  ['立於', '6'],
#  ['举办的', '6'],
#  ['年間', '7'],
#  ['年年', '6'],
#  ['山东', '6'],
#  ['方可', '7'],
#  ['元和', '7'],
#  ['辜梓豪', '9'],
#  ['同名', '6'],
#  ['罗玄', '7'],
#  ['方捷', '7'],
#  ['淘汰賽', '9'],
#  ['局棋', '6'],
#  ['陈浩', '9'],
#  ['男子', '7'],
#  ['结果', '6'],
#  ['位', '6'],
#  ['丁烈', '6'],
#  ['運用', '11'],
#  ['围棋名人战', '6'],
#  ['林海峰', '7'],
#  ['贊助', '10'],
#  ['人机', '6'],
#  ['世界第', '7'],
#  ['加藤', '6'],
#  ['日和', '6'],
#  ['年獲', '6'],
#  ['选拔', '6'],
#  ['讀賣新聞', '6'],
#  ['職業圍棋', '7'],
#  ['小林光', '17'],
#  ['年日', '9'],
#  ['計算', '6'],
#  ['日围棋', '6'],
#  ['围棋大', '6'],
#  ['对弈', '12'],
#  ['錦標賽', '6'],
#  ['丁明君', '6'],
#  ['赛冠军', '14'],
#  ['伺服器', '6'],
#  ['届比', '7'],
#  ['综合', '9'],
#  ['業棋士', '7'],
#  ['国务', '7'],
#  ['为围棋', '6'],
#  ['张馨月', '6'],
#  ['女子围', '7'],
#  ['年度', '9'],
#  ['无锡市', '6'],
#  ['程式碼', '7'],
#  ['顾水如', '6'],
#  ['出线', '12'],
#  ['棋水平', '6'],
#  ['公開賽', '8'],
#  ['年取', '6'],
#  ['數子', '6'],
#  ['本赛第', '7'],
#  ['分散式', '6'],
#  ['指围棋', '7'],
#  ['围棋队', '8'],
#  ['网络', '9'],
#  ['對弈', '8'],
#  ['国规则', '6'],
#  ['為台灣', '8'],
#  ['使用者', '6'],
#  ['关西', '10'],
#  ['目的', '10'],
#  ['改名為', '7'],
#  ['優勝者', '7'],
#  ['為了', '9'],
#  ['版本', '7'],
#  ['团体', '6'],
#  ['段位', '7'],
#  ['周睿', '13'],
#  ['决赛中', '6'],
#  ['落子', '8'],
#  ['資源', '7'],
#  ['程式', '6'],
#  ['电视', '6'],
#  ['弟子', '11'],
#  ['為圍棋', '6'],
#  ['小光', '19'],
#  ['抗賽', '6'],
#  ['家督', '6'],
#  ['白棋', '6'],
#  ['券杯', '7'],
#  ['實利', '6'],
#  ['晚报', '6'],
#  ['安井', '6'],
#  ['秀和', '14'],
#  ['限公', '8'],
#  ['名譽', '7'],
#  ['發行', '9'],
#  ['挑戰', '7'],
#  ['蒙地', '8'],
#  ['新布局', '6'],
#  ['大赛', '6'],
#  ['武宮', '7'],
#  ['报道', '6'],
#  ['直播', '9'],
#  ['獲勝', '7'],
#  ['和韩', '7'],
#  ['協會', '6'],
#  ['團體', '6'],
#  ['采取', '6'],
#  ['中日', '10'],
#  ['才能', '11'],
#  ['守角', '9'],
#  ['现代', '6'],
#  ['浙江', '9'],
#  ['之間', '10'],
#  ['赛区', '10'],
#  ['已經', '6'],
#  ['造成', '7'],
#  ['例子', '6'],
#  ['当今', '6'],
#  ['高目', '7'],
#  ['棋圣战', '9'],
#  ['日本队', '6'],
#  ['郭闻潮', '6'],
#  ['方先', '7'],
#  ['小时', '7'],
#  ['棋坛', '6'],
#  ['策略', '6'],
#  ['曹薰', '6'],
#  ['本身', '6'],
#  ['男女', '6'],
#  ['星位', '7'],
#  ['丁浩', '7'],
#  ['全国', '8'],
#  ['征子', '6'],
#  ['原子', '6'],
#  ['发生', '8'],
#  ['整個', '7'],
#  ['參加', '9'],
#  ['目數', '7'],
#  ['個黑', '6'],
#  ['秀策', '6'],
#  ['方用', '6'],
#  ['弈城', '7'],
#  ['棋盘', '17'],
#  ['首次', '9'],
#  ['长考', '7'],
#  ['秀行', '6'],
#  ['风格', '6'],
#  ['電腦圍', '8'],
#  ['亚军', '7'],
#  ['业围', '7'],
#  ['比目法', '11'],
#  ['日本的', '6'],
#  ['9x9', '8'],
#  ['类似', '9'],
#  ['三三', '7'],
#  ['手数', '6'],
#  ['連接', '6'],
#  ['官方', '6'],
#  ['繼承', '7'],
#  ['作戰', '6'],
#  ['国棋院', '10'],
#  ['黑方', '7'],
#  ['業餘', '6'],
#  ['個角', '7'],
#  ['许嘉阳', '6'],
#  ['分為', '6'],
#  ['王世', '6'],
#  ['國內', '8'],
#  ['崔精', '8'],
#  ['国围', '6'],
#  ['機會', '7'],
#  ['陳耀燁', '7'],
#  ['職業棋', '6'],
#  ['职业围棋', '7'],
#  ['范胤', '6'],
#  ['世界最', '6'],
#  ['芮乃伟', '7'],
#  ['官子', '6'],
#  ['李昌鎬', '8'],
#  ['演算法', '8'],
#  ['朴文垚', '7'],
#  ['浙江省', '8'],
#  ['屆起', '11'],
#  ['阿含', '9'],
#  ['決賽', '9'],
#  ['按照', '11'],
#  ['少年', '6'],
#  ['赵治勋', '6'],
#  ['本年度', '6'],
#  ['终局', '6'],
#  ['決定', '6'],
#  ['情況下', '6'],
#  ['棋局', '7'],
#  ['情况', '10'],
#  ['處理', '7'],
#  ['全局', '7'],
#  ['执黑', '8'],
#  ['林家', '7'],
#  ['交叉', '7'],
#  ['擊敗', '11'],
#  ['變成', '6'],
#  ['木谷', '6'],
#  ['强赛', '7'],
#  ['戰鬥', '7'],
#  ['任何', '8'],
#  ['內容', '6'],
#  ['日本棋院', '6'],
#  ['日至', '6'],
#  ['國際', '6'],
#  ['广西', '6'],
#  ['曹大元', '6'],
#  ['應對', '7'],
#  ['尤其', '6'],
#  ['整个', '10'],
#  ['职业棋', '8'],
#  ['国内', '6'],
#  ['改名', '6'],
#  ['發生', '7'],
#  ['叫吃', '10'],
#  ['冠亚军', '6'],
#  ['全日本', '7'],
#  ['織田', '6'],
#  ['藤泽', '8'],
#  ['广东', '6'],
#  ['海峰棋院', '10'],
#  ['三子', '8'],
#  ['局面', '9'],
#  ['重要', '7'],
#  ['年围', '6'],
#  ['西洋棋', '6'],
#  ['棋聖戰', '7'],
#  ['富士通杯', '8'],
#  ['非常', '8'],
#  ['董彦', '9'],
#  ['對手', '6'],
#  ['選手', '8'],
#  ['韓國棋院', '6'],
#  ['帳號', '7'],
#  ['以後', '6'],
#  ['公开', '6'],
#  ['圍棋棋', '8'],
#  ['棋协会', '6'],
#  ['關西棋院', '7'],
#  ['職業圍', '6'],
#  ['种子选', '6'],
#  ['中盤', '10'],
#  ['队以', '6'],
#  ['中日韩', '6'],
#  ['杭州市', '6'],
#  ['推出', '7'],
#  ['等级', '8'],
#  ['將棋', '8'],
#  ['變化', '6'],
#  ['棋具', '7'],
#  ['棋協會', '8'],
#  ['陈祖德', '13'],
#  ['年因', '6'],
#  ['严欢', '6'],
#  ['位置', '8'],
#  ['江铸久', '8'],
#  ['联合', '10'],
#  ['为世界', '7'],
#  ['对局费', '7'],
#  ['围棋规则', '6'],
#  ['执白', '7'],
#  ['李康', '6'],
#  ['結果', '7'],
#  ['活棋', '6'],
#  ['决赛', '12'],
#  ['胡耀宇', '6'],
#  ['國際賽', '6'],
#  ['了围棋', '6'],
#  ['應氏', '7'],
#  ['三段', '6'],
#  ['這種', '7'],
#  ['番棋', '6'],
#  ['赞助', '15'],
#  ['传统', '6'],
#  ['影响', '9'],
#  ['城市', '6'],
#  ['国家体', '6'],
#  ['掛角', '7'],
#  ['秀哉', '6'],
#  ['奖金', '7'],
#  ['特定', '6'],
#  ['局部', '6'],
#  ['年舉', '7'],
#  ['棋战', '7'],
#  ['古灵益', '6'],
#  ['階段', '8'],
#  ['年台', '6'],
#  ['達到', '10'],
#  ['地區', '6'],
#  ['自己的', '8'],
#  ['比赛中', '10'],
#  ['为围', '6'],
#  ['实战', '7'],
#  ['兒子', '6'],
#  ['停辦', '13'],
#  ['比賽中', '7'],
#  ['算砂', '6'],
#  ['秀甫', '6'],
#  ['李喆', '6'],
#  ['公開', '6'],
#  ['公司', '7'],
#  ['黑貼', '7'],
#  ['大飛', '8'],
#  ['张璇', '7'],
#  ['本局', '6'],
#  ['依照', '6'],
#  ['職業棋手', '7'],
#  ['技术', '10'],
#  ['初段', '11'],
#  ['读秒的', '6'],
#  ['類似', '6'],
#  ['中国', '14'],
#  ['发展', '8'],
#  ['日本围', '7'],
#  ['李世石', '9'],
#  ['云南', '6'],
#  ['安冬旭', '6'],
#  ['奧林匹亞', '6'],
#  ['安井家', '6'],
#  ['韩国', '9'],
#  ['形態', '6'],
#  ['年改', '7'],
#  ['年共', '6'],
#  ['象棋', '6'],
#  ['多数', '8'],
#  ['大学', '7'],
#  ['北京', '7'],
#  ['成為', '10'],
#  ['分鐘', '12'],
#  ['某些', '7'],
#  ['棋手在', '6'],
#  ['周泓余', '6'],
#  ['范廷鈺', '7'],
#  ['是日本', '7'],
#  ['重視', '6'],
#  ['勝率', '6'],
#  ['頭銜', '9'],
#  ['台灣圍棋', '8'],
#  ['届应', '6'],
#  ['参赛', '13'],
#  ['柁嘉熹', '6'],
#  ['年以', '6'],
#  ['年代', '11'],
#  ['佟禹林', '6'],
#  ['是台灣', '8'],
#  ['黑白', '7'],
#  ['時候', '6'],
#  ['金志锡', '6'],
#  ['然而', '8'],
#  ['保留', '10'],
#  ['是圍棋', '6'],
#  ['實力', '9'],
#  ['此時', '8'],
#  ['連勝', '6'],
#  ['人民', '6'],
#  ['關西', '6'],
#  ['成績', '6'],
#  ['職業棋士', '7'],
#  ['網路', '9'],
#  ['黑棋', '13'],
#  ['孔杰', '6'],
#  ['宋容慧', '8'],
#  ['出現', '6'],
#  ['要求', '7'],
#  ['围棋协会', '6'],
#  ['或者', '9'],
#  ['圍棋協', '6'],
#  ['棋形', '17'],
#  ['雖然', '6'],
#  ['遊戲', '6'],
#  ['睦镇硕', '6'],
#  ['抗赛', '7'],
#  ['三番棋', '8'],
#  ['先手', '11'],
#  ['是由', '6'],
#  ['野狐', '7'],
#  ['特殊', '6'],
#  ['蔡竞', '6'],
#  ['首轮', '11'],
#  ['進入', '6'],
#  ['丁伟', '6'],
#  ['日文', '7'],
#  ['模樣', '13'],
#  ['後因', '7'],
#  ['段和', '6'],
#  ['選擇', '7'],
#  ['木谷實', '7'],
#  ['讓子', '8'],
#  ['彭荃', '6'],
#  ['價值', '6'],
#  ['年舉辦', '7'],
#  ['王磊', '6'],
#  ['当时中', '7'],
#  ['届起', '7'],
#  ['国队', '9'],
#  ['职业围', '6'],
#  ['常昊', '7'],
#  ['唐奕', '8'],
#  ['坂田', '7'],
#  ['研究', '6'],
#  ['本賽', '6'],
#  ...]

# %%
import jieba.posseg as pseg

def grade_term(lst):
    anotherlst=[]
    for i in range(len(lst)):
        score=0
        sentence=pseg.cut(lst[i][0])
        for w in sentence:
            if w.flag in ['n','nz','nt','nr','ns','nw']:
                score+=1
        anotherlst.append(score)
    newlst=[]
    for  i in range(len(anotherlst)):
        newlst.append([lst[i][0],int(lst[i][-1])+int(lst[i][-1])*anotherlst[i]])
    return newlst
lst=grade_term(lst)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/5w/cbkbcc4x09q85s79vbdnh2vc0000gn/T/jieba.cache
# Loading model cost 1.004 seconds.
# Prefix dict has been built successfully.

# %%
lst
# Out:
# [['定段', 28],
#  ['江流儿', 90],
#  ['雷凌云', 63],
#  ['云子', 52],
#  ['雙人圍', 24],
#  ['江流', 56],
#  ['劫材', 22],
#  ['对局者', 42],
#  ['唐韋星', 16],
#  ['方圓社', 117],
#  ['棋鬼王', 33],
#  ['定段赛', 16],
#  ['轮于', 13],
#  ['天元战', 22],
#  ['本届', 9],
#  ['循环圈', 8],
#  ['預選', 7],
#  ['齐鲁晚', 20],
#  ['本身劫', 8],
#  ['碁聖', 7],
#  ['强败者', 16],
#  ['deepmind', 10],
#  ['御城棋', 33],
#  ['杯冠军', 26],
#  ['時代', 20],
#  ['年道', 9],
#  ['方胜', 28],
#  ['廣島', 14],
#  ['上届', 6],
#  ['免选', 7],
#  ['挑战者', 16],
#  ['黑嘉嘉', 18],
#  ['淡路修', 14],
#  ['天台', 16],
#  ['聂卫平', 12],
#  ['任中', 9],
#  ['山城宏', 27],
#  ['等级分', 6],
#  ['贴目', 12],
#  ['臺北市', 12],
#  ['岩本', 16],
#  ['甘肃', 14],
#  ['白昕卉', 22],
#  ['張凱馨', 16],
#  ['丈和', 23],
#  ['晋级', 12],
#  ['丹朱', 16],
#  ['瀨越', 12],
#  ['楊子', 14],
#  ['因碩', 16],
#  ['刘小光', 14],
#  ['轮败者', 20],
#  ['1轮', 16],
#  ['区', 32],
#  ['男子组', 16],
#  ['劫爭', 13],
#  ['韩元', 38],
#  ['女子组', 18],
#  ['小林觉', 18],
#  ['擂台赛', 16],
#  ['赛棋手', 18],
#  ['黄河杯', 16],
#  ['女子棋', 21],
#  ['訓練', 6],
#  ['楊子萱', 18],
#  ['荒木氏', 12],
#  ['擂台', 6],
#  ['决赛第', 12],
#  ['强败者获', 12],
#  ['專案', 12],
#  ['俘子', 12],
#  ['柯潔', 12],
#  ['分至', 6],
#  ['本戰', 12],
#  ['过惕生', 7],
#  ['联棋', 11],
#  ['橋本', 14],
#  ['复赛', 9],
#  ['圍棋界', 14],
#  ['城围', 14],
#  ['俞俐均', 20],
#  ['届中', 6],
#  ['通算', 12],
#  ['codice', 6],
#  ['聯', 9],
#  ['朝日新', 14],
#  ['绝艺', 12],
#  ['天元', 7],
#  ['王座', 12],
#  ['邱峻', 14],
#  ['灵杯', 16],
#  ['棋圣', 26],
#  ['女流名人', 18],
#  ['黄龙士', 27],
#  ['队获得', 14],
#  ['謝依旻', 7],
#  ['颗子', 24],
#  ['挑戰者', 14],
#  ['組織', 13],
#  ['中環盃', 8],
#  ['农心杯', 12],
#  ['赵南哲', 14],
#  ['新布石', 12],
#  ['應昌', 12],
#  ['玩家', 14],
#  ['黑子', 16],
#  ['外勢', 18],
#  ['學習', 9],
#  ['深入', 8],
#  ['胜率', 18],
#  ['收官', 12],
#  ['位棋', 12],
#  ['资格赛', 16],
#  ['方棋子', 30],
#  ['全国性', 18],
#  ['白方', 12],
#  ['际象棋', 9],
#  ['李世乭', 14],
#  ['年為', 8],
#  ['人戰', 20],
#  ['亚洲', 12],
#  ['队和', 20],
#  ['名誉', 14],
#  ['打劫', 10],
#  ['理光', 18],
#  ['霸王', 14],
#  ['飛刀', 18],
#  ['得到', 8],
#  ['聂卫', 20],
#  ['正夫', 16],
#  ['本选赛', 6],
#  ['只棋子', 12],
#  ['半决赛', 16],
#  ['妖刀', 24],
#  ['雙人', 14],
#  ['家康', 14],
#  ['网棋', 14],
#  ['十一', 7],
#  ['執白', 6],
#  ['主将', 12],
#  ['國流', 16],
#  ['目外', 8],
#  ['经过', 10],
#  ['更具', 6],
#  ['负', 9],
#  ['中华台北', 24],
#  ['腾讯', 20],
#  ['李昌镐', 12],
#  ['中盘', 16],
#  ['頭銜者', 20],
#  ['年代表', 12],
#  ['王座戰', 18],
#  ['棋聖', 16],
#  ['南韓首爾', 12],
#  ['碁聖戰', 6],
#  ['國手', 18],
#  ['混双赛', 12],
#  ['江戶', 12],
#  ['奖金为', 16],
#  ['賽進行', 7],
#  ['国女子', 18],
#  ['決定戰', 14],
#  ['網路圍', 12],
#  ['金明训', 14],
#  ['余棋手', 12],
#  ['团体赛', 14],
#  ['10万', 7],
#  ['圍棋高', 6],
#  ['朴志恩', 12],
#  ['开局', 12],
#  ['职业', 12],
#  ['吴清源', 20],
#  ['海峰', 14],
#  ['级分', 16],
#  ['衢州市', 12],
#  ['王晨星', 24],
#  ['段胜', 12],
#  ['視台', 18],
#  ['產生', 12],
#  ['正式', 7],
#  ['聖戰', 20],
#  ['王戰', 33],
#  ['排名', 7],
#  ['賽制', 20],
#  ['抽签', 6],
#  ['金荣', 12],
#  ['国手', 16],
#  ['分先', 6],
#  ['最強', 6],
#  ['中方', 7],
#  ['导致', 8],
#  ['曾经', 7],
#  ['担任', 6],
#  ['9日', 7],
#  ['當作', 12],
#  ['豐田', 12],
#  ['座戰', 12],
#  ['屆本', 6],
#  ['击败', 6],
#  ['组合', 7],
#  ['来自', 6],
#  ['下棋', 6],
#  ['武汉', 12],
#  ['聯盟', 20],
#  ['成绩', 16],
#  ['引起', 6],
#  ['只能', 6],
#  ['负李', 12],
#  ['年底', 7],
#  ['下午', 9],
#  ['單敗', 12],
#  ['耀烨', 12],
#  ['重庆', 16],
#  ['項目', 24],
#  ['手棋', 14],
#  ['棋王赛', 14],
#  ['禁止', 6],
#  ['為日本', 14],
#  ['歐洲', 22],
#  ['黑龙江', 16],
#  ['羋昱廷', 6],
#  ['晏天章', 16],
#  ['提子', 24],
#  ['江苏', 12],
#  ['混双', 8],
#  ['白子', 12],
#  ['棋經', 12],
#  ['选手', 7],
#  ['黄龙', 14],
#  ['男棋手', 18],
#  ['背景', 16],
#  ['循环', 6],
#  ['日', 9],
#  ['国际象', 21],
#  ['杯世界', 12],
#  ['国参加', 12],
#  ['獲勝者', 6],
#  ['预选', 13],
#  ['人類', 12],
#  ['着法', 7],
#  ['主办', 8],
#  ['围棋赛', 16],
#  ['申旻埈', 8],
#  ['崔哲瀚', 18],
#  ['连胜', 22],
#  ['名人战', 14],
#  ['亞軍', 18],
#  ['步棋', 20],
#  ['镇围棋', 12],
#  ['个人', 12],
#  ['组', 36],
#  ['王积薪', 16],
#  ['家家督', 12],
#  ['目半', 8],
#  ['為名人', 20],
#  ['还棋头', 14],
#  ['vs', 10],
#  ['预选赛', 14],
#  ['对局', 16],
#  ['黃士', 18],
#  ['推广', 9],
#  ['挑战', 6],
#  ['人以', 14],
#  ['姜堰', 14],
#  ['数据', 16],
#  ['分析', 7],
#  ['人围', 12],
#  ['交流', 20],
#  ['軟體', 12],
#  ['方圓', 32],
#  ['跡目', 16],
#  ['年日本', 20],
#  ['衢州', 12],
#  ['亞藝盃', 6],
#  ['其它', 11],
#  ['网选', 16],
#  ['负于', 8],
#  ['勝制', 8],
#  ['獲得', 8],
#  ['此頭銜', 12],
#  ['杯本赛', 12],
#  ['名人賽', 22],
#  ['关东', 12],
#  ['團隊', 12],
#  ['棋品', 12],
#  ['道策', 18],
#  ['则是', 6],
#  ['弈秋', 16],
#  ['複雜', 8],
#  ['小飛', 14],
#  ['透過', 9],
#  ['杯围棋', 6],
#  ['数学', 12],
#  ['围棋最', 6],
#  ['基金會', 16],
#  ['中國圍', 12],
#  ['对抗赛', 22],
#  ['际围棋', 6],
#  ['棋世界', 18],
#  ['本棋院', 12],
#  ['服务器', 12],
#  ['国家队', 14],
#  ['是围棋', 8],
#  ['围棋网', 6],
#  ['自我訓練', 7],
#  ['淘汰赛', 12],
#  ['棋院和', 12],
#  ['内围棋', 12],
#  ['重要性', 12],
#  ['世本因', 12],
#  ['个人赛', 16],
#  ['為本因', 6],
#  ['選拔賽', 16],
#  ['段位的', 12],
#  ['输给了', 6],
#  ['市围棋', 12],
#  ['刀定式', 21],
#  ['组成的', 6],
#  ['俱乐部', 12],
#  ['被视为', 6],
#  ['研究的', 7],
#  ['將棋界', 12],
#  ['赵晨宇', 12],
#  ['被叫做', 6],
#  ['电王战', 18],
#  ['假眼活', 12],
#  ['段以', 7],
#  ['桐山杯', 33],
#  ['方式', 14],
#  ['之一', 31],
#  ['体育', 9],
#  ['名单', 26],
#  ['位提白', 6],
#  ['朴鋕恩', 18],
#  ['方用时', 18],
#  ['规则', 18],
#  ['元战', 12],
#  ['制度', 28],
#  ['工智', 14],
#  ['業圍', 12],
#  ['因坊', 16],
#  ['国棋', 14],
#  ['之间', 6],
#  ['氏杯', 16],
#  ['国业', 20],
#  ['酒店', 12],
#  ['運算', 9],
#  ['單位', 14],
#  ['定式', 20],
#  ['最高', 10],
#  ['全國', 12],
#  ['本学', 12],
#  ['传说', 14],
#  ['網站', 14],
#  ['最佳', 7],
#  ['实业', 12],
#  ['国职', 14],
#  ['院和', 12],
#  ['南京', 12],
#  ['高段', 7],
#  ['支援', 6],
#  ['政府', 14],
#  ['同樣', 6],
#  ['能力', 16],
#  ['表团', 20],
#  ['国流', 22],
#  ['棋牌', 14],
#  ['參數', 14],
#  ['全部', 14],
#  ['模仿', 6],
#  ['团队', 12],
#  ['三轮', 6],
#  ['佔角', 12],
#  ['對戰', 16],
#  ['讀賣', 7],
#  ['元老', 16],
#  ['應用', 11],
#  ['实际', 14],
#  ['再次', 6],
#  ['中学', 12],
#  ['网上', 6],
#  ['卫平', 24],
#  ['則因', 6],
#  ['中部', 7],
#  ['顶尖', 16],
#  ['系列', 6],
#  ['原因', 12],
#  ['国象', 16],
#  ['这种', 9],
#  ['邀请', 8],
#  ['赛于', 18],
#  ['计数', 14],
#  ['九段', 7],
#  ['設定', 8],
#  ['各地', 7],
#  ['為台', 12],
#  ['李东勋', 12],
#  ['预赛', 6],
#  ['长期', 6],
#  ['卡斯', 6],
#  ['貼目', 16],
#  ['比對', 6],
#  ['真眼', 10],
#  ['之莹', 12],
#  ['工作', 8],
#  ['富士', 12],
#  ['通过', 12],
#  ['執黑', 6],
#  ['圣战', 18],
#  ['大小', 6],
#  ['读秒', 18],
#  ['世代', 6],
#  ['裁判', 6],
#  ['程度', 12],
#  ['卡尔', 6],
#  ['台赛', 14],
#  ['棋協', 18],
#  ['日本圍', 14],
#  ['12万', 6],
#  ['实力', 14],
#  ['安節', 18],
#  ['陕西', 12],
#  ['全运', 12],
#  ['显著', 9],
#  ['智能', 16],
#  ['參考', 6],
#  ['当时', 7],
#  ['宣布', 8],
#  ['网格', 16],
#  ['坐标', 8],
#  ['棋艺', 14],
#  ['循環', 6],
#  ['極其', 6],
#  ['世襲', 6],
#  ['達成', 8],
#  ['日程', 12],
#  ['每年', 9],
#  ['東京', 12],
#  ['专家', 18],
#  ['规定', 12],
#  ['方一', 12],
#  ['本薰', 6],
#  ['提升', 9],
#  ['之子', 7],
#  ['占据', 7],
#  ['1月1日', 7],
#  ['江维', 12],
#  ['升降', 6],
#  ['连续', 8],
#  ['佛乘', 12],
#  ['德川', 12],
#  ['报名', 6],
#  ['利益', 16],
#  ['赛前', 6],
#  ['连接', 6],
#  ['先前', 6],
#  ['东京', 12],
#  ['创办', 11],
#  ['手割', 6],
#  ['打算', 6],
#  ['實做', 7],
#  ['可能', 10],
#  ['变得', 10],
#  ['歷史', 12],
#  ['坊門', 12],
#  ['利用', 12],
#  ['十二', 6],
#  ['台北', 12],
#  ['成员', 12],
#  ['消劫', 9],
#  ['领域', 14],
#  ['之父', 12],
#  ['争夺', 6],
#  ['2万', 7],
#  ['得第', 6],
#  ['开发', 13],
#  ['佐為', 10],
#  ['己方', 12],
#  ['马晓春', 16],
#  ['外卡', 12],
#  ['後黑', 14],
#  ['29日', 6],
#  ['加以', 6],
#  ['知得', 9],
#  ['高校', 12],
#  ['很多', 6],
#  ['受到', 8],
#  ['相鄰', 6],
#  ['小组', 12],
#  ['打入', 8],
#  ['出场', 18],
#  ['彼此', 8],
#  ['分數', 12],
#  ['停止', 6],
#  ['胜出', 8],
#  ['局', 16],
#  ['为', 9],
#  ['距離', 14],
#  ['挑战赛', 18],
#  ['点', 6],
#  ['李小溪', 18],
#  ['周俊勳', 14],
#  ['月', 7],
#  ['3日', 6],
#  ['6日', 8],
#  ['将于', 6],
#  ['聞社', 7],
#  ['創立', 7],
#  ['4日', 6],
#  ['定石', 12],
#  ['下到', 6],
#  ['棋以', 12],
#  ['釋出', 8],
#  ['赛制', 20],
#  ['种子', 14],
#  ['香港', 12],
#  ['腾讯野', 18],
#  ['思考', 6],
#  ['小時', 8],
#  ['单败淘', 12],
#  ['放送', 6],
#  ['获胜者', 14],
#  ['复杂性', 20],
#  ['同时', 8],
#  ['互相', 8],
#  ['方各', 6],
#  ['职业棋手', 21],
#  ['棋戰', 14],
#  ['人数', 14],
#  ['技巧', 16],
#  ['附近', 7],
#  ['則是', 6],
#  ['女流', 12],
#  ['际象', 12],
#  ['平面', 12],
#  ['这样', 8],
#  ['直线', 12],
#  ['阶段', 12],
#  ['虽然', 7],
#  ['夺得', 6],
#  ['名棋手', 14],
#  ['意思', 14],
#  ['包圍', 9],
#  ['段位制', 20],
#  ['超過', 6],
#  ['改稱', 6],
#  ['正官庄杯', 21],
#  ['世纪', 18],
#  ['圍棋賽', 14],
#  ['强战', 6],
#  ['樊麾', 33],
#  ['必須', 6],
#  ['formula', 6],
#  ['范西屏', 14],
#  ['国手战', 18],
#  ['互联网', 18],
#  ['扇興杯', 12],
#  ['名人戰', 12],
#  ['对围棋', 6],
#  ['豐田杯', 12],
#  ['通常', 9],
#  ['舉辦', 9],
#  ['主要', 8],
#  ['手合', 14],
#  ['国棋手', 21],
#  ['周俊', 14],
#  ['真露杯', 7],
#  ['中環', 14],
#  ['数子', 18],
#  ['得天元', 6],
#  ['赞助商', 6],
#  ['3月4日', 6],
#  ['周俊勋', 14],
#  ['數子法', 18],
#  ['杭州', 16],
#  ['世乭', 6],
#  ['資料', 12],
#  ['棋赛', 12],
#  ['工程', 12],
#  ['淘汰', 6],
#  ['棋賽', 16],
#  ['赛事', 20],
#  ['广州', 18],
#  ['對弈中', 7],
#  ['厚勢', 20],
#  ['安排', 8],
#  ['生涯', 14],
#  ['2轮', 16],
#  ['宇宙流', 21],
#  ['上海', 12],
#  ['对于', 9],
#  ['胜负', 8],
#  ['名将', 14],
#  ['专业', 12],
#  ['快棋', 12],
#  ['获得', 6],
#  ['存在', 6],
#  ['立於', 12],
#  ['举办的', 6],
#  ['年間', 7],
#  ['年年', 6],
#  ['山东', 12],
#  ['方可', 14],
#  ['元和', 7],
#  ['辜梓豪', 18],
#  ['同名', 12],
#  ['罗玄', 14],
#  ['方捷', 14],
#  ['淘汰賽', 9],
#  ['局棋', 12],
#  ['陈浩', 18],
#  ['男子', 14],
#  ['结果', 12],
#  ['位', 6],
#  ['丁烈', 12],
#  ['運用', 11],
#  ['围棋名人战', 12],
#  ['林海峰', 14],
#  ['贊助', 10],
#  ['人机', 12],
#  ['世界第', 14],
#  ['加藤', 12],
#  ['日和', 6],
#  ['年獲', 6],
#  ['选拔', 6],
#  ['讀賣新聞', 12],
#  ['職業圍棋', 14],
#  ['小林光', 51],
#  ['年日', 9],
#  ['計算', 6],
#  ['日围棋', 6],
#  ['围棋大', 6],
#  ['对弈', 12],
#  ['錦標賽', 12],
#  ['丁明君', 12],
#  ['赛冠军', 42],
#  ['伺服器', 12],
#  ['届比', 7],
#  ['综合', 9],
#  ['業棋士', 14],
#  ['国务', 14],
#  ['为围棋', 6],
#  ['张馨月', 12],
#  ['女子围', 14],
#  ['年度', 18],
#  ['无锡市', 12],
#  ['程式碼', 14],
#  ['顾水如', 12],
#  ['出线', 24],
#  ['棋水平', 18],
#  ['公開賽', 16],
#  ['年取', 6],
#  ['數子', 12],
#  ['本赛第', 14],
#  ['分散式', 12],
#  ['指围棋', 14],
#  ['围棋队', 16],
#  ['网络', 18],
#  ['對弈', 8],
#  ['国规则', 18],
#  ['為台灣', 16],
#  ['使用者', 12],
#  ['关西', 20],
#  ['目的', 20],
#  ['改名為', 7],
#  ['優勝者', 14],
#  ['為了', 9],
#  ['版本', 14],
#  ['团体', 12],
#  ['段位', 14],
#  ['周睿', 13],
#  ['决赛中', 12],
#  ['落子', 16],
#  ['資源', 14],
#  ['程式', 12],
#  ['电视', 12],
#  ['弟子', 22],
#  ['為圍棋', 6],
#  ['小光', 38],
#  ['抗賽', 6],
#  ['家督', 12],
#  ['白棋', 12],
#  ['券杯', 14],
#  ['實利', 12],
#  ['晚报', 12],
#  ['安井', 12],
#  ['秀和', 14],
#  ['限公', 16],
#  ['名譽', 14],
#  ['發行', 9],
#  ['挑戰', 7],
#  ['蒙地', 16],
#  ['新布局', 12],
#  ['大赛', 12],
#  ['武宮', 14],
#  ['报道', 6],
#  ['直播', 9],
#  ['獲勝', 7],
#  ['和韩', 14],
#  ['協會', 12],
#  ['團體', 12],
#  ['采取', 6],
#  ['中日', 10],
#  ['才能', 11],
#  ['守角', 18],
#  ['现代', 6],
#  ['浙江', 18],
#  ['之間', 10],
#  ['赛区', 20],
#  ['已經', 6],
#  ['造成', 7],
#  ['例子', 12],
#  ['当今', 6],
#  ['高目', 14],
#  ['棋圣战', 18],
#  ['日本队', 12],
#  ['郭闻潮', 12],
#  ['方先', 14],
#  ['小时', 14],
#  ['棋坛', 12],
#  ['策略', 12],
#  ['曹薰', 12],
#  ['本身', 6],
#  ['男女', 12],
#  ['星位', 14],
#  ['丁浩', 14],
#  ['全国', 16],
#  ['征子', 12],
#  ['原子', 12],
#  ['发生', 8],
#  ['整個', 7],
#  ['參加', 9],
#  ['目數', 14],
#  ['個黑', 6],
#  ['秀策', 12],
#  ['方用', 12],
#  ['弈城', 14],
#  ['棋盘', 34],
#  ['首次', 9],
#  ['长考', 7],
#  ['秀行', 12],
#  ['风格', 12],
#  ['電腦圍', 16],
#  ['亚军', 14],
#  ['业围', 14],
#  ['比目法', 22],
#  ['日本的', 12],
#  ['9x9', 8],
#  ['类似', 9],
#  ['三三', 7],
#  ['手数', 12],
#  ['連接', 6],
#  ['官方', 12],
#  ['繼承', 7],
#  ['作戰', 6],
#  ['国棋院', 30],
#  ['黑方', 14],
#  ['業餘', 12],
#  ['個角', 14],
#  ['许嘉阳', 12],
#  ['分為', 6],
#  ['王世', 12],
#  ['國內', 8],
#  ['崔精', 16],
#  ['国围', 12],
#  ['機會', 14],
#  ['陳耀燁', 14],
#  ['職業棋', 18],
#  ['职业围棋', 14],
#  ['范胤', 12],
#  ['世界最', 12],
#  ['芮乃伟', 14],
#  ['官子', 12],
#  ['李昌鎬', 16],
#  ['演算法', 16],
#  ['朴文垚', 14],
#  ['浙江省', 16],
#  ['屆起', 11],
#  ['阿含', 18],
#  ['決賽', 18],
#  ['按照', 11],
#  ['少年', 6],
#  ['赵治勋', 12],
#  ['本年度', 12],
#  ['终局', 12],
#  ['決定', 6],
#  ['情況下', 12],
#  ['棋局', 14],
#  ['情况', 20],
#  ['處理', 7],
#  ['全局', 14],
#  ['执黑', 8],
#  ['林家', 14],
#  ['交叉', 14],
#  ['擊敗', 11],
#  ['變成', 6],
#  ['木谷', 12],
#  ['强赛', 7],
#  ['戰鬥', 7],
#  ['任何', 8],
#  ['內容', 12],
#  ['日本棋院', 18],
#  ['日至', 6],
#  ['國際', 12],
#  ['广西', 12],
#  ['曹大元', 12],
#  ['應對', 7],
#  ['尤其', 6],
#  ['整个', 10],
#  ['职业棋', 24],
#  ['国内', 6],
#  ['改名', 6],
#  ['發生', 7],
#  ['叫吃', 10],
#  ['冠亚军', 12],
#  ['全日本', 14],
#  ['織田', 12],
#  ['藤泽', 16],
#  ['广东', 12],
#  ['海峰棋院', 30],
#  ['三子', 8],
#  ['局面', 18],
#  ['重要', 7],
#  ['年围', 12],
#  ['西洋棋', 12],
#  ['棋聖戰', 21],
#  ['富士通杯', 16],
#  ['非常', 8],
#  ['董彦', 18],
#  ['對手', 6],
#  ['選手', 8],
#  ['韓國棋院', 18],
#  ['帳號', 14],
#  ['以後', 12],
#  ['公开', 6],
#  ['圍棋棋', 8],
#  ['棋协会', 18],
#  ['關西棋院', 21],
#  ['職業圍', 12],
#  ['种子选', 12],
#  ['中盤', 20],
#  ['队以', 12],
#  ['中日韩', 12],
#  ['杭州市', 12],
#  ['推出', 7],
#  ['等级', 8],
#  ['將棋', 16],
#  ['變化', 6],
#  ['棋具', 14],
#  ['棋協會', 24],
#  ['陈祖德', 26],
#  ['年因', 6],
#  ['严欢', 12],
#  ['位置', 8],
#  ['江铸久', 16],
#  ['联合', 10],
#  ['为世界', 14],
#  ['对局费', 14],
#  ['围棋规则', 12],
#  ['执白', 7],
#  ['李康', 12],
#  ['結果', 14],
#  ['活棋', 12],
#  ['决赛', 24],
#  ['胡耀宇', 12],
#  ['國際賽', 12],
#  ['了围棋', 6],
#  ['應氏', 14],
#  ['三段', 6],
#  ['這種', 7],
#  ['番棋', 12],
#  ['赞助', 15],
#  ['传统', 12],
#  ['影响', 9],
#  ['城市', 12],
#  ['国家体', 18],
#  ['掛角', 14],
#  ['秀哉', 6],
#  ['奖金', 14],
#  ['特定', 6],
#  ['局部', 12],
#  ['年舉', 7],
#  ['棋战', 14],
#  ['古灵益', 12],
#  ['階段', 16],
#  ['年台', 6],
#  ['達到', 10],
#  ['地區', 12],
#  ['自己的', 8],
#  ['比赛中', 10],
#  ['为围', 6],
#  ['实战', 7],
#  ['兒子', 12],
#  ['停辦', 13],
#  ['比賽中', 7],
#  ['算砂', 12],
#  ['秀甫', 12],
#  ['李喆', 12],
#  ['公開', 6],
#  ['公司', 14],
#  ['黑貼', 14],
#  ['大飛', 16],
#  ['张璇', 14],
#  ['本局', 12],
#  ['依照', 6],
#  ['職業棋手', 21],
#  ['技术', 20],
#  ['初段', 11],
#  ['读秒的', 12],
#  ['類似', 6],
#  ['中国', 28],
#  ['发展', 8],
#  ['日本围', 14],
#  ['李世石', 18],
#  ['云南', 12],
#  ['安冬旭', 12],
#  ['奧林匹亞', 12],
#  ['安井家', 12],
#  ['韩国', 18],
#  ['形態', 12],
#  ['年改', 7],
#  ['年共', 6],
#  ['象棋', 6],
#  ['多数', 8],
#  ['大学', 14],
#  ['北京', 14],
#  ['成為', 10],
#  ['分鐘', 12],
#  ['某些', 7],
#  ['棋手在', 12],
#  ['周泓余', 12],
#  ['范廷鈺', 14],
#  ['是日本', 14],
#  ['重視', 6],
#  ['勝率', 12],
#  ['頭銜', 18],
#  ['台灣圍棋', 16],
#  ['届应', 6],
#  ['参赛', 26],
#  ['柁嘉熹', 12],
#  ['年以', 6],
#  ['年代', 11],
#  ['佟禹林', 12],
#  ['是台灣', 16],
#  ['黑白', 7],
#  ['時候', 12],
#  ['金志锡', 18],
#  ['然而', 8],
#  ['保留', 10],
#  ['是圍棋', 6],
#  ['實力', 18],
#  ['此時', 8],
#  ['連勝', 12],
#  ['人民', 12],
#  ['關西', 12],
#  ['成績', 12],
#  ['職業棋士', 21],
#  ['網路', 18],
#  ['黑棋', 26],
#  ['孔杰', 12],
#  ['宋容慧', 16],
#  ['出現', 6],
#  ['要求', 7],
#  ['围棋协会', 12],
#  ['或者', 9],
#  ['圍棋協', 12],
#  ['棋形', 34],
#  ['雖然', 6],
#  ['遊戲', 12],
#  ['睦镇硕', 6],
#  ['抗赛', 7],
#  ['三番棋', 16],
#  ['先手', 22],
#  ['是由', 6],
#  ['野狐', 14],
#  ['特殊', 6],
#  ['蔡竞', 12],
#  ['首轮', 11],
#  ['進入', 6],
#  ['丁伟', 12],
#  ['日文', 14],
#  ['模樣', 26],
#  ['後因', 14],
#  ['段和', 6],
#  ['選擇', 7],
#  ['木谷實', 14],
#  ['讓子', 8],
#  ['彭荃', 12],
#  ['價值', 12],
#  ['年舉辦', 7],
#  ['王磊', 12],
#  ['当时中', 7],
#  ['届起', 7],
#  ['国队', 18],
#  ['职业围', 12],
#  ['常昊', 14],
#  ['唐奕', 16],
#  ['坂田', 14],
#  ['研究', 6],
#  ['本賽', 12],
#  ...]

# %%
lst.sort(key=lambda x:x[-1],reverse=True)

# %%
lst
# Out:
# [['方圓社', 117],
#  ['江流儿', 90],
#  ['雷凌云', 63],
#  ['江流', 56],
#  ['云子', 52],
#  ['小林光', 51],
#  ['元人', 48],
#  ['对局者', 42],
#  ['赛冠军', 42],
#  ['韩元', 38],
#  ['小光', 38],
#  ['组', 36],
#  ['棋盘', 34],
#  ['棋形', 34],
#  ['棋鬼王', 33],
#  ['御城棋', 33],
#  ['王戰', 33],
#  ['桐山杯', 33],
#  ['樊麾', 33],
#  ['区', 32],
#  ['方圓', 32],
#  ['之一', 31],
#  ['方棋子', 30],
#  ['国棋院', 30],
#  ['海峰棋院', 30],
#  ['定段', 28],
#  ['方胜', 28],
#  ['制度', 28],
#  ['中国', 28],
#  ['女子', 28],
#  ['山城宏', 27],
#  ['黄龙士', 27],
#  ['杯冠军', 26],
#  ['棋圣', 26],
#  ['名单', 26],
#  ['陈祖德', 26],
#  ['参赛', 26],
#  ['黑棋', 26],
#  ['模樣', 26],
#  ['雙人圍', 24],
#  ['颗子', 24],
#  ['妖刀', 24],
#  ['中华台北', 24],
#  ['王晨星', 24],
#  ['項目', 24],
#  ['提子', 24],
#  ['卫平', 24],
#  ['出线', 24],
#  ['职业棋', 24],
#  ['棋協會', 24],
#  ['决赛', 24],
#  ['台灣棋', 24],
#  ['後來', 24],
#  ['如果', 24],
#  ['本赛', 24],
#  ['丈和', 23],
#  ['劫材', 22],
#  ['天元战', 22],
#  ['白昕卉', 22],
#  ['歐洲', 22],
#  ['连胜', 22],
#  ['名人賽', 22],
#  ['对抗赛', 22],
#  ['国流', 22],
#  ['弟子', 22],
#  ['比目法', 22],
#  ['先手', 22],
#  ['規則', 22],
#  ['年全', 22],
#  ['由於', 22],
#  ['對局', 22],
#  ['中國圍棋', 22],
#  ['女子棋', 21],
#  ['国际象', 21],
#  ['刀定式', 21],
#  ['职业棋手', 21],
#  ['正官庄杯', 21],
#  ['国棋手', 21],
#  ['宇宙流', 21],
#  ['棋聖戰', 21],
#  ['關西棋院', 21],
#  ['職業棋手', 21],
#  ['職業棋士', 21],
#  ['財團法人', 21],
#  ['齐鲁晚', 20],
#  ['時代', 20],
#  ['轮败者', 20],
#  ['俞俐均', 20],
#  ['人戰', 20],
#  ['队和', 20],
#  ['聂卫', 20],
#  ['腾讯', 20],
#  ['頭銜者', 20],
#  ['吴清源', 20],
#  ['聖戰', 20],
#  ['賽制', 20],
#  ['聯盟', 20],
#  ['步棋', 20],
#  ['為名人', 20],
#  ['交流', 20],
#  ['年日本', 20],
#  ['国业', 20],
#  ['定式', 20],
#  ['表团', 20],
#  ['赛制', 20],
#  ['复杂性', 20],
#  ['段位制', 20],
#  ['赛事', 20],
#  ['厚勢', 20],
#  ['关西', 20],
#  ['目的', 20],
#  ['赛区', 20],
#  ['情况', 20],
#  ['中盤', 20],
#  ['技术', 20],
#  ['時間', 20],
#  ['昭和', 20],
#  ['之後', 20],
#  ['本因坊', 20],
#  ['日本', 20],
#  ['世界', 20],
#  ['黑嘉嘉', 18],
#  ['女子组', 18],
#  ['小林觉', 18],
#  ['赛棋手', 18],
#  ['楊子萱', 18],
#  ['女流名人', 18],
#  ['外勢', 18],
#  ['胜率', 18],
#  ['全国性', 18],
#  ['理光', 18],
#  ['飛刀', 18],
#  ['王座戰', 18],
#  ['國手', 18],
#  ['国女子', 18],
#  ['視台', 18],
#  ['男棋手', 18],
#  ['崔哲瀚', 18],
#  ['亞軍', 18],
#  ['黃士', 18],
#  ['道策', 18],
#  ['棋世界', 18],
#  ['电王战', 18],
#  ['朴鋕恩', 18],
#  ['方用时', 18],
#  ['规则', 18],
#  ['赛于', 18],
#  ['圣战', 18],
#  ['读秒', 18],
#  ['棋協', 18],
#  ['安節', 18],
#  ['专家', 18],
#  ['出场', 18],
#  ['挑战赛', 18],
#  ['李小溪', 18],
#  ['腾讯野', 18],
#  ['世纪', 18],
#  ['国手战', 18],
#  ['互联网', 18],
#  ['数子', 18],
#  ['數子法', 18],
#  ['广州', 18],
#  ['辜梓豪', 18],
#  ['陈浩', 18],
#  ['年度', 18],
#  ['棋水平', 18],
#  ['网络', 18],
#  ['国规则', 18],
#  ['守角', 18],
#  ['浙江', 18],
#  ['棋圣战', 18],
#  ['職業棋', 18],
#  ['阿含', 18],
#  ['決賽', 18],
#  ['日本棋院', 18],
#  ['局面', 18],
#  ['董彦', 18],
#  ['韓國棋院', 18],
#  ['棋协会', 18],
#  ['国家体', 18],
#  ['李世石', 18],
#  ['韩国', 18],
#  ['頭銜', 18],
#  ['金志锡', 18],
#  ['實力', 18],
#  ['網路', 18],
#  ['国队', 18],
#  ['游戏', 18],
#  ['中央', 18],
#  ['日本棋', 18],
#  ['優勢', 18],
#  ['台灣棋院', 18],
#  ['中國', 18],
#  ['台灣', 18],
#  ['唐韋星', 16],
#  ['定段赛', 16],
#  ['强败者', 16],
#  ['挑战者', 16],
#  ['天台', 16],
#  ['岩本', 16],
#  ['張凱馨', 16],
#  ['丹朱', 16],
#  ['因碩', 16],
#  ['1轮', 16],
#  ['男子组', 16],
#  ['擂台赛', 16],
#  ['黄河杯', 16],
#  ['灵杯', 16],
#  ['黑子', 16],
#  ['资格赛', 16],
#  ['正夫', 16],
#  ['半决赛', 16],
#  ['國流', 16],
#  ['中盘', 16],
#  ['棋聖', 16],
#  ['奖金为', 16],
#  ['级分', 16],
#  ['国手', 16],
#  ['成绩', 16],
#  ['重庆', 16],
#  ['黑龙江', 16],
#  ['晏天章', 16],
#  ['背景', 16],
#  ['围棋赛', 16],
#  ['王积薪', 16],
#  ['对局', 16],
#  ['数据', 16],
#  ['跡目', 16],
#  ['网选', 16],
#  ['弈秋', 16],
#  ['基金會', 16],
#  ['个人赛', 16],
#  ['選拔賽', 16],
#  ['因坊', 16],
#  ['氏杯', 16],
#  ['能力', 16],
#  ['對戰', 16],
#  ['元老', 16],
#  ['顶尖', 16],
#  ['国象', 16],
#  ['貼目', 16],
#  ['智能', 16],
#  ['网格', 16],
#  ['利益', 16],
#  ['马晓春', 16],
#  ['局', 16],
#  ['技巧', 16],
#  ['杭州', 16],
#  ['棋賽', 16],
#  ['2轮', 16],
#  ['公開賽', 16],
#  ['围棋队', 16],
#  ['為台灣', 16],
#  ['落子', 16],
#  ['限公', 16],
#  ['蒙地', 16],
#  ['全国', 16],
#  ['電腦圍', 16],
#  ['崔精', 16],
#  ['李昌鎬', 16],
#  ['演算法', 16],
#  ['浙江省', 16],
#  ['藤泽', 16],
#  ['富士通杯', 16],
#  ['將棋', 16],
#  ['江铸久', 16],
#  ['階段', 16],
#  ['大飛', 16],
#  ['台灣圍棋', 16],
#  ['是台灣', 16],
#  ['宋容慧', 16],
#  ['三番棋', 16],
#  ['唐奕', 16],
#  ['電腦', 16],
#  ['卞相', 16],
#  ['李轩豪', 16],
#  ['朴永训', 16],
#  ['限公司', 16],
#  ['原本', 16],
#  ['優勝', 16],
#  ['情況', 16],
#  ['唐韦星', 16],
#  ['冠军', 16],
#  ['赞助', 15],
#  ['其中', 15],
#  ['廣島', 14],
#  ['淡路修', 14],
#  ['甘肃', 14],
#  ['楊子', 14],
#  ['刘小光', 14],
#  ['橋本', 14],
#  ['圍棋界', 14],
#  ['城围', 14],
#  ['朝日新', 14],
#  ['邱峻', 14],
#  ['队获得', 14],
#  ['挑戰者', 14],
#  ['赵南哲', 14],
#  ['玩家', 14],
#  ['李世乭', 14],
#  ['名誉', 14],
#  ['霸王', 14],
#  ['雙人', 14],
#  ['家康', 14],
#  ['网棋', 14],
#  ['決定戰', 14],
#  ['金明训', 14],
#  ['团体赛', 14],
#  ['海峰', 14],
#  ['手棋', 14],
#  ['棋王赛', 14],
#  ['為日本', 14],
#  ['黄龙', 14],
#  ['名人战', 14],
#  ['还棋头', 14],
#  ['预选赛', 14],
#  ['人以', 14],
#  ['姜堰', 14],
#  ['小飛', 14],
#  ['国家队', 14],
#  ['方式', 14],
#  ['工智', 14],
#  ['国棋', 14],
#  ['單位', 14],
#  ['传说', 14],
#  ['網站', 14],
#  ['国职', 14],
#  ['政府', 14],
#  ['棋牌', 14],
#  ['參數', 14],
#  ['全部', 14],
#  ['实际', 14],
#  ['计数', 14],
#  ['台赛', 14],
#  ['日本圍', 14],
#  ['实力', 14],
#  ['棋艺', 14],
#  ['领域', 14],
#  ['後黑', 14],
#  ['距離', 14],
#  ['周俊勳', 14],
#  ['种子', 14],
#  ['获胜者', 14],
#  ['棋戰', 14],
#  ['人数', 14],
#  ['名棋手', 14],
#  ['意思', 14],
#  ['圍棋賽', 14],
#  ['范西屏', 14],
#  ['手合', 14],
#  ['周俊', 14],
#  ['中環', 14],
#  ['周俊勋', 14],
#  ['生涯', 14],
#  ['名将', 14],
#  ['方可', 14],
#  ['罗玄', 14],
#  ['方捷', 14],
#  ['男子', 14],
#  ['林海峰', 14],
#  ['世界第', 14],
#  ['職業圍棋', 14],
#  ['業棋士', 14],
#  ['国务', 14],
#  ['女子围', 14],
#  ['程式碼', 14],
#  ['本赛第', 14],
#  ['指围棋', 14],
#  ['優勝者', 14],
#  ['版本', 14],
#  ['段位', 14],
#  ['資源', 14],
#  ['券杯', 14],
#  ['秀和', 14],
#  ['名譽', 14],
#  ['武宮', 14],
#  ['和韩', 14],
#  ['高目', 14],
#  ['方先', 14],
#  ['小时', 14],
#  ['星位', 14],
#  ['丁浩', 14],
#  ['目數', 14],
#  ['弈城', 14],
#  ['亚军', 14],
#  ['业围', 14],
#  ['黑方', 14],
#  ['個角', 14],
#  ['機會', 14],
#  ['陳耀燁', 14],
#  ['职业围棋', 14],
#  ['芮乃伟', 14],
#  ['朴文垚', 14],
#  ['棋局', 14],
#  ['全局', 14],
#  ['林家', 14],
#  ['交叉', 14],
#  ['全日本', 14],
#  ['帳號', 14],
#  ['棋具', 14],
#  ['为世界', 14],
#  ['对局费', 14],
#  ['結果', 14],
#  ['應氏', 14],
#  ['掛角', 14],
#  ['奖金', 14],
#  ['棋战', 14],
#  ['公司', 14],
#  ['黑貼', 14],
#  ['张璇', 14],
#  ['日本围', 14],
#  ['大学', 14],
#  ['北京', 14],
#  ['范廷鈺', 14],
#  ['是日本', 14],
#  ['野狐', 14],
#  ['日文', 14],
#  ['後因', 14],
#  ['木谷實', 14],
#  ['常昊', 14],
#  ['坂田', 14],
#  ['論文', 14],
#  ['罗洗河', 14],
#  ['過程', 14],
#  ['布局', 14],
#  ['朴廷桓', 14],
#  ['曹薰铉', 14],
#  ['陶欣然', 14],
#  ['目数', 14],
#  ['俞斌', 14],
#  ['井山裕太', 14],
#  ['刘星', 14],
#  ['獎金', 14],
#  ['冠軍', 14],
#  ['開始', 14],
#  ['棋譜', 14],
#  ['刘昌赫', 14],
#  ['胜者', 14],
#  ['世紀', 14],
#  ['党毅飞', 14],
#  ['江维杰', 14],
#  ['位棋手', 14],
#  ['棋手', 14],
#  ['业余', 14],
#  ['范廷钰', 14],
#  ['棋子', 14],
#  ['棋盤', 14],
#  ['国际', 14],
#  ['轮于', 13],
#  ['劫爭', 13],
#  ['組織', 13],
#  ['预选', 13],
#  ['开发', 13],
#  ['周睿', 13],
#  ['停辦', 13],
#  ['本因', 13],
#  ['聂卫平', 12],
#  ['贴目', 12],
#  ['臺北市', 12],
#  ['晋级', 12],
#  ['瀨越', 12],
#  ['荒木氏', 12],
#  ['决赛第', 12],
#  ['强败者获', 12],
#  ['專案', 12],
#  ['俘子', 12],
#  ['柯潔', 12],
#  ['本戰', 12],
#  ['通算', 12],
#  ['绝艺', 12],
#  ['王座', 12],
#  ['农心杯', 12],
#  ['新布石', 12],
#  ['應昌', 12],
#  ['收官', 12],
#  ['位棋', 12],
#  ['白方', 12],
#  ['亚洲', 12],
#  ['只棋子', 12],
#  ['主将', 12],
#  ['李昌镐', 12],
#  ['年代表', 12],
#  ['南韓首爾', 12],
#  ['混双赛', 12],
#  ['江戶', 12],
#  ['網路圍', 12],
#  ['余棋手', 12],
#  ['朴志恩', 12],
#  ['开局', 12],
#  ['职业', 12],
#  ['衢州市', 12],
#  ['段胜', 12],
#  ['產生', 12],
#  ['金荣', 12],
#  ['當作', 12],
#  ['豐田', 12],
#  ['座戰', 12],
#  ['武汉', 12],
#  ['负李', 12],
#  ['單敗', 12],
#  ['耀烨', 12],
#  ['江苏', 12],
#  ['白子', 12],
#  ['棋經', 12],
#  ['杯世界', 12],
#  ['国参加', 12],
#  ['人類', 12],
#  ['镇围棋', 12],
#  ['个人', 12],
#  ['家家督', 12],
#  ['人围', 12],
#  ['軟體', 12],
#  ['衢州', 12],
#  ['此頭銜', 12],
#  ['杯本赛', 12],
#  ['关东', 12],
#  ['團隊', 12],
#  ['棋品', 12],
#  ['数学', 12],
#  ['中國圍', 12],
#  ['本棋院', 12],
#  ['服务器', 12],
#  ['淘汰赛', 12],
#  ['棋院和', 12],
#  ['内围棋', 12],
#  ['重要性', 12],
#  ['世本因', 12],
#  ['段位的', 12],
#  ['市围棋', 12],
#  ['俱乐部', 12],
#  ['將棋界', 12],
#  ['赵晨宇', 12],
#  ['假眼活', 12],
#  ['元战', 12],
#  ['業圍', 12],
#  ['酒店', 12],
#  ['全國', 12],
#  ['本学', 12],
#  ['实业', 12],
#  ['院和', 12],
#  ['南京', 12],
#  ['团队', 12],
#  ['佔角', 12],
#  ['中学', 12],
#  ['原因', 12],
#  ['為台', 12],
#  ['李东勋', 12],
#  ['之莹', 12],
#  ['富士', 12],
#  ['通过', 12],
#  ['程度', 12],
#  ['陕西', 12],
#  ['全运', 12],
#  ['日程', 12],
#  ['東京', 12],
#  ['规定', 12],
#  ['方一', 12],
#  ['江维', 12],
#  ['佛乘', 12],
#  ['德川', 12],
#  ['东京', 12],
#  ['歷史', 12],
#  ['坊門', 12],
#  ['利用', 12],
#  ['台北', 12],
#  ['成员', 12],
#  ['之父', 12],
#  ['己方', 12],
#  ['外卡', 12],
#  ['高校', 12],
#  ['小组', 12],
#  ['分數', 12],
#  ['定石', 12],
#  ['棋以', 12],
#  ['香港', 12],
#  ['单败淘', 12],
#  ['女流', 12],
#  ['际象', 12],
#  ['平面', 12],
#  ['直线', 12],
#  ['阶段', 12],
#  ['扇興杯', 12],
#  ['名人戰', 12],
#  ['豐田杯', 12],
#  ['資料', 12],
#  ['棋赛', 12],
#  ['工程', 12],
#  ['上海', 12],
#  ['专业', 12],
#  ['快棋', 12],
#  ['立於', 12],
#  ['山东', 12],
#  ['同名', 12],
#  ['局棋', 12],
#  ['结果', 12],
#  ['丁烈', 12],
#  ['围棋名人战', 12],
#  ['人机', 12],
#  ['加藤', 12],
#  ['讀賣新聞', 12],
#  ['对弈', 12],
#  ['錦標賽', 12],
#  ['丁明君', 12],
#  ['伺服器', 12],
#  ['张馨月', 12],
#  ['无锡市', 12],
#  ['顾水如', 12],
#  ['數子', 12],
#  ['分散式', 12],
#  ['使用者', 12],
#  ['团体', 12],
#  ['决赛中', 12],
#  ['程式', 12],
#  ['电视', 12],
#  ['家督', 12],
#  ['白棋', 12],
#  ['實利', 12],
#  ['晚报', 12],
#  ['安井', 12],
#  ['新布局', 12],
#  ['大赛', 12],
#  ['協會', 12],
#  ['團體', 12],
#  ['例子', 12],
#  ['日本队', 12],
#  ['郭闻潮', 12],
#  ['棋坛', 12],
#  ['策略', 12],
#  ['曹薰', 12],
#  ['男女', 12],
#  ['征子', 12],
#  ['原子', 12],
#  ['秀策', 12],
#  ['方用', 12],
#  ['秀行', 12],
#  ['风格', 12],
#  ['日本的', 12],
#  ['手数', 12],
#  ['官方', 12],
#  ['業餘', 12],
#  ['许嘉阳', 12],
#  ['王世', 12],
#  ['国围', 12],
#  ['范胤', 12],
#  ['世界最', 12],
#  ['官子', 12],
#  ['赵治勋', 12],
#  ['本年度', 12],
#  ['终局', 12],
#  ['情況下', 12],
#  ['木谷', 12],
#  ['內容', 12],
#  ['國際', 12],
#  ['广西', 12],
#  ['曹大元', 12],
#  ['冠亚军', 12],
#  ['織田', 12],
#  ['广东', 12],
#  ['年围', 12],
#  ['西洋棋', 12],
#  ['以後', 12],
#  ['職業圍', 12],
#  ['种子选', 12],
#  ['队以', 12],
#  ['中日韩', 12],
#  ['杭州市', 12],
#  ['严欢', 12],
#  ['围棋规则', 12],
#  ['李康', 12],
#  ['活棋', 12],
#  ['胡耀宇', 12],
#  ['國際賽', 12],
#  ['番棋', 12],
#  ['传统', 12],
#  ['城市', 12],
#  ['局部', 12],
#  ['古灵益', 12],
#  ['地區', 12],
#  ['兒子', 12],
#  ['算砂', 12],
#  ['秀甫', 12],
#  ['李喆', 12],
#  ['本局', 12],
#  ['读秒的', 12],
#  ['云南', 12],
#  ['安冬旭', 12],
#  ['奧林匹亞', 12],
#  ['安井家', 12],
#  ['形態', 12],
#  ['分鐘', 12],
#  ['棋手在', 12],
#  ['周泓余', 12],
#  ['勝率', 12],
#  ['柁嘉熹', 12],
#  ['佟禹林', 12],
#  ['時候', 12],
#  ['連勝', 12],
#  ['人民', 12],
#  ['關西', 12],
#  ['成績', 12],
#  ['孔杰', 12],
#  ['围棋协会', 12],
#  ['圍棋協', 12],
#  ['遊戲', 12],
#  ['蔡竞', 12],
#  ['丁伟', 12],
#  ['彭荃', 12],
#  ['價值', 12],
#  ['王磊', 12],
#  ['职业围', 12],
#  ['本賽', 12],
#  ['棋界', 12],
#  ['战胜', 12],
#  ['电脑', 12],
#  ['世本', 12],
#  ['吳清源', 12],
#  ['棋盤上', 12],
#  ['行棋', 12],
#  ['范蕴若', 12],
#  ['申真谞', 12],
#  ['国际围', 12],
#  ['賽事', 12],
#  ['人赛', 12],
#  ['檀啸', 12],
#  ['国围棋', 12],
#  ['时间', 12],
#  ['英文', 12],
#  ['杨鼎新', 12],
#  ['用时', 12],
#  ['姜东润', 12],
#  ['韓國', 12],
#  ['国家', 12],
#  ['棋王', 12],
#  ['雙方', 12],
#  ['规则与', 12],
#  ['佈局', 12],
#  ['對方', 12],
#  ['柯洁', 12],
#  ['女棋手', 12],
#  ['棋院', 12],
#  ['连笑', 12],
#  ['陈耀烨', 12],
#  ['谢赫', 12],
#  ['周鹤洋', 12],
#  ['棋力', 12],
#  ['棋士', 12],
#  ['4子', 12],
#  ['職業', 12],
#  ['古力', 12],
#  ['联棋', 11],
#  ['其它', 11],
#  ['應用', 11],
#  ['创办', 11],
#  ['運用', 11],
#  ['才能', 11],
#  ['屆起', 11],
#  ['按照', 11],
#  ['擊敗', 11],
#  ['初段', 11],
#  ['年代', 11],
#  ['首轮', 11],
#  ['以下', 11],
#  ['同時', 11],
#  ['围棋', 11],
#  ['deepmind', 10],
#  ['打劫', 10],
#  ['经过', 10],
#  ['vs', 10],
#  ['最高', 10],
#  ['真眼', 10],
#  ['可能', 10],
#  ['变得', 10],
#  ['佐為', 10],
#  ['贊助', 10],
#  ['中日', 10],
#  ['之間', 10],
#  ['整个', 10],
#  ['叫吃', 10],
#  ['联合', 10],
#  ['達到', 10],
#  ['比赛中', 10],
#  ['成為', 10],
#  ['保留', 10],
#  ['攻擊', 10],
#  ['小目', 10],
#  ['比較', 10],
#  ['以上', 10],
#  ['根据', 10],
#  ['', 10],
#  ['年第', 10],
#  ['本届', 9],
#  ['年道', 9],
#  ['任中', 9],
#  ['复赛', 9],
#  ['聯', 9],
#  ['學習', 9],
#  ['际象棋', 9],
#  ['负', 9],
#  ['下午', 9],
#  ['日', 9],
#  ['推广', 9],
#  ['透過', 9],
#  ['体育', 9],
#  ['運算', 9],
#  ['这种', 9],
#  ['显著', 9],
#  ['每年', 9],
#  ['提升', 9],
#  ['消劫', 9],
#  ['知得', 9],
#  ['为', 9],
#  ['包圍', 9],
#  ['通常', 9],
#  ['舉辦', 9],
#  ['对于', 9],
#  ['淘汰賽', 9],
#  ['年日', 9],
#  ['综合', 9],
#  ['為了', 9],
#  ['發行', 9],
#  ['直播', 9],
#  ['參加', 9],
#  ['首次', 9],
#  ['类似', 9],
#  ['影响', 9],
#  ['或者', 9],
#  ['年间', 9],
#  ['元晟溱', 9],
#  ['采用', 9],
#  ['認為', 9],
#  ['特別', 9],
#  ['年开', 9],
#  ['', 9],
#  ['這些', 9],
#  ['开始', 9],
#  ['', 9],
#  ['以及', 9],
#  ['循环圈', 8],
#  ['本身劫', 8],
#  ['中環盃', 8],
#  ['深入', 8],
#  ['年為', 8],
#  ['得到', 8],
#  ['目外', 8],
#  ['导致', 8],
#  ['混双', 8],
#  ['主办', 8],
#  ['申旻埈', 8],
#  ['目半', 8],
#  ['负于', 8],
#  ['勝制', 8],
#  ['獲得', 8],
#  ['複雜', 8],
#  ['是围棋', 8],
#  ['邀请', 8],
#  ['設定', 8],
#  ['工作', 8],
#  ['宣布', 8],
#  ['坐标', 8],
#  ['達成', 8],
#  ['连续', 8],
#  ['受到', 8],
#  ['打入', 8],
#  ['彼此', 8],
#  ['胜出', 8],
#  ['6日', 8],
#  ['釋出', 8],
#  ['小時', 8],
#  ['同时', 8],
#  ['互相', 8],
#  ['这样', 8],
#  ['主要', 8],
#  ['安排', 8],
#  ['胜负', 8],
#  ['對弈', 8],
#  ['发生', 8],
#  ['9x9', 8],
#  ['國內', 8],
#  ['执黑', 8],
#  ['任何', 8],
#  ['三子', 8],
#  ['非常', 8],
#  ['選手', 8],
#  ['圍棋棋', 8],
#  ['等级', 8],
#  ['位置', 8],
#  ['自己的', 8],
#  ['发展', 8],
#  ['多数', 8],
#  ['然而', 8],
#  ['此時', 8],
#  ['讓子', 8],
#  ['始于', 8],
#  ['這個', 8],
#  ['首届', 8],
#  ['下法', 8],
#  ['稱為', 8],
#  ['比賽', 8],
#  ['年起', 8],
#  ['使用', 8],
#  ['圍棋', 8],
#  ['預選', 7],
#  ['碁聖', 7],
#  ['免选', 7],
#  ['过惕生', 7],
#  ['天元', 7],
#  ['謝依旻', 7],
#  ['十一', 7],
#  ['賽進行', 7],
#  ['10万', 7],
#  ['正式', 7],
#  ['排名', 7],
#  ['中方', 7],
#  ['曾经', 7],
#  ['9日', 7],
#  ['组合', 7],
#  ['年底', 7],
#  ['选手', 7],
#  ['着法', 7],
#  ['分析', 7],
#  ['自我訓練', 7],
#  ['研究的', 7],
#  ['段以', 7],
#  ['最佳', 7],
#  ['高段', 7],
#  ['讀賣', 7],
#  ['中部', 7],
#  ['九段', 7],
#  ['各地', 7],
#  ['当时', 7],
#  ['之子', 7],
#  ['占据', 7],
#  ['1月1日', 7],
#  ['實做', 7],
#  ['2万', 7],
#  ['月', 7],
#  ['聞社', 7],
#  ['創立', 7],
#  ['附近', 7],
#  ['虽然', 7],
#  ['真露杯', 7],
#  ['對弈中', 7],
#  ['年間', 7],
#  ['元和', 7],
#  ['届比', 7],
#  ['改名為', 7],
#  ['挑戰', 7],
#  ['獲勝', 7],
#  ['造成', 7],
#  ['整個', 7],
#  ['长考', 7],
#  ['三三', 7],
#  ['繼承', 7],
#  ['處理', 7],
#  ['强赛', 7],
#  ['戰鬥', 7],
#  ['應對', 7],
#  ['發生', 7],
#  ['重要', 7],
#  ['推出', 7],
#  ['执白', 7],
#  ['這種', 7],
#  ['年舉', 7],
#  ['实战', 7],
#  ['比賽中', 7],
#  ['年改', 7],
#  ['某些', 7],
#  ['黑白', 7],
#  ['要求', 7],
#  ['抗赛', 7],
#  ['選擇', 7],
#  ['年舉辦', 7],
#  ['当时中', 7],
#  ['届起', 7],
#  ['至第', 7],
#  ['', 7],
#  ['改為', 7],
#  ['年開', 7],
#  ['主辦', 7],
#  ['', 7],
#  ['上届', 6],
#  ['等级分', 6],
#  ['訓練', 6],
#  ['擂台', 6],
#  ['分至', 6],
#  ['届中', 6],
#  ['codice', 6],
#  ['本选赛', 6],
#  ['執白', 6],
#  ['更具', 6],
#  ['碁聖戰', 6],
#  ['圍棋高', 6],
#  ['抽签', 6],
#  ['分先', 6],
#  ['最強', 6],
#  ['担任', 6],
#  ['屆本', 6],
#  ['击败', 6],
#  ['来自', 6],
#  ['下棋', 6],
#  ...]

# %%
len(lst)
# Out:
# 1160

# %%
text=''
for i in range(len(lst)):
    text+=lst[i][0]
from zhconv import convert
text
# Out:
# '方圓社江流儿雷凌云江流云子小林光元人对局者赛冠军韩元小光组棋盘棋形棋鬼王御城棋王戰桐山杯樊麾区方圓之一方棋子国棋院海峰棋院定段方胜制度中国女子山城宏黄龙士杯冠军棋圣名单陈祖德参赛黑棋模樣雙人圍颗子妖刀中华台北王晨星項目提子卫平出线职业棋棋協會决赛台灣棋後來如果本赛丈和劫材天元战白昕卉歐洲连胜名人賽对抗赛国流弟子比目法先手規則年全由於對局中國圍棋女子棋国际象刀定式职业棋手正官庄杯国棋手宇宙流棋聖戰關西棋院職業棋手職業棋士財團法人齐鲁晚時代轮败者俞俐均人戰队和聂卫腾讯頭銜者吴清源聖戰賽制聯盟步棋為名人交流年日本国业定式表团赛制复杂性段位制赛事厚勢关西目的赛区情况中盤技术時間昭和之後本因坊日本世界黑嘉嘉女子组小林觉赛棋手楊子萱女流名人外勢胜率全国性理光飛刀王座戰國手国女子視台男棋手崔哲瀚亞軍黃士道策棋世界电王战朴鋕恩方用时规则赛于圣战读秒棋協安節专家出场挑战赛李小溪腾讯野世纪国手战互联网数子數子法广州辜梓豪陈浩年度棋水平网络国规则守角浙江棋圣战職業棋阿含決賽日本棋院局面董彦韓國棋院棋协会国家体李世石韩国頭銜金志锡實力網路国队游戏中央日本棋優勢台灣棋院中國台灣唐韋星定段赛强败者挑战者天台岩本張凱馨丹朱因碩1轮男子组擂台赛黄河杯灵杯黑子资格赛正夫半决赛國流中盘棋聖奖金为级分国手成绩重庆黑龙江晏天章背景围棋赛王积薪对局数据跡目网选弈秋基金會个人赛選拔賽因坊氏杯能力對戰元老顶尖国象貼目智能网格利益马晓春局技巧杭州棋賽2轮公開賽围棋队為台灣落子限公蒙地全国電腦圍崔精李昌鎬演算法浙江省藤泽富士通杯將棋江铸久階段大飛台灣圍棋是台灣宋容慧三番棋唐奕電腦卞相李轩豪朴永训限公司原本優勝情況唐韦星冠军赞助其中廣島淡路修甘肃楊子刘小光橋本圍棋界城围朝日新邱峻队获得挑戰者赵南哲玩家李世乭名誉霸王雙人家康网棋決定戰金明训团体赛海峰手棋棋王赛為日本黄龙名人战还棋头预选赛人以姜堰小飛国家队方式工智国棋單位传说網站国职政府棋牌參數全部实际计数台赛日本圍实力棋艺领域後黑距離周俊勳种子获胜者棋戰人数名棋手意思圍棋賽范西屏手合周俊中環周俊勋生涯名将方可罗玄方捷男子林海峰世界第職業圍棋業棋士国务女子围程式碼本赛第指围棋優勝者版本段位資源券杯秀和名譽武宮和韩高目方先小时星位丁浩目數弈城亚军业围黑方個角機會陳耀燁职业围棋芮乃伟朴文垚棋局全局林家交叉全日本帳號棋具为世界对局费結果應氏掛角奖金棋战公司黑貼张璇日本围大学北京范廷鈺是日本野狐日文後因木谷實常昊坂田論文罗洗河過程布局朴廷桓曹薰铉陶欣然目数俞斌井山裕太刘星獎金冠軍開始棋譜刘昌赫胜者世紀党毅飞江维杰位棋手棋手业余范廷钰棋子棋盤国际轮于劫爭組織预选开发周睿停辦本因聂卫平贴目臺北市晋级瀨越荒木氏决赛第强败者获專案俘子柯潔本戰通算绝艺王座农心杯新布石應昌收官位棋白方亚洲只棋子主将李昌镐年代表南韓首爾混双赛江戶網路圍余棋手朴志恩开局职业衢州市段胜產生金荣當作豐田座戰武汉负李單敗耀烨江苏白子棋經杯世界国参加人類镇围棋个人家家督人围軟體衢州此頭銜杯本赛关东團隊棋品数学中國圍本棋院服务器淘汰赛棋院和内围棋重要性世本因段位的市围棋俱乐部將棋界赵晨宇假眼活元战業圍酒店全國本学实业院和南京团队佔角中学原因為台李东勋之莹富士通过程度陕西全运日程東京规定方一江维佛乘德川东京歷史坊門利用台北成员之父己方外卡高校小组分數定石棋以香港单败淘女流际象平面直线阶段扇興杯名人戰豐田杯資料棋赛工程上海专业快棋立於山东同名局棋结果丁烈围棋名人战人机加藤讀賣新聞对弈錦標賽丁明君伺服器张馨月无锡市顾水如數子分散式使用者团体决赛中程式电视家督白棋實利晚报安井新布局大赛協會團體例子日本队郭闻潮棋坛策略曹薰男女征子原子秀策方用秀行风格日本的手数官方業餘许嘉阳王世国围范胤世界最官子赵治勋本年度终局情況下木谷內容國際广西曹大元冠亚军織田广东年围西洋棋以後職業圍种子选队以中日韩杭州市严欢围棋规则李康活棋胡耀宇國際賽番棋传统城市局部古灵益地區兒子算砂秀甫李喆本局读秒的云南安冬旭奧林匹亞安井家形態分鐘棋手在周泓余勝率柁嘉熹佟禹林時候連勝人民關西成績孔杰围棋协会圍棋協遊戲蔡竞丁伟彭荃價值王磊职业围本賽棋界战胜电脑世本吳清源棋盤上行棋范蕴若申真谞国际围賽事人赛檀啸国围棋时间英文杨鼎新用时姜东润韓國国家棋王雙方规则与佈局對方柯洁女棋手棋院连笑陈耀烨谢赫周鹤洋棋力棋士4子職業古力联棋其它應用创办運用才能屆起按照擊敗初段年代首轮以下同時围棋deepmind打劫经过vs最高真眼可能变得佐為贊助中日之間整个叫吃联合達到比赛中成為保留攻擊小目比較以上根据年第本届年道任中复赛聯學習际象棋负下午日推广透過体育運算这种显著每年提升消劫知得为包圍通常舉辦对于淘汰賽年日综合為了發行直播參加首次类似影响或者年间元晟溱采用認為特別年开這些开始以及循环圈本身劫中環盃深入年為得到目外导致混双主办申旻埈目半负于勝制獲得複雜是围棋邀请設定工作宣布坐标達成连续受到打入彼此胜出6日釋出小時同时互相这样主要安排胜负對弈发生9x9國內执黑任何三子非常選手圍棋棋等级位置自己的发展多数然而此時讓子始于這個首届下法稱為比賽年起使用圍棋預選碁聖免选过惕生天元謝依旻十一賽進行10万正式排名中方曾经9日组合年底选手着法分析自我訓練研究的段以最佳高段讀賣中部九段各地当时之子占据1月1日實做2万月聞社創立附近虽然真露杯對弈中年間元和届比改名為挑戰獲勝造成整個长考三三繼承處理强赛戰鬥應對發生重要推出执白這種年舉实战比賽中年改某些黑白要求抗赛選擇年舉辦当时中届起至第改為年開主辦上届等级分訓練擂台分至届中codice本选赛執白更具碁聖戰圍棋高抽签分先最強担任屆本击败来自下棋引起只能禁止羋昱廷循环獲勝者挑战亞藝盃则是杯围棋围棋最际围棋围棋网為本因输给了组成的被视为被叫做位提白之间支援同樣模仿三轮再次网上則因系列预赛长期卡斯比對執黑大小世代裁判卡尔12万參考循環極其世襲本薰升降报名赛前连接先前手割打算十二争夺得第29日加以很多相鄰停止点3日将于4日下到思考放送方各則是夺得超過改稱强战必須formula对围棋得天元赞助商3月4日世乭淘汰获得存在举办的年年位日和年獲选拔計算日围棋围棋大为围棋年取為圍棋抗賽报道采取现代已經当今本身個黑連接作戰分為少年決定變成日至尤其国内改名對手公开變化年因了围棋三段秀哉特定年台为围公開依照類似年共象棋重視届应年以是圍棋出現雖然睦镇硕是由特殊進入段和研究進行目前稱作年才黄奕中这些周睿羊名為年获年至年和年到年由年中其他採用芈昱廷时越發展當時每方比赛'

# %%
text=convert(text,'zh-cn')
with open("oneclick.txt",'w') as f2:
    f2.writelines(text)
f2.close()

# %%
text
# Out:
# '方圆社江流儿雷凌云江流云子小林光元人对局者赛冠军韩元小光组棋盘棋形棋鬼王御城棋王战桐山杯樊麾区方圆之一方棋子国棋院海峰棋院定段方胜制度中国女子山城宏黄龙士杯冠军棋圣名单陈祖德参赛黑棋模样双人围颗子妖刀中华台北王晨星项目提子卫平出线职业棋棋协会决赛台湾棋后来如果本赛丈和劫材天元战白昕卉欧洲连胜名人赛对抗赛国流弟子比目法先手规则年全由于对局中国围棋女子棋国际象刀定式职业棋手正官庄杯国棋手宇宙流棋圣战关西棋院职业棋手职业棋士财团法人齐鲁晚时代轮败者俞俐均人战队和聂卫腾讯头衔者吴清源圣战赛制联盟步棋为名人交流年日本国业定式表团赛制复杂性段位制赛事厚势关西目的赛区情况中盘技术时间昭和之后本因坊日本世界黑嘉嘉女子组小林觉赛棋手杨子萱女流名人外势胜率全国性理光飞刀王座战国手国女子视台男棋手崔哲瀚亚军黄士道策棋世界电王战朴鋕恩方用时规则赛于圣战读秒棋协安节专家出场挑战赛李小溪腾讯野世纪国手战互联网数子数子法广州辜梓豪陈浩年度棋水平网络国规则守角浙江棋圣战职业棋阿含决赛日本棋院局面董彦韩国棋院棋协会国家体李世石韩国头衔金志锡实力网络国队游戏中央日本棋优势台湾棋院中国台湾唐韦星定段赛强败者挑战者天台岩本张凯馨丹朱因硕1轮男子组擂台赛黄河杯灵杯黑子资格赛正夫半决赛国流中盘棋圣奖金为级分国手成绩重庆黑龙江晏天章背景围棋赛王积薪对局数据迹目网选弈秋基金会个人赛选拔赛因坊氏杯能力对战元老顶尖国象贴目智能网格利益马晓春局技巧杭州棋赛2轮公开赛围棋队为台湾落子限公蒙地全国电脑围崔精李昌镐算法浙江省藤泽富士通杯将棋江铸久阶段大飞台湾围棋是台湾宋容慧三番棋唐奕电脑卞相李轩豪朴永训限公司原本优胜情况唐韦星冠军赞助其中广岛淡路修甘肃杨子刘小光桥本围棋界城围朝日新邱峻队获得挑战者赵南哲玩家李世乭名誉霸王双人家康网棋决定战金明训团体赛海峰手棋棋王赛为日本黄龙名人战还棋头预选赛人以姜堰小飞国家队方式工智国棋单位传说网站国职政府棋牌参数全部实际计数台赛日本围实力棋艺领域后黑距离周俊勋种子获胜者棋战人数名棋手意思围棋赛范西屏手合周俊中环周俊勋生涯名将方可罗玄方捷男子林海峰世界第职业围棋业棋士国务女子围程式码本赛第指围棋优胜者版本段位资源券杯秀和名誉武宫和韩高目方先小时星位丁浩目数弈城亚军业围黑方个角机会陈耀烨职业围棋芮乃伟朴文垚棋局全局林家交叉全日本账号棋具为世界对局费结果应氏挂角奖金棋战公司黑贴张璇日本围大学北京范廷钰是日本野狐日文后因木谷实常昊坂田论文罗洗河过程布局朴廷桓曹薰铉陶欣然目数俞斌井山裕太刘星奖金冠军开始棋谱刘昌赫胜者世纪党毅飞江维杰位棋手棋手业余范廷钰棋子棋盘国际轮于劫争组织预选开发周睿停办本因聂卫平贴目台北市晋级濑越荒木氏决赛第强败者获专案俘子柯洁本战通算绝艺王座农心杯新布石应昌收官位棋白方亚洲只棋子主将李昌镐年代表韩国首尔混双赛江户网络围余棋手朴志恩开局职业衢州市段胜产生金荣当作丰田座战武汉负李单败耀烨江苏白子棋经杯世界国参加人类镇围棋个人家家督人围软件衢州此头衔杯本赛关东团队棋品数学中国围本棋院服务器淘汰赛棋院和内围棋重要性世本因段位的市围棋俱乐部将棋界赵晨宇假眼活元战业围酒店全国本学实业院和南京团队占角中学原因为台李东勋之莹富士通过程度陕西全运日程东京规定方一江维佛乘德川东京历史坊门利用台北成员之父己方外卡高校小组分数定石棋以香港单败淘女流际象平面直线阶段扇兴杯名人战丰田杯资料棋赛工程上海专业快棋立于山东同名局棋结果丁烈围棋名人战人机加藤读卖新闻对弈锦标赛丁明君服务器张馨月无锡市顾水如数子分散式使用者团体决赛中程式电视家督白棋实利晚报安井新布局大赛协会团体例子日本队郭闻潮棋坛策略曹薰男女征子原子秀策方用秀行风格日本的手数官方业余许嘉阳王世国围范胤世界最官子赵治勋本年度终局情况下木谷内容国际广西曹大元冠亚军织田广东年围国际象棋以后职业围种子选队以中日韩杭州市严欢围棋规则李康活棋胡耀宇国际赛番棋传统城市局部古灵益地区儿子算砂秀甫李喆本局读秒的云南安冬旭奥林匹亚安井家形态分钟棋手在周泓余胜率柁嘉熹佟禹林时候连胜人民关西成绩孔杰围棋协会围棋协游戏蔡竞丁伟彭荃价值王磊职业围本赛棋界战胜电脑世本吴清源棋盘上行棋范蕴若申真谞国际围赛事人赛檀啸国围棋时间英文杨鼎新用时姜东润韩国国家棋王双方规则与布局对方柯洁女棋手棋院连笑陈耀烨谢赫周鹤洋棋力棋士4子职业古力联棋其它应用创办运用才能届起按照击败初段年代首轮以下同时围棋deepmind打劫经过vs最高真眼可能变得佐为赞助中日之间整个叫吃联合达到比赛中成为保留攻击小目比较以上根据年第本届年道任中复赛联学习际象棋负下午日推广透过体育运算这种显著每年提升消劫知得为包围通常举办对于淘汰赛年日综合为了发行直播参加首次类似影响或者年间元晟溱采用认为特别年开这些开始以及循环圈本身劫中环杯深入年为得到目外导致混双主办申旻埈目半负于胜制获得复杂是围棋邀请设定工作宣布坐标达成连续受到打入彼此胜出6日释出小时同时互相这样主要安排胜负对弈发生9x9国内执黑任何三子非常选手围棋棋等级位置自己的发展多数然而此时让子始于这个首届下法称为比赛年起使用围棋预选碁圣免选过惕生天元谢依旻十一赛进行10万正式排名中方曾经9日组合年底选手着法分析自我训练研究的段以最佳高段读卖中部九段各地当时之子占据1月1日实做2万月闻社创立附近虽然真露杯对弈中年间元和届比改名为挑战获胜造成整个长考三三继承处理强赛战斗应对发生重要推出执白这种年举实战比赛中年改某些黑白要求抗赛选择年举办当时中届起至第改为年开主办上届等级分训练擂台分至届中codice本选赛执白更具碁圣战围棋高抽签分先最强担任届本击败来自下棋引起只能禁止芈昱廷循环获胜者挑战亚艺杯则是杯围棋围棋最际围棋围棋网为本因输给了组成的被视为被叫做位提白之间支援同样模仿三轮再次网上则因系列预赛长期卡斯比对执黑大小世代裁判卡尔12万参考循环极其世袭本薰升降报名赛前连接先前手割打算十二争夺得第29日加以很多相邻停止点3日将于4日下到思考放送方各则是夺得超过改称强战必须formula对围棋得天元赞助商3月4日世乭淘汰获得存在举办的年年位日和年获选拔计算日围棋围棋大为围棋年取为围棋抗赛报道采取现代已经当今本身个黑连接作战分为少年决定变成日至尤其国内改名对手公开变化年因了围棋三段秀哉特定年台为围公开依照类似年共象棋重视届应年以是围棋出现虽然睦镇硕是由特殊进入段和研究进行目前称作年才黄奕中这些周睿羊名为年获年至年和年到年由年中其他采用芈昱廷时越发展当时每方比赛'

# %%
filtered_lst=[]
ruled_out=[]
for i in range(len(lst)):
    sentence=pseg.cut(lst[i][0])
    condition=True
    for w in sentence:
        if w.flag not in ['n','nz','nt','nr','ns','nw']:
            condition=False
    if condition==True:
        filtered_lst.append([lst[i][0],lst[i][1]])
    else:
        ruled_out.append([lst[i][0],lst[i][1]])

# %%
filtered_lst
# Out:
# [['方圓社', 117],
#  ['江流儿', 90],
#  ['雷凌云', 63],
#  ['江流', 56],
#  ['云子', 52],
#  ['小林光', 51],
#  ['赛冠军', 42],
#  ['韩元', 38],
#  ['小光', 38],
#  ['棋盘', 34],
#  ['棋形', 34],
#  ['棋鬼王', 33],
#  ['王戰', 33],
#  ['桐山杯', 33],
#  ['樊麾', 33],
#  ['区', 32],
#  ['方圓', 32],
#  ['方棋子', 30],
#  ['国棋院', 30],
#  ['海峰棋院', 30],
#  ['定段', 28],
#  ['方胜', 28],
#  ['制度', 28],
#  ['中国', 28],
#  ['女子', 28],
#  ['山城宏', 27],
#  ['黄龙士', 27],
#  ['棋圣', 26],
#  ['名单', 26],
#  ['陈祖德', 26],
#  ['参赛', 26],
#  ['黑棋', 26],
#  ['模樣', 26],
#  ['颗子', 24],
#  ['妖刀', 24],
#  ['中华台北', 24],
#  ['王晨星', 24],
#  ['項目', 24],
#  ['提子', 24],
#  ['卫平', 24],
#  ['出线', 24],
#  ['职业棋', 24],
#  ['棋協會', 24],
#  ['决赛', 24],
#  ['台灣棋', 24],
#  ['本赛', 24],
#  ['劫材', 22],
#  ['天元战', 22],
#  ['白昕卉', 22],
#  ['歐洲', 22],
#  ['连胜', 22],
#  ['对抗赛', 22],
#  ['国流', 22],
#  ['弟子', 22],
#  ['規則', 22],
#  ['女子棋', 21],
#  ['国际象', 21],
#  ['刀定式', 21],
#  ['职业棋手', 21],
#  ['正官庄杯', 21],
#  ['国棋手', 21],
#  ['宇宙流', 21],
#  ['關西棋院', 21],
#  ['職業棋手', 21],
#  ['職業棋士', 21],
#  ['財團法人', 21],
#  ['時代', 20],
#  ['人戰', 20],
#  ['聂卫', 20],
#  ['腾讯', 20],
#  ['吴清源', 20],
#  ['聖戰', 20],
#  ['賽制', 20],
#  ['聯盟', 20],
#  ['步棋', 20],
#  ['交流', 20],
#  ['国业', 20],
#  ['定式', 20],
#  ['表团', 20],
#  ['赛制', 20],
#  ['复杂性', 20],
#  ['段位制', 20],
#  ['赛事', 20],
#  ['厚勢', 20],
#  ['关西', 20],
#  ['目的', 20],
#  ['赛区', 20],
#  ['情况', 20],
#  ['中盤', 20],
#  ['技术', 20],
#  ['時間', 20],
#  ['昭和', 20],
#  ['日本', 20],
#  ['世界', 20],
#  ['黑嘉嘉', 18],
#  ['女子组', 18],
#  ['小林觉', 18],
#  ['赛棋手', 18],
#  ['楊子萱', 18],
#  ['女流名人', 18],
#  ['外勢', 18],
#  ['胜率', 18],
#  ['全国性', 18],
#  ['理光', 18],
#  ['飛刀', 18],
#  ['國手', 18],
#  ['国女子', 18],
#  ['視台', 18],
#  ['男棋手', 18],
#  ['崔哲瀚', 18],
#  ['亞軍', 18],
#  ['黃士', 18],
#  ['道策', 18],
#  ['棋世界', 18],
#  ['电王战', 18],
#  ['方用时', 18],
#  ['规则', 18],
#  ['圣战', 18],
#  ['读秒', 18],
#  ['棋協', 18],
#  ['安節', 18],
#  ['专家', 18],
#  ['出场', 18],
#  ['挑战赛', 18],
#  ['李小溪', 18],
#  ['腾讯野', 18],
#  ['世纪', 18],
#  ['国手战', 18],
#  ['互联网', 18],
#  ['数子', 18],
#  ['數子法', 18],
#  ['广州', 18],
#  ['陈浩', 18],
#  ['年度', 18],
#  ['棋水平', 18],
#  ['网络', 18],
#  ['国规则', 18],
#  ['守角', 18],
#  ['浙江', 18],
#  ['棋圣战', 18],
#  ['職業棋', 18],
#  ['阿含', 18],
#  ['決賽', 18],
#  ['日本棋院', 18],
#  ['局面', 18],
#  ['董彦', 18],
#  ['韓國棋院', 18],
#  ['棋协会', 18],
#  ['国家体', 18],
#  ['李世石', 18],
#  ['韩国', 18],
#  ['頭銜', 18],
#  ['金志锡', 18],
#  ['實力', 18],
#  ['網路', 18],
#  ['国队', 18],
#  ['游戏', 18],
#  ['中央', 18],
#  ['日本棋', 18],
#  ['優勢', 18],
#  ['台灣棋院', 18],
#  ['中國', 18],
#  ['台灣', 18],
#  ['唐韋星', 16],
#  ['挑战者', 16],
#  ['天台', 16],
#  ['岩本', 16],
#  ['張凱馨', 16],
#  ['丹朱', 16],
#  ['男子组', 16],
#  ['擂台赛', 16],
#  ['灵杯', 16],
#  ['黑子', 16],
#  ['资格赛', 16],
#  ['正夫', 16],
#  ['半决赛', 16],
#  ['國流', 16],
#  ['中盘', 16],
#  ['级分', 16],
#  ['国手', 16],
#  ['成绩', 16],
#  ['重庆', 16],
#  ['黑龙江', 16],
#  ['晏天章', 16],
#  ['背景', 16],
#  ['围棋赛', 16],
#  ['王积薪', 16],
#  ['对局', 16],
#  ['数据', 16],
#  ['跡目', 16],
#  ['弈秋', 16],
#  ['个人赛', 16],
#  ['因坊', 16],
#  ['氏杯', 16],
#  ['能力', 16],
#  ['元老', 16],
#  ['顶尖', 16],
#  ['国象', 16],
#  ['貼目', 16],
#  ['智能', 16],
#  ['网格', 16],
#  ['利益', 16],
#  ['马晓春', 16],
#  ['局', 16],
#  ['技巧', 16],
#  ['杭州', 16],
#  ['棋賽', 16],
#  ['公開賽', 16],
#  ['围棋队', 16],
#  ['落子', 16],
#  ['蒙地', 16],
#  ['全国', 16],
#  ['崔精', 16],
#  ['李昌鎬', 16],
#  ['演算法', 16],
#  ['浙江省', 16],
#  ['藤泽', 16],
#  ['富士通杯', 16],
#  ['將棋', 16],
#  ['階段', 16],
#  ['宋容慧', 16],
#  ['電腦', 16],
#  ['卞相', 16],
#  ['朴永训', 16],
#  ['原本', 16],
#  ['優勝', 16],
#  ['情況', 16],
#  ['唐韦星', 16],
#  ['冠军', 16],
#  ['廣島', 14],
#  ['甘肃', 14],
#  ['楊子', 14],
#  ['刘小光', 14],
#  ['橋本', 14],
#  ['城围', 14],
#  ['邱峻', 14],
#  ['赵南哲', 14],
#  ['玩家', 14],
#  ['名誉', 14],
#  ['霸王', 14],
#  ['雙人', 14],
#  ['家康', 14],
#  ['网棋', 14],
#  ['金明训', 14],
#  ['团体赛', 14],
#  ['海峰', 14],
#  ['手棋', 14],
#  ['棋王赛', 14],
#  ['黄龙', 14],
#  ['名人战', 14],
#  ['预选赛', 14],
#  ['姜堰', 14],
#  ['小飛', 14],
#  ['国家队', 14],
#  ['方式', 14],
#  ['工智', 14],
#  ['国棋', 14],
#  ['單位', 14],
#  ['传说', 14],
#  ['網站', 14],
#  ['国职', 14],
#  ['政府', 14],
#  ['棋牌', 14],
#  ['參數', 14],
#  ['全部', 14],
#  ['实际', 14],
#  ['计数', 14],
#  ['台赛', 14],
#  ['实力', 14],
#  ['棋艺', 14],
#  ['领域', 14],
#  ['距離', 14],
#  ['周俊勳', 14],
#  ['种子', 14],
#  ['获胜者', 14],
#  ['棋戰', 14],
#  ['人数', 14],
#  ['意思', 14],
#  ['范西屏', 14],
#  ['手合', 14],
#  ['周俊', 14],
#  ['中環', 14],
#  ['周俊勋', 14],
#  ['生涯', 14],
#  ['名将', 14],
#  ['方可', 14],
#  ['罗玄', 14],
#  ['方捷', 14],
#  ['男子', 14],
#  ['林海峰', 14],
#  ['国务', 14],
#  ['優勝者', 14],
#  ['版本', 14],
#  ['段位', 14],
#  ['資源', 14],
#  ['券杯', 14],
#  ['名譽', 14],
#  ['武宮', 14],
#  ['高目', 14],
#  ['方先', 14],
#  ['小时', 14],
#  ['星位', 14],
#  ['丁浩', 14],
#  ['目數', 14],
#  ['弈城', 14],
#  ['亚军', 14],
#  ['业围', 14],
#  ['黑方', 14],
#  ['個角', 14],
#  ['機會', 14],
#  ['陳耀燁', 14],
#  ['芮乃伟', 14],
#  ['棋局', 14],
#  ['全局', 14],
#  ['林家', 14],
#  ['交叉', 14],
#  ['帳號', 14],
#  ['棋具', 14],
#  ['結果', 14],
#  ['應氏', 14],
#  ['掛角', 14],
#  ['奖金', 14],
#  ['棋战', 14],
#  ['公司', 14],
#  ['黑貼', 14],
#  ['张璇', 14],
#  ['大学', 14],
#  ['北京', 14],
#  ['范廷鈺', 14],
#  ['野狐', 14],
#  ['日文', 14],
#  ['常昊', 14],
#  ['坂田', 14],
#  ['論文', 14],
#  ['罗洗河', 14],
#  ['過程', 14],
#  ['布局', 14],
#  ['朴廷桓', 14],
#  ['曹薰铉', 14],
#  ['目数', 14],
#  ['俞斌', 14],
#  ['刘星', 14],
#  ['獎金', 14],
#  ['冠軍', 14],
#  ['棋譜', 14],
#  ['刘昌赫', 14],
#  ['胜者', 14],
#  ['世紀', 14],
#  ['党毅飞', 14],
#  ['江维杰', 14],
#  ['棋手', 14],
#  ['业余', 14],
#  ['范廷钰', 14],
#  ['棋子', 14],
#  ['棋盤', 14],
#  ['国际', 14],
#  ['聂卫平', 12],
#  ['贴目', 12],
#  ['晋级', 12],
#  ['瀨越', 12],
#  ['專案', 12],
#  ['俘子', 12],
#  ['柯潔', 12],
#  ['本戰', 12],
#  ['绝艺', 12],
#  ['王座', 12],
#  ['新布石', 12],
#  ['應昌', 12],
#  ['收官', 12],
#  ['位棋', 12],
#  ['白方', 12],
#  ['亚洲', 12],
#  ['主将', 12],
#  ['李昌镐', 12],
#  ['江戶', 12],
#  ['朴志恩', 12],
#  ['开局', 12],
#  ['职业', 12],
#  ['衢州市', 12],
#  ['段胜', 12],
#  ['產生', 12],
#  ['金荣', 12],
#  ['豐田', 12],
#  ['武汉', 12],
#  ['單敗', 12],
#  ['江苏', 12],
#  ['白子', 12],
#  ['棋經', 12],
#  ['人類', 12],
#  ['个人', 12],
#  ['人围', 12],
#  ['軟體', 12],
#  ['衢州', 12],
#  ['关东', 12],
#  ['團隊', 12],
#  ['棋品', 12],
#  ['数学', 12],
#  ['服务器', 12],
#  ['淘汰赛', 12],
#  ['重要性', 12],
#  ['俱乐部', 12],
#  ['赵晨宇', 12],
#  ['業圍', 12],
#  ['酒店', 12],
#  ['全國', 12],
#  ['本学', 12],
#  ['实业', 12],
#  ['南京', 12],
#  ['团队', 12],
#  ['中学', 12],
#  ['原因', 12],
#  ['李东勋', 12],
#  ['富士', 12],
#  ['程度', 12],
#  ['陕西', 12],
#  ['全运', 12],
#  ['日程', 12],
#  ['東京', 12],
#  ['规定', 12],
#  ['方一', 12],
#  ['江维', 12],
#  ['佛乘', 12],
#  ['德川', 12],
#  ['东京', 12],
#  ['歷史', 12],
#  ['坊門', 12],
#  ['利用', 12],
#  ['台北', 12],
#  ['成员', 12],
#  ['己方', 12],
#  ['外卡', 12],
#  ['高校', 12],
#  ['小组', 12],
#  ['分數', 12],
#  ['定石', 12],
#  ['香港', 12],
#  ['女流', 12],
#  ['际象', 12],
#  ['平面', 12],
#  ['直线', 12],
#  ['阶段', 12],
#  ['豐田杯', 12],
#  ['資料', 12],
#  ['棋赛', 12],
#  ['工程', 12],
#  ['上海', 12],
#  ['专业', 12],
#  ['快棋', 12],
#  ['立於', 12],
#  ['山东', 12],
#  ['同名', 12],
#  ['局棋', 12],
#  ['结果', 12],
#  ['丁烈', 12],
#  ['人机', 12],
#  ['加藤', 12],
#  ['錦標賽', 12],
#  ['丁明君', 12],
#  ['伺服器', 12],
#  ['无锡市', 12],
#  ['數子', 12],
#  ['分散式', 12],
#  ['使用者', 12],
#  ['团体', 12],
#  ['程式', 12],
#  ['电视', 12],
#  ['家督', 12],
#  ['白棋', 12],
#  ['實利', 12],
#  ['晚报', 12],
#  ['安井', 12],
#  ['大赛', 12],
#  ['協會', 12],
#  ['團體', 12],
#  ['例子', 12],
#  ['日本队', 12],
#  ['郭闻潮', 12],
#  ['棋坛', 12],
#  ['策略', 12],
#  ['曹薰', 12],
#  ['男女', 12],
#  ['征子', 12],
#  ['原子', 12],
#  ['秀策', 12],
#  ['方用', 12],
#  ['秀行', 12],
#  ['风格', 12],
#  ['手数', 12],
#  ['官方', 12],
#  ['業餘', 12],
#  ['王世', 12],
#  ['国围', 12],
#  ['范胤', 12],
#  ['官子', 12],
#  ['赵治勋', 12],
#  ['本年度', 12],
#  ['终局', 12],
#  ['木谷', 12],
#  ['內容', 12],
#  ['國際', 12],
#  ['广西', 12],
#  ['曹大元', 12],
#  ['冠亚军', 12],
#  ['織田', 12],
#  ['广东', 12],
#  ['年围', 12],
#  ['西洋棋', 12],
#  ['職業圍', 12],
#  ['中日韩', 12],
#  ['杭州市', 12],
#  ['严欢', 12],
#  ['李康', 12],
#  ['活棋', 12],
#  ['胡耀宇', 12],
#  ['國際賽', 12],
#  ['传统', 12],
#  ['城市', 12],
#  ['局部', 12],
#  ['古灵益', 12],
#  ['地區', 12],
#  ['兒子', 12],
#  ['秀甫', 12],
#  ['本局', 12],
#  ['云南', 12],
#  ['安冬旭', 12],
#  ['奧林匹亞', 12],
#  ['安井家', 12],
#  ['形態', 12],
#  ['周泓余', 12],
#  ['勝率', 12],
#  ['佟禹林', 12],
#  ['時候', 12],
#  ['連勝', 12],
#  ['人民', 12],
#  ['關西', 12],
#  ['成績', 12],
#  ['孔杰', 12],
#  ['遊戲', 12],
#  ['蔡竞', 12],
#  ['丁伟', 12],
#  ['彭荃', 12],
#  ['價值', 12],
#  ['王磊', 12],
#  ['本賽', 12],
#  ['棋界', 12],
#  ['战胜', 12],
#  ['电脑', 12],
#  ['世本', 12],
#  ['行棋', 12],
#  ['范蕴若', 12],
#  ['賽事', 12],
#  ['人赛', 12],
#  ['檀啸', 12],
#  ['时间', 12],
#  ['英文', 12],
#  ['姜东润', 12],
#  ['韓國', 12],
#  ['国家', 12],
#  ['棋王', 12],
#  ['雙方', 12],
#  ['柯洁', 12],
#  ['女棋手', 12],
#  ['棋院', 12],
#  ['连笑', 12],
#  ['陈耀烨', 12],
#  ['谢赫', 12],
#  ['周鹤洋', 12],
#  ['棋力', 12],
#  ['棋士', 12],
#  ['職業', 12],
#  ['古力', 12],
#  ['', 10],
#  ['', 9],
#  ['', 9],
#  ['', 7],
#  ['', 7]]

# %%
ruled_out
# Out:
# [['元人', 48],
#  ['对局者', 42],
#  ['组', 36],
#  ['御城棋', 33],
#  ['之一', 31],
#  ['杯冠军', 26],
#  ['雙人圍', 24],
#  ['後來', 24],
#  ['如果', 24],
#  ['丈和', 23],
#  ['名人賽', 22],
#  ['比目法', 22],
#  ['先手', 22],
#  ['年全', 22],
#  ['由於', 22],
#  ['對局', 22],
#  ['中國圍棋', 22],
#  ['棋聖戰', 21],
#  ['齐鲁晚', 20],
#  ['轮败者', 20],
#  ['俞俐均', 20],
#  ['队和', 20],
#  ['頭銜者', 20],
#  ['為名人', 20],
#  ['年日本', 20],
#  ['之後', 20],
#  ['本因坊', 20],
#  ['王座戰', 18],
#  ['朴鋕恩', 18],
#  ['赛于', 18],
#  ['辜梓豪', 18],
#  ['定段赛', 16],
#  ['强败者', 16],
#  ['因碩', 16],
#  ['1轮', 16],
#  ['黄河杯', 16],
#  ['棋聖', 16],
#  ['奖金为', 16],
#  ['网选', 16],
#  ['基金會', 16],
#  ['選拔賽', 16],
#  ['對戰', 16],
#  ['2轮', 16],
#  ['為台灣', 16],
#  ['限公', 16],
#  ['電腦圍', 16],
#  ['江铸久', 16],
#  ['大飛', 16],
#  ['台灣圍棋', 16],
#  ['是台灣', 16],
#  ['三番棋', 16],
#  ['唐奕', 16],
#  ['李轩豪', 16],
#  ['限公司', 16],
#  ['赞助', 15],
#  ['其中', 15],
#  ['淡路修', 14],
#  ['圍棋界', 14],
#  ['朝日新', 14],
#  ['队获得', 14],
#  ['挑戰者', 14],
#  ['李世乭', 14],
#  ['決定戰', 14],
#  ['為日本', 14],
#  ['还棋头', 14],
#  ['人以', 14],
#  ['日本圍', 14],
#  ['後黑', 14],
#  ['名棋手', 14],
#  ['圍棋賽', 14],
#  ['世界第', 14],
#  ['職業圍棋', 14],
#  ['業棋士', 14],
#  ['女子围', 14],
#  ['程式碼', 14],
#  ['本赛第', 14],
#  ['指围棋', 14],
#  ['秀和', 14],
#  ['和韩', 14],
#  ['职业围棋', 14],
#  ['朴文垚', 14],
#  ['全日本', 14],
#  ['为世界', 14],
#  ['对局费', 14],
#  ['日本围', 14],
#  ['是日本', 14],
#  ['後因', 14],
#  ['木谷實', 14],
#  ['陶欣然', 14],
#  ['井山裕太', 14],
#  ['開始', 14],
#  ['位棋手', 14],
#  ['轮于', 13],
#  ['劫爭', 13],
#  ['組織', 13],
#  ['预选', 13],
#  ['开发', 13],
#  ['周睿', 13],
#  ['停辦', 13],
#  ['本因', 13],
#  ['臺北市', 12],
#  ['荒木氏', 12],
#  ['决赛第', 12],
#  ['强败者获', 12],
#  ['通算', 12],
#  ['农心杯', 12],
#  ['只棋子', 12],
#  ['年代表', 12],
#  ['南韓首爾', 12],
#  ['混双赛', 12],
#  ['網路圍', 12],
#  ['余棋手', 12],
#  ['當作', 12],
#  ['座戰', 12],
#  ['负李', 12],
#  ['耀烨', 12],
#  ['杯世界', 12],
#  ['国参加', 12],
#  ['镇围棋', 12],
#  ['家家督', 12],
#  ['此頭銜', 12],
#  ['杯本赛', 12],
#  ['中國圍', 12],
#  ['本棋院', 12],
#  ['棋院和', 12],
#  ['内围棋', 12],
#  ['世本因', 12],
#  ['段位的', 12],
#  ['市围棋', 12],
#  ['將棋界', 12],
#  ['假眼活', 12],
#  ['元战', 12],
#  ['院和', 12],
#  ['佔角', 12],
#  ['為台', 12],
#  ['之莹', 12],
#  ['通过', 12],
#  ['之父', 12],
#  ['棋以', 12],
#  ['单败淘', 12],
#  ['扇興杯', 12],
#  ['名人戰', 12],
#  ['围棋名人战', 12],
#  ['讀賣新聞', 12],
#  ['对弈', 12],
#  ['张馨月', 12],
#  ['顾水如', 12],
#  ['决赛中', 12],
#  ['新布局', 12],
#  ['日本的', 12],
#  ['许嘉阳', 12],
#  ['世界最', 12],
#  ['情況下', 12],
#  ['以後', 12],
#  ['种子选', 12],
#  ['队以', 12],
#  ['围棋规则', 12],
#  ['番棋', 12],
#  ['算砂', 12],
#  ['李喆', 12],
#  ['读秒的', 12],
#  ['分鐘', 12],
#  ['棋手在', 12],
#  ['柁嘉熹', 12],
#  ['围棋协会', 12],
#  ['圍棋協', 12],
#  ['职业围', 12],
#  ['吳清源', 12],
#  ['棋盤上', 12],
#  ['申真谞', 12],
#  ['国际围', 12],
#  ['国围棋', 12],
#  ['杨鼎新', 12],
#  ['用时', 12],
#  ['规则与', 12],
#  ['佈局', 12],
#  ['對方', 12],
#  ['4子', 12],
#  ['联棋', 11],
#  ['其它', 11],
#  ['應用', 11],
#  ['创办', 11],
#  ['運用', 11],
#  ['才能', 11],
#  ['屆起', 11],
#  ['按照', 11],
#  ['擊敗', 11],
#  ['初段', 11],
#  ['年代', 11],
#  ['首轮', 11],
#  ['以下', 11],
#  ['同時', 11],
#  ['围棋', 11],
#  ['deepmind', 10],
#  ['打劫', 10],
#  ['经过', 10],
#  ['vs', 10],
#  ['最高', 10],
#  ['真眼', 10],
#  ['可能', 10],
#  ['变得', 10],
#  ['佐為', 10],
#  ['贊助', 10],
#  ['中日', 10],
#  ['之間', 10],
#  ['整个', 10],
#  ['叫吃', 10],
#  ['联合', 10],
#  ['達到', 10],
#  ['比赛中', 10],
#  ['成為', 10],
#  ['保留', 10],
#  ['攻擊', 10],
#  ['小目', 10],
#  ['比較', 10],
#  ['以上', 10],
#  ['根据', 10],
#  ['年第', 10],
#  ['本届', 9],
#  ['年道', 9],
#  ['任中', 9],
#  ['复赛', 9],
#  ['聯', 9],
#  ['學習', 9],
#  ['际象棋', 9],
#  ['负', 9],
#  ['下午', 9],
#  ['日', 9],
#  ['推广', 9],
#  ['透過', 9],
#  ['体育', 9],
#  ['運算', 9],
#  ['这种', 9],
#  ['显著', 9],
#  ['每年', 9],
#  ['提升', 9],
#  ['消劫', 9],
#  ['知得', 9],
#  ['为', 9],
#  ['包圍', 9],
#  ['通常', 9],
#  ['舉辦', 9],
#  ['对于', 9],
#  ['淘汰賽', 9],
#  ['年日', 9],
#  ['综合', 9],
#  ['為了', 9],
#  ['發行', 9],
#  ['直播', 9],
#  ['參加', 9],
#  ['首次', 9],
#  ['类似', 9],
#  ['影响', 9],
#  ['或者', 9],
#  ['年间', 9],
#  ['元晟溱', 9],
#  ['采用', 9],
#  ['認為', 9],
#  ['特別', 9],
#  ['年开', 9],
#  ['這些', 9],
#  ['开始', 9],
#  ['以及', 9],
#  ['循环圈', 8],
#  ['本身劫', 8],
#  ['中環盃', 8],
#  ['深入', 8],
#  ['年為', 8],
#  ['得到', 8],
#  ['目外', 8],
#  ['导致', 8],
#  ['混双', 8],
#  ['主办', 8],
#  ['申旻埈', 8],
#  ['目半', 8],
#  ['负于', 8],
#  ['勝制', 8],
#  ['獲得', 8],
#  ['複雜', 8],
#  ['是围棋', 8],
#  ['邀请', 8],
#  ['設定', 8],
#  ['工作', 8],
#  ['宣布', 8],
#  ['坐标', 8],
#  ['達成', 8],
#  ['连续', 8],
#  ['受到', 8],
#  ['打入', 8],
#  ['彼此', 8],
#  ['胜出', 8],
#  ['6日', 8],
#  ['釋出', 8],
#  ['小時', 8],
#  ['同时', 8],
#  ['互相', 8],
#  ['这样', 8],
#  ['主要', 8],
#  ['安排', 8],
#  ['胜负', 8],
#  ['對弈', 8],
#  ['发生', 8],
#  ['9x9', 8],
#  ['國內', 8],
#  ['执黑', 8],
#  ['任何', 8],
#  ['三子', 8],
#  ['非常', 8],
#  ['選手', 8],
#  ['圍棋棋', 8],
#  ['等级', 8],
#  ['位置', 8],
#  ['自己的', 8],
#  ['发展', 8],
#  ['多数', 8],
#  ['然而', 8],
#  ['此時', 8],
#  ['讓子', 8],
#  ['始于', 8],
#  ['這個', 8],
#  ['首届', 8],
#  ['下法', 8],
#  ['稱為', 8],
#  ['比賽', 8],
#  ['年起', 8],
#  ['使用', 8],
#  ['圍棋', 8],
#  ['預選', 7],
#  ['碁聖', 7],
#  ['免选', 7],
#  ['过惕生', 7],
#  ['天元', 7],
#  ['謝依旻', 7],
#  ['十一', 7],
#  ['賽進行', 7],
#  ['10万', 7],
#  ['正式', 7],
#  ['排名', 7],
#  ['中方', 7],
#  ['曾经', 7],
#  ['9日', 7],
#  ['组合', 7],
#  ['年底', 7],
#  ['选手', 7],
#  ['着法', 7],
#  ['分析', 7],
#  ['自我訓練', 7],
#  ['研究的', 7],
#  ['段以', 7],
#  ['最佳', 7],
#  ['高段', 7],
#  ['讀賣', 7],
#  ['中部', 7],
#  ['九段', 7],
#  ['各地', 7],
#  ['当时', 7],
#  ['之子', 7],
#  ['占据', 7],
#  ['1月1日', 7],
#  ['實做', 7],
#  ['2万', 7],
#  ['月', 7],
#  ['聞社', 7],
#  ['創立', 7],
#  ['附近', 7],
#  ['虽然', 7],
#  ['真露杯', 7],
#  ['對弈中', 7],
#  ['年間', 7],
#  ['元和', 7],
#  ['届比', 7],
#  ['改名為', 7],
#  ['挑戰', 7],
#  ['獲勝', 7],
#  ['造成', 7],
#  ['整個', 7],
#  ['长考', 7],
#  ['三三', 7],
#  ['繼承', 7],
#  ['處理', 7],
#  ['强赛', 7],
#  ['戰鬥', 7],
#  ['應對', 7],
#  ['發生', 7],
#  ['重要', 7],
#  ['推出', 7],
#  ['执白', 7],
#  ['這種', 7],
#  ['年舉', 7],
#  ['实战', 7],
#  ['比賽中', 7],
#  ['年改', 7],
#  ['某些', 7],
#  ['黑白', 7],
#  ['要求', 7],
#  ['抗赛', 7],
#  ['選擇', 7],
#  ['年舉辦', 7],
#  ['当时中', 7],
#  ['届起', 7],
#  ['至第', 7],
#  ['改為', 7],
#  ['年開', 7],
#  ['主辦', 7],
#  ['上届', 6],
#  ['等级分', 6],
#  ['訓練', 6],
#  ['擂台', 6],
#  ['分至', 6],
#  ['届中', 6],
#  ['codice', 6],
#  ['本选赛', 6],
#  ['執白', 6],
#  ['更具', 6],
#  ['碁聖戰', 6],
#  ['圍棋高', 6],
#  ['抽签', 6],
#  ['分先', 6],
#  ['最強', 6],
#  ['担任', 6],
#  ['屆本', 6],
#  ['击败', 6],
#  ['来自', 6],
#  ['下棋', 6],
#  ['引起', 6],
#  ['只能', 6],
#  ['禁止', 6],
#  ['羋昱廷', 6],
#  ['循环', 6],
#  ['獲勝者', 6],
#  ['挑战', 6],
#  ['亞藝盃', 6],
#  ['则是', 6],
#  ['杯围棋', 6],
#  ['围棋最', 6],
#  ['际围棋', 6],
#  ['围棋网', 6],
#  ['為本因', 6],
#  ['输给了', 6],
#  ['组成的', 6],
#  ['被视为', 6],
#  ['被叫做', 6],
#  ['位提白', 6],
#  ['之间', 6],
#  ['支援', 6],
#  ['同樣', 6],
#  ['模仿', 6],
#  ['三轮', 6],
#  ['再次', 6],
#  ['网上', 6],
#  ['則因', 6],
#  ['系列', 6],
#  ['预赛', 6],
#  ['长期', 6],
#  ['卡斯', 6],
#  ['比對', 6],
#  ['執黑', 6],
#  ['大小', 6],
#  ['世代', 6],
#  ['裁判', 6],
#  ['卡尔', 6],
#  ['12万', 6],
#  ['參考', 6],
#  ['循環', 6],
#  ['極其', 6],
#  ['世襲', 6],
#  ['本薰', 6],
#  ['升降', 6],
#  ['报名', 6],
#  ['赛前', 6],
#  ['连接', 6],
#  ['先前', 6],
#  ['手割', 6],
#  ['打算', 6],
#  ['十二', 6],
#  ['争夺', 6],
#  ['得第', 6],
#  ['29日', 6],
#  ['加以', 6],
#  ['很多', 6],
#  ['相鄰', 6],
#  ['停止', 6],
#  ['点', 6],
#  ['3日', 6],
#  ['将于', 6],
#  ['4日', 6],
#  ['下到', 6],
#  ['思考', 6],
#  ['放送', 6],
#  ['方各', 6],
#  ['則是', 6],
#  ['夺得', 6],
#  ['超過', 6],
#  ['改稱', 6],
#  ['强战', 6],
#  ['必須', 6],
#  ['formula', 6],
#  ['对围棋', 6],
#  ['得天元', 6],
#  ['赞助商', 6],
#  ['3月4日', 6],
#  ['世乭', 6],
#  ['淘汰', 6],
#  ['获得', 6],
#  ['存在', 6],
#  ['举办的', 6],
#  ['年年', 6],
#  ['位', 6],
#  ['日和', 6],
#  ['年獲', 6],
#  ['选拔', 6],
#  ['計算', 6],
#  ['日围棋', 6],
#  ['围棋大', 6],
#  ['为围棋', 6],
#  ['年取', 6],
#  ['為圍棋', 6],
#  ['抗賽', 6],
#  ['报道', 6],
#  ['采取', 6],
#  ['现代', 6],
#  ['已經', 6],
#  ['当今', 6],
#  ['本身', 6],
#  ['個黑', 6],
#  ['連接', 6],
#  ['作戰', 6],
#  ['分為', 6],
#  ['少年', 6],
#  ['決定', 6],
#  ['變成', 6],
#  ['日至', 6],
#  ['尤其', 6],
#  ['国内', 6],
#  ['改名', 6],
#  ['對手', 6],
#  ['公开', 6],
#  ['變化', 6],
#  ['年因', 6],
#  ['了围棋', 6],
#  ['三段', 6],
#  ['秀哉', 6],
#  ['特定', 6],
#  ['年台', 6],
#  ['为围', 6],
#  ['公開', 6],
#  ['依照', 6],
#  ['類似', 6],
#  ['年共', 6],
#  ['象棋', 6],
#  ['重視', 6],
#  ['届应', 6],
#  ['年以', 6],
#  ['是圍棋', 6],
#  ['出現', 6],
#  ['雖然', 6],
#  ['睦镇硕', 6],
#  ['是由', 6],
#  ['特殊', 6],
#  ['進入', 6],
#  ['段和', 6],
#  ['研究', 6],
#  ['進行', 6],
#  ['目前', 6],
#  ['稱作', 6],
#  ['年才', 6],
#  ['黄奕中', 6],
#  ['这些', 6],
#  ['周睿羊', 6],
#  ['名為', 6],
#  ['年获', 6],
#  ['年至', 6],
#  ['年和', 6],
#  ['年到', 6],
#  ['年由', 6],
#  ['年中', 6],
#  ['其他', 6],
#  ['採用', 6],
#  ['芈昱廷', 6],
#  ['时越', 6],
#  ['發展', 6],
#  ['當時', 6],
#  ['每方', 6],
#  ['比赛', 6]]

# %%
len(filtered_lst)
# Out:
# 576

# %%
len(ruled_out)
# Out:
# 584

# %%
def remove_space(lst):
    newlst=[]
    for i in range(len(lst)):
        if lst[i][0]=='':
            pass
        else:
            newlst.append([lst[i][0],lst[i][1]])
    return newlst
filtered_lst=remove_space(filtered_lst)
filtered_lst
# Out:
# [['方圓社', 117],
#  ['江流儿', 90],
#  ['雷凌云', 63],
#  ['江流', 56],
#  ['云子', 52],
#  ['小林光', 51],
#  ['赛冠军', 42],
#  ['韩元', 38],
#  ['小光', 38],
#  ['棋盘', 34],
#  ['棋形', 34],
#  ['棋鬼王', 33],
#  ['王戰', 33],
#  ['桐山杯', 33],
#  ['樊麾', 33],
#  ['区', 32],
#  ['方圓', 32],
#  ['方棋子', 30],
#  ['国棋院', 30],
#  ['海峰棋院', 30],
#  ['定段', 28],
#  ['方胜', 28],
#  ['制度', 28],
#  ['中国', 28],
#  ['女子', 28],
#  ['山城宏', 27],
#  ['黄龙士', 27],
#  ['棋圣', 26],
#  ['名单', 26],
#  ['陈祖德', 26],
#  ['参赛', 26],
#  ['黑棋', 26],
#  ['模樣', 26],
#  ['颗子', 24],
#  ['妖刀', 24],
#  ['中华台北', 24],
#  ['王晨星', 24],
#  ['項目', 24],
#  ['提子', 24],
#  ['卫平', 24],
#  ['出线', 24],
#  ['职业棋', 24],
#  ['棋協會', 24],
#  ['决赛', 24],
#  ['台灣棋', 24],
#  ['本赛', 24],
#  ['劫材', 22],
#  ['天元战', 22],
#  ['白昕卉', 22],
#  ['歐洲', 22],
#  ['连胜', 22],
#  ['对抗赛', 22],
#  ['国流', 22],
#  ['弟子', 22],
#  ['規則', 22],
#  ['女子棋', 21],
#  ['国际象', 21],
#  ['刀定式', 21],
#  ['职业棋手', 21],
#  ['正官庄杯', 21],
#  ['国棋手', 21],
#  ['宇宙流', 21],
#  ['關西棋院', 21],
#  ['職業棋手', 21],
#  ['職業棋士', 21],
#  ['財團法人', 21],
#  ['時代', 20],
#  ['人戰', 20],
#  ['聂卫', 20],
#  ['腾讯', 20],
#  ['吴清源', 20],
#  ['聖戰', 20],
#  ['賽制', 20],
#  ['聯盟', 20],
#  ['步棋', 20],
#  ['交流', 20],
#  ['国业', 20],
#  ['定式', 20],
#  ['表团', 20],
#  ['赛制', 20],
#  ['复杂性', 20],
#  ['段位制', 20],
#  ['赛事', 20],
#  ['厚勢', 20],
#  ['关西', 20],
#  ['目的', 20],
#  ['赛区', 20],
#  ['情况', 20],
#  ['中盤', 20],
#  ['技术', 20],
#  ['時間', 20],
#  ['昭和', 20],
#  ['日本', 20],
#  ['世界', 20],
#  ['黑嘉嘉', 18],
#  ['女子组', 18],
#  ['小林觉', 18],
#  ['赛棋手', 18],
#  ['楊子萱', 18],
#  ['女流名人', 18],
#  ['外勢', 18],
#  ['胜率', 18],
#  ['全国性', 18],
#  ['理光', 18],
#  ['飛刀', 18],
#  ['國手', 18],
#  ['国女子', 18],
#  ['視台', 18],
#  ['男棋手', 18],
#  ['崔哲瀚', 18],
#  ['亞軍', 18],
#  ['黃士', 18],
#  ['道策', 18],
#  ['棋世界', 18],
#  ['电王战', 18],
#  ['方用时', 18],
#  ['规则', 18],
#  ['圣战', 18],
#  ['读秒', 18],
#  ['棋協', 18],
#  ['安節', 18],
#  ['专家', 18],
#  ['出场', 18],
#  ['挑战赛', 18],
#  ['李小溪', 18],
#  ['腾讯野', 18],
#  ['世纪', 18],
#  ['国手战', 18],
#  ['互联网', 18],
#  ['数子', 18],
#  ['數子法', 18],
#  ['广州', 18],
#  ['陈浩', 18],
#  ['年度', 18],
#  ['棋水平', 18],
#  ['网络', 18],
#  ['国规则', 18],
#  ['守角', 18],
#  ['浙江', 18],
#  ['棋圣战', 18],
#  ['職業棋', 18],
#  ['阿含', 18],
#  ['決賽', 18],
#  ['日本棋院', 18],
#  ['局面', 18],
#  ['董彦', 18],
#  ['韓國棋院', 18],
#  ['棋协会', 18],
#  ['国家体', 18],
#  ['李世石', 18],
#  ['韩国', 18],
#  ['頭銜', 18],
#  ['金志锡', 18],
#  ['實力', 18],
#  ['網路', 18],
#  ['国队', 18],
#  ['游戏', 18],
#  ['中央', 18],
#  ['日本棋', 18],
#  ['優勢', 18],
#  ['台灣棋院', 18],
#  ['中國', 18],
#  ['台灣', 18],
#  ['唐韋星', 16],
#  ['挑战者', 16],
#  ['天台', 16],
#  ['岩本', 16],
#  ['張凱馨', 16],
#  ['丹朱', 16],
#  ['男子组', 16],
#  ['擂台赛', 16],
#  ['灵杯', 16],
#  ['黑子', 16],
#  ['资格赛', 16],
#  ['正夫', 16],
#  ['半决赛', 16],
#  ['國流', 16],
#  ['中盘', 16],
#  ['级分', 16],
#  ['国手', 16],
#  ['成绩', 16],
#  ['重庆', 16],
#  ['黑龙江', 16],
#  ['晏天章', 16],
#  ['背景', 16],
#  ['围棋赛', 16],
#  ['王积薪', 16],
#  ['对局', 16],
#  ['数据', 16],
#  ['跡目', 16],
#  ['弈秋', 16],
#  ['个人赛', 16],
#  ['因坊', 16],
#  ['氏杯', 16],
#  ['能力', 16],
#  ['元老', 16],
#  ['顶尖', 16],
#  ['国象', 16],
#  ['貼目', 16],
#  ['智能', 16],
#  ['网格', 16],
#  ['利益', 16],
#  ['马晓春', 16],
#  ['局', 16],
#  ['技巧', 16],
#  ['杭州', 16],
#  ['棋賽', 16],
#  ['公開賽', 16],
#  ['围棋队', 16],
#  ['落子', 16],
#  ['蒙地', 16],
#  ['全国', 16],
#  ['崔精', 16],
#  ['李昌鎬', 16],
#  ['演算法', 16],
#  ['浙江省', 16],
#  ['藤泽', 16],
#  ['富士通杯', 16],
#  ['將棋', 16],
#  ['階段', 16],
#  ['宋容慧', 16],
#  ['電腦', 16],
#  ['卞相', 16],
#  ['朴永训', 16],
#  ['原本', 16],
#  ['優勝', 16],
#  ['情況', 16],
#  ['唐韦星', 16],
#  ['冠军', 16],
#  ['廣島', 14],
#  ['甘肃', 14],
#  ['楊子', 14],
#  ['刘小光', 14],
#  ['橋本', 14],
#  ['城围', 14],
#  ['邱峻', 14],
#  ['赵南哲', 14],
#  ['玩家', 14],
#  ['名誉', 14],
#  ['霸王', 14],
#  ['雙人', 14],
#  ['家康', 14],
#  ['网棋', 14],
#  ['金明训', 14],
#  ['团体赛', 14],
#  ['海峰', 14],
#  ['手棋', 14],
#  ['棋王赛', 14],
#  ['黄龙', 14],
#  ['名人战', 14],
#  ['预选赛', 14],
#  ['姜堰', 14],
#  ['小飛', 14],
#  ['国家队', 14],
#  ['方式', 14],
#  ['工智', 14],
#  ['国棋', 14],
#  ['單位', 14],
#  ['传说', 14],
#  ['網站', 14],
#  ['国职', 14],
#  ['政府', 14],
#  ['棋牌', 14],
#  ['參數', 14],
#  ['全部', 14],
#  ['实际', 14],
#  ['计数', 14],
#  ['台赛', 14],
#  ['实力', 14],
#  ['棋艺', 14],
#  ['领域', 14],
#  ['距離', 14],
#  ['周俊勳', 14],
#  ['种子', 14],
#  ['获胜者', 14],
#  ['棋戰', 14],
#  ['人数', 14],
#  ['意思', 14],
#  ['范西屏', 14],
#  ['手合', 14],
#  ['周俊', 14],
#  ['中環', 14],
#  ['周俊勋', 14],
#  ['生涯', 14],
#  ['名将', 14],
#  ['方可', 14],
#  ['罗玄', 14],
#  ['方捷', 14],
#  ['男子', 14],
#  ['林海峰', 14],
#  ['国务', 14],
#  ['優勝者', 14],
#  ['版本', 14],
#  ['段位', 14],
#  ['資源', 14],
#  ['券杯', 14],
#  ['名譽', 14],
#  ['武宮', 14],
#  ['高目', 14],
#  ['方先', 14],
#  ['小时', 14],
#  ['星位', 14],
#  ['丁浩', 14],
#  ['目數', 14],
#  ['弈城', 14],
#  ['亚军', 14],
#  ['业围', 14],
#  ['黑方', 14],
#  ['個角', 14],
#  ['機會', 14],
#  ['陳耀燁', 14],
#  ['芮乃伟', 14],
#  ['棋局', 14],
#  ['全局', 14],
#  ['林家', 14],
#  ['交叉', 14],
#  ['帳號', 14],
#  ['棋具', 14],
#  ['結果', 14],
#  ['應氏', 14],
#  ['掛角', 14],
#  ['奖金', 14],
#  ['棋战', 14],
#  ['公司', 14],
#  ['黑貼', 14],
#  ['张璇', 14],
#  ['大学', 14],
#  ['北京', 14],
#  ['范廷鈺', 14],
#  ['野狐', 14],
#  ['日文', 14],
#  ['常昊', 14],
#  ['坂田', 14],
#  ['論文', 14],
#  ['罗洗河', 14],
#  ['過程', 14],
#  ['布局', 14],
#  ['朴廷桓', 14],
#  ['曹薰铉', 14],
#  ['目数', 14],
#  ['俞斌', 14],
#  ['刘星', 14],
#  ['獎金', 14],
#  ['冠軍', 14],
#  ['棋譜', 14],
#  ['刘昌赫', 14],
#  ['胜者', 14],
#  ['世紀', 14],
#  ['党毅飞', 14],
#  ['江维杰', 14],
#  ['棋手', 14],
#  ['业余', 14],
#  ['范廷钰', 14],
#  ['棋子', 14],
#  ['棋盤', 14],
#  ['国际', 14],
#  ['聂卫平', 12],
#  ['贴目', 12],
#  ['晋级', 12],
#  ['瀨越', 12],
#  ['專案', 12],
#  ['俘子', 12],
#  ['柯潔', 12],
#  ['本戰', 12],
#  ['绝艺', 12],
#  ['王座', 12],
#  ['新布石', 12],
#  ['應昌', 12],
#  ['收官', 12],
#  ['位棋', 12],
#  ['白方', 12],
#  ['亚洲', 12],
#  ['主将', 12],
#  ['李昌镐', 12],
#  ['江戶', 12],
#  ['朴志恩', 12],
#  ['开局', 12],
#  ['职业', 12],
#  ['衢州市', 12],
#  ['段胜', 12],
#  ['產生', 12],
#  ['金荣', 12],
#  ['豐田', 12],
#  ['武汉', 12],
#  ['單敗', 12],
#  ['江苏', 12],
#  ['白子', 12],
#  ['棋經', 12],
#  ['人類', 12],
#  ['个人', 12],
#  ['人围', 12],
#  ['軟體', 12],
#  ['衢州', 12],
#  ['关东', 12],
#  ['團隊', 12],
#  ['棋品', 12],
#  ['数学', 12],
#  ['服务器', 12],
#  ['淘汰赛', 12],
#  ['重要性', 12],
#  ['俱乐部', 12],
#  ['赵晨宇', 12],
#  ['業圍', 12],
#  ['酒店', 12],
#  ['全國', 12],
#  ['本学', 12],
#  ['实业', 12],
#  ['南京', 12],
#  ['团队', 12],
#  ['中学', 12],
#  ['原因', 12],
#  ['李东勋', 12],
#  ['富士', 12],
#  ['程度', 12],
#  ['陕西', 12],
#  ['全运', 12],
#  ['日程', 12],
#  ['東京', 12],
#  ['规定', 12],
#  ['方一', 12],
#  ['江维', 12],
#  ['佛乘', 12],
#  ['德川', 12],
#  ['东京', 12],
#  ['歷史', 12],
#  ['坊門', 12],
#  ['利用', 12],
#  ['台北', 12],
#  ['成员', 12],
#  ['己方', 12],
#  ['外卡', 12],
#  ['高校', 12],
#  ['小组', 12],
#  ['分數', 12],
#  ['定石', 12],
#  ['香港', 12],
#  ['女流', 12],
#  ['际象', 12],
#  ['平面', 12],
#  ['直线', 12],
#  ['阶段', 12],
#  ['豐田杯', 12],
#  ['資料', 12],
#  ['棋赛', 12],
#  ['工程', 12],
#  ['上海', 12],
#  ['专业', 12],
#  ['快棋', 12],
#  ['立於', 12],
#  ['山东', 12],
#  ['同名', 12],
#  ['局棋', 12],
#  ['结果', 12],
#  ['丁烈', 12],
#  ['人机', 12],
#  ['加藤', 12],
#  ['錦標賽', 12],
#  ['丁明君', 12],
#  ['伺服器', 12],
#  ['无锡市', 12],
#  ['數子', 12],
#  ['分散式', 12],
#  ['使用者', 12],
#  ['团体', 12],
#  ['程式', 12],
#  ['电视', 12],
#  ['家督', 12],
#  ['白棋', 12],
#  ['實利', 12],
#  ['晚报', 12],
#  ['安井', 12],
#  ['大赛', 12],
#  ['協會', 12],
#  ['團體', 12],
#  ['例子', 12],
#  ['日本队', 12],
#  ['郭闻潮', 12],
#  ['棋坛', 12],
#  ['策略', 12],
#  ['曹薰', 12],
#  ['男女', 12],
#  ['征子', 12],
#  ['原子', 12],
#  ['秀策', 12],
#  ['方用', 12],
#  ['秀行', 12],
#  ['风格', 12],
#  ['手数', 12],
#  ['官方', 12],
#  ['業餘', 12],
#  ['王世', 12],
#  ['国围', 12],
#  ['范胤', 12],
#  ['官子', 12],
#  ['赵治勋', 12],
#  ['本年度', 12],
#  ['终局', 12],
#  ['木谷', 12],
#  ['內容', 12],
#  ['國際', 12],
#  ['广西', 12],
#  ['曹大元', 12],
#  ['冠亚军', 12],
#  ['織田', 12],
#  ['广东', 12],
#  ['年围', 12],
#  ['西洋棋', 12],
#  ['職業圍', 12],
#  ['中日韩', 12],
#  ['杭州市', 12],
#  ['严欢', 12],
#  ['李康', 12],
#  ['活棋', 12],
#  ['胡耀宇', 12],
#  ['國際賽', 12],
#  ['传统', 12],
#  ['城市', 12],
#  ['局部', 12],
#  ['古灵益', 12],
#  ['地區', 12],
#  ['兒子', 12],
#  ['秀甫', 12],
#  ['本局', 12],
#  ['云南', 12],
#  ['安冬旭', 12],
#  ['奧林匹亞', 12],
#  ['安井家', 12],
#  ['形態', 12],
#  ['周泓余', 12],
#  ['勝率', 12],
#  ['佟禹林', 12],
#  ['時候', 12],
#  ['連勝', 12],
#  ['人民', 12],
#  ['關西', 12],
#  ['成績', 12],
#  ['孔杰', 12],
#  ['遊戲', 12],
#  ['蔡竞', 12],
#  ['丁伟', 12],
#  ['彭荃', 12],
#  ['價值', 12],
#  ['王磊', 12],
#  ['本賽', 12],
#  ['棋界', 12],
#  ['战胜', 12],
#  ['电脑', 12],
#  ['世本', 12],
#  ['行棋', 12],
#  ['范蕴若', 12],
#  ['賽事', 12],
#  ['人赛', 12],
#  ['檀啸', 12],
#  ['时间', 12],
#  ['英文', 12],
#  ['姜东润', 12],
#  ['韓國', 12],
#  ['国家', 12],
#  ['棋王', 12],
#  ['雙方', 12],
#  ['柯洁', 12],
#  ['女棋手', 12],
#  ['棋院', 12],
#  ['连笑', 12],
#  ['陈耀烨', 12],
#  ['谢赫', 12],
#  ['周鹤洋', 12],
#  ['棋力', 12],
#  ['棋士', 12],
#  ['職業', 12],
#  ['古力', 12]]

# %%
len(filtered_lst)
# Out:
# 571

# %% [markdown]
# ## practice code below

# %%
#filter part
import jieba.posseg as pseg
lst2=[]
for i in range(len(lst)):
    sentence=pseg.cut(lst[i][0])
    lst2.append(sentence)
for i in range(len(lst2)):
    for w in lst2[i]:
        print(w.word,w.flag)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/5w/cbkbcc4x09q85s79vbdnh2vc0000gn/T/jieba.cache
# Loading model cost 0.936 seconds.
# Prefix dict has been built successfully.
# 定段 n
# 江流 ns
# 儿 n
# 雷 n
# 凌云 nr
# 云子 n
# 雙 m
# 人圍 n
# 江流 ns
# 劫材 n
# 对局 n
# 者 k
# 唐韋星 nr
# 方圓 n
# 社 n
# 棋 n
# 鬼王 n
# 定段 n
# 赛 v
# 轮于 v
# 天元战 nz
# 本届 r
# 循环 vn
# 圈 q
# 預選 v
# 齐鲁 nr
# 晚 tg
# 本身 r
# 劫 v
# 碁 yg
# 聖 j
# 强 a
# 败者 n
# deepmind eng
# 御 vg
# 城 n
# 棋 n
# 杯 q
# 冠军 n
# 時代 n
# 年 m
# 道 q
# 方胜 nr
# 廣島 ns
# 上届 j
# 免选 v
# 挑战者 n
# 黑嘉嘉 nr
# 淡路 n
# 修 v
# 天台 n
# 聂卫平 nr
# 任中 r
# 山城 ns
# 宏 n
# 等级分 l
# 贴目 n
# 臺 y
# 北 f
# 市 n
# 岩本 n
# 甘肃 ns
# 白昕卉 nr
# 張凱馨 nr
# 丈 q
# 和 c
# 晋级 nr
# 丹朱 nr
# 瀨越 ns
# 楊子 nr
# 因 p
# 碩 n
# 刘小光 nr
# 轮 zg
# 败者 n
# 1 m
# 轮 n
# 区 n
# 男子组 n
# 劫爭 vn
# 韩元 nr
# 女子组 n
# 小林觉 nr
# 擂台赛 ns
# 赛 nz
# 棋手 n
# 黄河 ns
# 杯 q
# 女子 n
# 棋 n
# 訓練 vn
# 楊子 nr
# 萱 n
# 荒木 n
# 氏 ng
# 擂台 v
# 决赛 n
# 第 m
# 强 a
# 败者 n
# 获 v
# 專案 n
# 俘子 n
# 柯潔 nr
# 分 v
# 至 p
# 本戰 nz
# 过惕 v
# 生 vn
# 联棋 v
# 橋本 n
# 复赛 vn
# 圍 v
# 棋界 n
# 城围 n
# 俞俐 nr
# 均 d
# 届 m
# 中 f
# 通算 v
# codice eng
# 聯 zg
# 朝日 n
# 新 a
# 绝艺 n
# 天元 q
# 王座 nr
# 邱峻 nr
# 灵杯 n
# 棋圣 ns
# 女流 n
# 名人 n
# 黄龙 nr
# 士 n
# 队 n
# 获得 v
# 謝 v
# 依 v
# 旻 zg
# 颗子 n
# 挑 v
# 戰者 n
# 組織 v
# 中 f
# 環 v
# 盃 zg
# 农心 n
# 杯 q
# 赵南哲 nr
# 新布石 ns
# 應昌 nr
# 玩家 n
# 黑子 n
# 外勢 n
# 學習 v
# 深入 v
# 胜率 n
# 收官 n
# 位棋 n
# 资格赛 n
# 方 n
# 棋子 n
# 全国性 n
# 白方 n
# 际 ng
# 象棋 v
# 李 nr
# 世 ng
# 乭 zg
# 年 m
# 為 p
# 人戰 nz
# 亚洲 ns
# 队 n
# 和 c
# 名誉 n
# 打劫 v
# 理光 n
# 霸王 n
# 飛刀 n
# 得到 v
# 聂卫 nr
# 正夫 n
# 本 r
# 选赛 v
# 只 d
# 棋子 n
# 半决赛 n
# 妖刀 n
# 雙人 n
# 家康 nz
# 网棋 n
# 十一 m
# 執白 v
# 主将 n
# 國流 n
# 目外 t
# 经过 p
# 更具 v
# 负 v
# 中华 nz
# 台北 ns
# 腾讯 nz
# 李昌镐 nr
# 中盘 n
# 頭銜 n
# 者 k
# 年 m
# 代表 n
# 王座 nr
# 戰 zg
# 棋 n
# 聖 j
# 南 f
# 韓首爾 nr
# 碁 yg
# 聖 j
# 戰 vg
# 國手 n
# 混 v
# 双赛 n
# 江戶 ns
# 奖金 n
# 为 p
# 賽 v
# 進行 v
# 国 n
# 女子 n
# 決定 v
# 戰 n
# 網路 n
# 圍 v
# 金明训 nr
# 余 m
# 棋手 n
# 团体赛 n
# 10 m
# 万 m
# 圍棋 v
# 高 a
# 朴志恩 nr
# 开局 n
# 职业 n
# 吴清源 nr
# 海峰 n
# 级分 n
# 衢州市 ns
# 王 nr
# 晨星 n
# 段胜 nr
# 視台 n
# 產生 n
# 正式 ad
# 聖戰 nz
# 王 nr
# 戰 n
# 排名 v
# 賽制 n
# 抽签 v
# 金荣 nr
# 国手 n
# 分先 d
# 最強 a
# 中方 f
# 导致 v
# 曾经 d
# 担任 v
# 9 m
# 日 m
# 當 p
# 作 n
# 豐田 nz
# 座 q
# 戰 n
# 屆本 d
# 击败 v
# 组合 v
# 来自 v
# 下棋 v
# 武汉 ns
# 聯盟 nt
# 成绩 n
# 引起 v
# 只能 v
# 负 v
# 李 nr
# 年底 t
# 下午 t
# 單敗 n
# 耀 v
# 烨 nr
# 重庆 ns
# 項目 n
# 手棋 n
# 棋王赛 n
# 禁止 v
# 為 zg
# 日本 ns
# 歐洲 ns
# 黑龙江 ns
# 羋 o
# 昱 g
# 廷 g
# 晏天章 nr
# 提子 n
# 江苏 ns
# 混双 v
# 白子 n
# 棋經 n
# 选手 v
# 黄龙 nr
# 男 n
# 棋手 n
# 背景 n
# 循环 vn
# 日 m
# 国际 n
# 象 n
# 杯 q
# 世界 n
# 国 n
# 参加 v
# 獲勝 v
# 者 k
# 预选 v
# 人類 n
# 着 uz
# 法 j
# 主办 b
# 围棋赛 n
# 申 v
# 旻 x
# 埈 zg
# 崔哲瀚 nr
# 连胜 nr
# 名人战 n
# 亞軍 nr
# 步棋 n
# 镇 n
# 围棋 v
# 个人 n
# 组 zg
# 王积薪 nr
# 家家 n
# 督 vg
# 目半 t
# 為 zg
# 名人 n
# 还 d
# 棋头 n
# vs eng
# 预选赛 n
# 对局 n
# 黃士 nr
# 推广 v
# 挑战 vn
# 人 n
# 以 p
# 姜堰 nr
# 数据 n
# 分析 vn
# 人围 n
# 交流 n
# 軟體 n
# 方圓 n
# 跡目 n
# 年 m
# 日本 ns
# 衢州 ns
# 亞 j
# 藝 ng
# 盃 zg
# 其它 r
# 网 n
# 选 v
# 负于 v
# 勝制 vn
# 獲得 v
# 此 r
# 頭銜 n
# 杯 q
# 本赛 n
# 名人 n
# 賽 x
# 关东 ns
# 團隊 n
# 棋品 n
# 道策 n
# 则 d
# 是 v
# 弈秋 n
# 複 yg
# 雜 v
# 小飛 nr
# 透過 v
# 杯 q
# 围棋 v
# 数学 n
# 围棋 v
# 最 d
# 基金 n
# 會 zg
# 中國 ns
# 圍 v
# 对抗赛 n
# 际 ng
# 围棋 v
# 棋 n
# 世界 n
# 本 r
# 棋院 n
# 服务器 n
# 国家队 nt
# 是 v
# 围棋 v
# 围棋网 i
# 自我 r
# 訓練 vn
# 淘汰赛 n
# 棋院 n
# 和 c
# 内 n
# 围棋 v
# 重要性 n
# 世本 n
# 因 c
# 个人赛 n
# 為 p
# 本 r
# 因 c
# 選拔 v
# 賽 n
# 段位 n
# 的 uj
# 输给 v
# 了 ul
# 市 n
# 围棋 v
# 刀 n
# 定式 n
# 组成 v
# 的 uj
# 俱乐部 n
# 被 p
# 视为 v
# 研究 vn
# 的 uj
# 將 d
# 棋界 n
# 赵晨宇 nr
# 被 p
# 叫做 v
# 电王 n
# 战 n
# 假眼 n
# 活 vn
# 段 q
# 以 f
# 桐山 ns
# 杯 n
# 方式 n
# 之一 r
# 体育 vn
# 名单 n
# 位 m
# 提白 v
# 朴 nr
# 鋕 zg
# 恩 nr
# 方用 n
# 时 n
# 规则 n
# 元 m
# 战 n
# 制度 n
# 工智 n
# 業圍 n
# 因坊 n
# 国棋 n
# 之间 f
# 氏杯 n
# 国业 n
# 酒店 n
# 運算 vn
# 單位 n
# 定式 n
# 最高 a
# 全國 nt
# 本学 n
# 传说 n
# 網站 n
# 最佳 z
# 实业 n
# 国职 n
# 院 n
# 和 c
# 南京 ns
# 高 a
# 段 q
# 支援 v
# 政府 n
# 同樣 d
# 能力 n
# 表团 n
# 国流 n
# 棋牌 n
# 參數 n
# 全部 n
# 模仿 v
# 团队 n
# 三轮 m
# 佔 v
# 角 n
# 對 p
# 戰 n
# 讀賣 v
# 元老 nr
# 應用 v
# 实际 n
# 再次 d
# 中学 n
# 网上 s
# 卫平 nr
# 則 d
# 因 p
# 中部 f
# 顶尖 n
# 系列 q
# 原因 n
# 国象 n
# 这种 r
# 邀请 v
# 赛于 v
# 计数 n
# 九段 m
# 設定 v
# 各地 r
# 為 p
# 台 ns
# 李东勋 nr
# 预赛 vn
# 长期 d
# 卡斯 nrt
# 貼目 n
# 比對 d
# 真眼 d
# 之 u
# 莹 nr
# 工作 vn
# 富士 n
# 通过 p
# 執黑 v
# 圣战 nz
# 大小 b
# 读秒 n
# 世代 t
# 裁判 vn
# 程度 n
# 卡尔 nrt
# 台赛 ns
# 棋 n
# 協 n
# 日本 ns
# 圍 x
# 12 m
# 万 m
# 实力 n
# 安節 nr
# 陕西 ns
# 全运 n
# 显著 a
# 智能 n
# 參考 v
# 当时 t
# 宣布 v
# 网格 n
# 坐标 v
# 棋艺 n
# 循環 vn
# 極其 d
# 世襲 vn
# 達成 v
# 日程 n
# 每年 r
# 東京 ns
# 专家 n
# 规定 n
# 方一 nr
# 本 r
# 薰 v
# 提升 v
# 之 u
# 子 ng
# 占据 v
# 1 m
# 月 m
# 1 m
# 日 m
# 江维 ns
# 升降 v
# 连续 a
# 佛乘 nz
# 德川 ns
# 报名 v
# 利益 n
# 赛前 t
# 连接 v
# 先前 t
# 东京 ns
# 创办 v
# 手割 v
# 打算 v
# 實做 v
# 可能 v
# 变得 v
# 歷史 n
# 坊門 n
# 利用 n
# 十二 m
# 台北 ns
# 成员 n
# 消劫 v
# 领域 n
# 之 u
# 父 n
# 争夺 v
# 2 m
# 万 m
# 得 ud
# 第 m
# 开发 v
# 佐 vg
# 為 p
# 己方 n
# 马晓春 nr
# 外卡 n
# 後 nr
# 黑 a
# 29 m
# 日 m
# 加以 v
# 知得 v
# 高校 n
# 很多 m
# 受到 v
# 相鄰 v
# 小组 n
# 打入 v
# 出场 n
# 彼此 r
# 分數 n
# 停止 v
# 胜出 v
# 局 n
# 为 p
# 距離 n
# 挑战赛 n
# 点 m
# 李 nr
# 小溪 nr
# 周俊勳 nr
# 月 m
# 3 m
# 日 m
# 6 m
# 日 m
# 将 d
# 于 p
# 聞社 l
# 創立 v
# 4 m
# 日 m
# 定石 n
# 下 f
# 到 v
# 棋 n
# 以 p
# 釋出 v
# 赛制 n
# 种子 n
# 香港 ns
# 腾讯 nz
# 野 n
# 思考 v
# 小 a
# 時 ng
# 单败 n
# 淘 v
# 放送 v
# 获胜者 n
# 复杂性 n
# 同时 c
# 互相 d
# 方 q
# 各 r
# 职业 n
# 棋手 n
# 棋戰 n
# 人数 n
# 技巧 n
# 附近 f
# 則 d
# 是 v
# 女流 n
# 际象 n
# 平面 n
# 这样 r
# 直线 n
# 阶段 n
# 虽然 c
# 夺得 v
# 名 q
# 棋手 n
# 意思 n
# 包圍 v
# 段位制 n
# 超過 v
# 改稱 v
# 正官 n
# 庄杯 n
# 世纪 n
# 圍 v
# 棋賽 n
# 强战 v
# 樊 nr
# 麾 n
# 必須 d
# formula eng
# 范西屏 nr
# 国手 n
# 战 n
# 互联网 n
# 扇 q
# 興杯 n
# 名人 n
# 戰 zg
# 对 p
# 围棋 v
# 豐田杯 nz
# 通常 d
# 舉辦 v
# 主要 b
# 手合 n
# 国 n
# 棋手 n
# 周俊 nr
# 真 d
# 露 v
# 杯 q
# 中環 ns
# 数子 n
# 得 ud
# 天元 q
# 赞助商 v
# 3 m
# 月 m
# 4 m
# 日 m
# 周俊勋 nr
# 數子 n
# 法 n
# 杭州 ns
# 世 ng
# 乭 zg
# 資料 n
# 棋赛 n
# 工程 n
# 淘汰 v
# 棋賽 n
# 赛事 n
# 广州 ns
# 對弈 vn
# 中 f
# 厚勢 n
# 安排 v
# 生涯 n
# 2 m
# 轮 n
# 宇宙 n
# 流 n
# 上海 ns
# 对于 p
# 胜负 v
# 名将 n
# 专业 n
# 快棋 n
# 获得 v
# 存在 v
# 立於 nr
# 举办 v
# 的 uj
# 年間 t
# 年 m
# 年 m
# 山东 ns
# 方可 n
# 元 m
# 和 c
# 辜梓 nr
# 豪 ag
# 同名 n
# 罗玄 nr
# 方捷 nr
# 淘汰 v
# 賽 x
# 局棋 n
# 陈浩 nr
# 男子 n
# 结果 n
# 位 q
# 丁烈 nr
# 運用 vn
# 围棋 v
# 名人战 n
# 林海峰 nr
# 贊助 v
# 人机 n
# 世界 n
# 第 m
# 加藤 nr
# 日 m
# 和 c
# 年 m
# 獲 v
# 选拔 v
# 讀賣 v
# 新聞 n
# 職業 n
# 圍棋 v
# 小林 nr
# 光 n
# 年 m
# 日 m
# 計算 v
# 日 m
# 围棋 v
# 围棋 v
# 大 a
# 对弈 v
# 錦標賽 n
# 丁明君 nr
# 赛 nz
# 冠军 n
# 伺服器 nz
# 届 m
# 比 p
# 综合 vn
# 業 x
# 棋士 n
# 国务 n
# 为 p
# 围棋 v
# 张馨 nr
# 月 m
# 女子 n
# 围 v
# 年度 n
# 无锡市 ns
# 程式 n
# 碼 x
# 顾水 nr
# 如 v
# 出线 n
# 棋 n
# 水平 n
# 公開賽 nr
# 年 m
# 取 v
# 數子 n
# 本赛 n
# 第 m
# 分散式 n
# 指 n
# 围棋 v
# 围棋队 n
# 网络 n
# 對弈 v
# 国 n
# 规则 n
# 為 p
# 台灣 ns
# 使用者 n
# 关西 ns
# 目的 n
# 改名 v
# 為 zg
# 優勝者 n
# 為了 p
# 版本 n
# 团体 n
# 段位 n
# 周睿 nrfg
# 决赛 n
# 中 f
# 落子 n
# 資源 n
# 程式 n
# 电视 n
# 弟子 n
# 為 p
# 圍棋 v
# 小光 nr
# 抗賽 vn
# 家督 nz
# 白棋 nr
# 券杯 n
# 實利 n
# 晚报 n
# 安井 ns
# 秀 ag
# 和 c
# 限 v
# 公 n
# 名譽 n
# 發行 v
# 挑戰 vn
# 蒙地 ns
# 新 a
# 布局 n
# 大赛 n
# 武宮 nr
# 报道 v
# 直播 vn
# 獲勝 v
# 和 c
# 韩 nr
# 協會 n
# 團體 n
# 采取 v
# 中日 t
# 才能 v
# 守角 n
# 现代 t
# 浙江 ns
# 之間 f
# 赛区 n
# 已經 d
# 造成 v
# 例子 n
# 当今 t
# 高目 n
# 棋圣战 n
# 日本队 nt
# 郭闻潮 nr
# 方先 nr
# 小时 n
# 棋坛 n
# 策略 n
# 曹薰 nr
# 本身 r
# 男女 n
# 星位 n
# 丁浩 nr
# 全国 n
# 征子 n
# 原子 n
# 发生 v
# 整個 b
# 參加 v
# 目數 n
# 個 m
# 黑 a
# 秀策 n
# 方用 n
# 弈城 n
# 棋盘 n
# 首次 m
# 长 a
# 考 v
# 秀行 n
# 风格 n
# 電腦 n
# 圍 v
# 亚军 nr
# 业围 n
# 比目 n
# 法 j
# 日本 ns
# 的 uj
# 9 m
# x9 eng
# 类似 v
# 三 m
# 三 m
# 手数 n
# 連接 v
# 官方 n
# 繼承 v
# 作戰 v
# 国 n
# 棋院 n
# 黑方 n
# 業餘 n
# 個角 n
# 许 m
# 嘉阳 ns
# 分為 v
# 王世 nr
# 國內 s
# 崔精 nr
# 国围 n
# 機會 n
# 陳耀燁 nr
# 職業 n
# 棋 n
# 职业 n
# 围棋 v
# 范胤 nr
# 世界 n
# 最 d
# 芮乃伟 nr
# 官子 n
# 李昌鎬 nr
# 演算法 n
# 朴 nr
# 文 ng
# 垚 zg
# 浙江省 ns
# 屆 m
# 起 v
# 阿含 nr
# 決賽 n
# 按照 p
# 少年 m
# 赵治勋 nr
# 本年度 n
# 终局 n
# 決定 v
# 情況 n
# 下 f
# 棋局 n
# 情况 n
# 處理 v
# 全局 n
# 执黑 v
# 林家 n
# 交叉 n
# 擊敗 v
# 變成 v
# 木谷 n
# 强赛 vn
# 戰鬥 vn
# 任何 r
# 內容 n
# 日本 ns
# 棋院 n
# 日 m
# 至 p
# 國際 n
# 广西 ns
# 曹大元 nr
# 應 v
# 對 p
# 尤其 d
# 整个 b
# 职业 n
# 棋 n
# 国内 s
# 改名 v
# 發生 v
# 叫 v
# 吃 v
# 冠亚军 n
# 全 a
# 日本 ns
# 織田 n
# 藤泽 nr
# 广东 ns
# 海峰 n
# 棋院 n
# 三子 m
# 局面 n
# 重要 a
# 年围 n
# 西洋棋 nr
# 棋 n
# 聖 j
# 戰 n
# 富士通杯 nz
# 非常 d
# 董彦 nr
# 對 p
# 手 s
# 選手 v
# 韓國 ns
# 棋院 n
# 帳號 n
# 以 p
# 後 nr
# 公开 ad
# 圍棋棋 i
# 棋 n
# 协会 n
# 關西 ns
# 棋院 n
# 職業圍 n
# 种子 n
# 选 zg
# 中盤 ns
# 队 n
# 以 p
# 中日韩 ns
# 杭州市 ns
# 推出 v
# 等级 b
# 將棋 n
# 變化 vn
# 棋具 n
# 棋 n
# 協會 n
# 陈祖德 nr
# 年 m
# 因 c
# 严欢 nr
# 位置 v
# 江铸 nr
# 久 a
# 联合 v
# 为 p
# 世界 n
# 对局 n
# 费 v
# 围棋 v
# 规则 n
# 执白 v
# 李康 nr
# 結果 n
# 活棋 n
# 决赛 n
# 胡耀宇 nr
# 國際賽 nz
# 了 ul
# 围棋 v
# 應氏 nr
# 三段 m
# 這種 r
# 番 q
# 棋 n
# 赞助 v
# 传统 n
# 影响 vn
# 城市 ns
# 国家 n
# 体 n
# 掛角 n
# 秀 ag
# 哉 y
# 奖金 n
# 特定 d
# 局部 n
# 年 m
# 舉 v
# 棋战 n
# 古灵益 nr
# 階段 n
# 年 m
# 台 q
# 達到 v
# 地區 n
# 自己 r
# 的 uj
# 比赛 vn
# 中 f
# 为 p
# 围 v
# 实战 v
# 兒子 n
# 停辦 v
# 比賽 vn
# 中 f
# 算 v
# 砂 n
# 秀甫 nr
# 李 nr
# 喆 zg
# 公開 ad
# 公司 n
# 黑貼 n
# 大 a
# 飛 n
# 张璇 nr
# 本局 n
# 依照 p
# 職業 n
# 棋手 n
# 技术 n
# 初段 t
# 读秒 n
# 的 uj
# 類似 v
# 中国 ns
# 发展 vn
# 日本 ns
# 围 v
# 李世石 nr
# 云南 ns
# 安冬旭 nr
# 奧林匹亞 nz
# 安井家 nr
# 韩国 ns
# 形態 n
# 年 m
# 改 v
# 年 m
# 共 d
# 象棋 v
# 多数 m
# 大学 n
# 北京 ns
# 成為 v
# 分鐘 q
# 某些 r
# 棋手 n
# 在 p
# 周泓余 nr
# 范廷鈺 nr
# 是 v
# 日本 ns
# 重視 v
# 勝率 n
# 頭銜 n
# 台灣 ns
# 圍棋 v
# 届 m
# 应 v
# 参赛 n
# 柁 g
# 嘉熹 nr
# 年 m
# 以 f
# 年代 t
# 佟禹林 nr
# 是 v
# 台灣 ns
# 黑白 z
# 時候 n
# 金志 n
# 锡 ns
# 然而 c
# 保留 v
# 是 v
# 圍棋 v
# 實力 n
# 此時 c
# 連勝 nr
# 人民 n
# 關西 ns
# 成績 n
# 職業 n
# 棋士 n
# 網路 n
# 黑棋 nr
# 孔杰 nr
# 宋容慧 nr
# 出現 v
# 要求 v
# 围棋 v
# 协会 n
# 或者 c
# 圍棋 v
# 協 n
# 棋形 n
# 雖然 c
# 遊戲 n
# 睦 ag
# 镇硕 nrt
# 抗赛 vn
# 三番 m
# 棋 n
# 先 d
# 手 n
# 是 v
# 由 p
# 野狐 nz
# 特殊 a
# 蔡竞 nr
# 首轮 m
# 進入 v
# 丁伟 nr
# 日文 n
# 模樣 n
# 後 nr
# 因 p
# 段 q
# 和 c
# 選擇 v
# 木谷 n
# 實 v
# 讓 v
# 子 ng
# 彭荃 nr
# 價值 n
# 年 m
# 舉辦 v
# 王磊 nr
# 当时 t
# 中 f
# 届 m
# 起 v
# 国队 n
# 职业 n
# 围 v
# 常昊 nr
# 唐 nr
# 奕 z
# 坂田 nr
# 研究 vn
# 本賽 n
# 棋界 n
# 以下 f
# 始于 d
# 進行 v
# 電腦 n
# 战胜 n
# 游戏 n
# 卞相 nr
# 目前 t
# 电脑 n
# 攻擊 v
# 論文 nz
# 罗洗河 nr
# 李轩 nr
# 豪 ag
# 世本 n
# 吳 x
# 清源 n
# 稱作 v
# 年才 t
# 年间 t
# 規則 n
# 過程 n
# 黄奕中 i
# 棋盤 n
# 上 f
# 布局 n
# 行棋 n
# 台灣 ns
# 棋 n
# 范蕴若 nr
# 朴廷桓 nr
# 申真 nr
# 谞 zg
# 這個 r
# 国际 n
# 围 v
# 財團 n
# 法人 n
# 曹薰铉 nr
# 賽事 nz
# 首届 m
# 人赛 n
# 小 a
# 目 t
# 朴永训 nr
# 檀啸 nr
# 至 p
# 第 m
# 这些 r
# 年 m
# 全 n
# 限 v
# 公司 n
# 陶 nr
# 欣然 d
# 目数 n
# 国 n
# 围棋 v
# 周睿羊 l
# 俞斌 nr
# 比較 d
# 井山裕 nr
# 太 d
# 名 m
# 為 p
# 时间 n
# 年 m
# 获 v
# 年 m
# 至 p
# 年 m
# 和 c
# 英文 nz
# 刘星 nr
# 元 m
# 晟 g
# 溱 g
# 杨 nr
# 鼎新 d
# 改為 v
# 獎金 n
# 用 p
# 时 n
# 年 m
# 到 v
# 姜东润 nr
# 韓國 ns
# 年 m
# 由 p
# 冠軍 n
# 国家 n
# 棋王 n
# 采用 v
# 中央 n
# 認為 v
# 開始 v
# 時間 n
# 特別 d
# 棋譜 n
# 刘昌赫 nr
# 雙方 n
# 日本 ns
# 棋 n
# 優勢 n
# 规则 n
# 与 p
# 後 nr
# 來 v
# 年 m
# 开 v
# 原本 n
# 由 p
# 於 nr
# 年 m
# 中 f
# 胜者 n
# 下 f
# 法 j
# 其他 r
# 佈 yg
# 局 n
# 對 p
# 方 n
# 昭和 nz
# 世紀 n
# 柯洁 nr
# 党毅飞 nr
# 女棋手 n
# 稱為 v
# 台灣 ns
# 棋院 n
# 棋院 n
# 對 p
# 局 n
# 採用 v
# 连笑 nr
# 江维杰 nr
# 陈耀烨 nr
# 以上 f
# 谢赫 nr
# 周鹤洋 nr
# 中國 ns
# 位 q
# 棋手 n
# 年 m
# 開 v
# 這些 r
# 开始 v
# 優勝 n
# 芈 o
# 昱 g
# 廷 g
# 棋手 n
# 业余 n
# 范廷钰 nr
# 时 ng
# 越 d
# 情況 n
# 同時 c
# 如果 c
# 根据 p
# 棋力 n
# 棋子 n
# 中國 ns
# 圍棋 v
# 棋士 n
# 發展 vn
# 4 m
# 子 nr
# 元 m
# 人 n
# 以及 c
# 棋盤 n
# 女子 n
# 當時 t
# 台灣 ns
# 唐韦星 nr
# 職業 n
# 国际 n
# 之 u
# 後 nr
# 比賽 vn
# 年 m
# 起 v
# 主辦 b
# 古力 n
# 本 r
# 因 c
# 使用 v
# 冠军 n
# 每方 r
# 本赛 n
# 本 r
# 因坊 n
# 比赛 vn
# 其中 r
# 年 m
# 第 m
# 日本 ns
# 圍棋 v
# 世界 n
# 围棋 v

# %%
filtered_lst=[]
ruled_out=[]
for i in range(len(lst)):
    sentence=pseg.cut(lst[i][0])
    condition=True
    for w in sentence:
        if w.flag not in ['n','nz','nt','nr','ns','nw']:
            condition=False
    if condition==True:
        filtered_lst.append(lst[i][0])
    else:
        ruled_out.append(lst[i][0])

# %%
filtered_lst
# Out:
# ['定段',
#  '江流儿',
#  '雷凌云',
#  '云子',
#  '江流',
#  '劫材',
#  '唐韋星',
#  '方圓社',
#  '棋鬼王',
#  '天元战',
#  '時代',
#  '方胜',
#  '廣島',
#  '挑战者',
#  '黑嘉嘉',
#  '天台',
#  '聂卫平',
#  '山城宏',
#  '贴目',
#  '岩本',
#  '甘肃',
#  '白昕卉',
#  '張凱馨',
#  '晋级',
#  '丹朱',
#  '瀨越',
#  '楊子',
#  '刘小光',
#  '区',
#  '男子组',
#  '韩元',
#  '女子组',
#  '小林觉',
#  '擂台赛',
#  '赛棋手',
#  '女子棋',
#  '楊子萱',
#  '專案',
#  '俘子',
#  '柯潔',
#  '本戰',
#  '橋本',
#  '城围',
#  '绝艺',
#  '王座',
#  '邱峻',
#  '灵杯',
#  '棋圣',
#  '女流名人',
#  '黄龙士',
#  '颗子',
#  '赵南哲',
#  '新布石',
#  '應昌',
#  '玩家',
#  '黑子',
#  '外勢',
#  '胜率',
#  '收官',
#  '位棋',
#  '资格赛',
#  '方棋子',
#  '全国性',
#  '白方',
#  '人戰',
#  '亚洲',
#  '名誉',
#  '理光',
#  '霸王',
#  '飛刀',
#  '聂卫',
#  '正夫',
#  '半决赛',
#  '妖刀',
#  '雙人',
#  '家康',
#  '网棋',
#  '主将',
#  '國流',
#  '中华台北',
#  '腾讯',
#  '李昌镐',
#  '中盘',
#  '國手',
#  '江戶',
#  '国女子',
#  '金明训',
#  '团体赛',
#  '朴志恩',
#  '开局',
#  '职业',
#  '吴清源',
#  '海峰',
#  '级分',
#  '衢州市',
#  '王晨星',
#  '段胜',
#  '視台',
#  '產生',
#  '聖戰',
#  '王戰',
#  '賽制',
#  '金荣',
#  '国手',
#  '豐田',
#  '武汉',
#  '聯盟',
#  '成绩',
#  '單敗',
#  '重庆',
#  '項目',
#  '手棋',
#  '棋王赛',
#  '歐洲',
#  '黑龙江',
#  '晏天章',
#  '提子',
#  '江苏',
#  '白子',
#  '棋經',
#  '黄龙',
#  '男棋手',
#  '背景',
#  '国际象',
#  '人類',
#  '围棋赛',
#  '崔哲瀚',
#  '连胜',
#  '名人战',
#  '亞軍',
#  '步棋',
#  '个人',
#  '王积薪',
#  '预选赛',
#  '对局',
#  '黃士',
#  '姜堰',
#  '数据',
#  '人围',
#  '交流',
#  '軟體',
#  '方圓',
#  '跡目',
#  '衢州',
#  '关东',
#  '團隊',
#  '棋品',
#  '道策',
#  '弈秋',
#  '小飛',
#  '数学',
#  '对抗赛',
#  '棋世界',
#  '服务器',
#  '国家队',
#  '淘汰赛',
#  '重要性',
#  '个人赛',
#  '刀定式',
#  '俱乐部',
#  '赵晨宇',
#  '电王战',
#  '桐山杯',
#  '方式',
#  '名单',
#  '方用时',
#  '规则',
#  '制度',
#  '工智',
#  '業圍',
#  '因坊',
#  '国棋',
#  '氏杯',
#  '国业',
#  '酒店',
#  '單位',
#  '定式',
#  '全國',
#  '本学',
#  '传说',
#  '網站',
#  '实业',
#  '国职',
#  '南京',
#  '政府',
#  '能力',
#  '表团',
#  '国流',
#  '棋牌',
#  '參數',
#  '全部',
#  '团队',
#  '元老',
#  '实际',
#  '中学',
#  '卫平',
#  '顶尖',
#  '原因',
#  '国象',
#  '计数',
#  '李东勋',
#  '貼目',
#  '富士',
#  '圣战',
#  '读秒',
#  '程度',
#  '台赛',
#  '棋協',
#  '实力',
#  '安節',
#  '陕西',
#  '全运',
#  '智能',
#  '网格',
#  '棋艺',
#  '日程',
#  '東京',
#  '专家',
#  '规定',
#  '方一',
#  '江维',
#  '佛乘',
#  '德川',
#  '利益',
#  '东京',
#  '歷史',
#  '坊門',
#  '利用',
#  '台北',
#  '成员',
#  '领域',
#  '己方',
#  '马晓春',
#  '外卡',
#  '高校',
#  '小组',
#  '出场',
#  '分數',
#  '局',
#  '距離',
#  '挑战赛',
#  '李小溪',
#  '周俊勳',
#  '定石',
#  '赛制',
#  '种子',
#  '香港',
#  '腾讯野',
#  '获胜者',
#  '复杂性',
#  '职业棋手',
#  '棋戰',
#  '人数',
#  '技巧',
#  '女流',
#  '际象',
#  '平面',
#  '直线',
#  '阶段',
#  '意思',
#  '段位制',
#  '正官庄杯',
#  '世纪',
#  '樊麾',
#  '范西屏',
#  '国手战',
#  '互联网',
#  '豐田杯',
#  '手合',
#  '国棋手',
#  '周俊',
#  '中環',
#  '数子',
#  '周俊勋',
#  '數子法',
#  '杭州',
#  '資料',
#  '棋赛',
#  '工程',
#  '棋賽',
#  '赛事',
#  '广州',
#  '厚勢',
#  '生涯',
#  '宇宙流',
#  '上海',
#  '名将',
#  '专业',
#  '快棋',
#  '立於',
#  '山东',
#  '方可',
#  '同名',
#  '罗玄',
#  '方捷',
#  '局棋',
#  '陈浩',
#  '男子',
#  '结果',
#  '丁烈',
#  '林海峰',
#  '人机',
#  '加藤',
#  '小林光',
#  '錦標賽',
#  '丁明君',
#  '赛冠军',
#  '伺服器',
#  '国务',
#  '年度',
#  '无锡市',
#  '出线',
#  '棋水平',
#  '公開賽',
#  '數子',
#  '分散式',
#  '围棋队',
#  '网络',
#  '国规则',
#  '使用者',
#  '关西',
#  '目的',
#  '優勝者',
#  '版本',
#  '团体',
#  '段位',
#  '落子',
#  '資源',
#  '程式',
#  '电视',
#  '弟子',
#  '小光',
#  '家督',
#  '白棋',
#  '券杯',
#  '實利',
#  '晚报',
#  '安井',
#  '名譽',
#  '蒙地',
#  '大赛',
#  '武宮',
#  '協會',
#  '團體',
#  '守角',
#  '浙江',
#  '赛区',
#  '例子',
#  '高目',
#  '棋圣战',
#  '日本队',
#  '郭闻潮',
#  '方先',
#  '小时',
#  '棋坛',
#  '策略',
#  '曹薰',
#  '男女',
#  '星位',
#  '丁浩',
#  '全国',
#  '征子',
#  '原子',
#  '目數',
#  '秀策',
#  '方用',
#  '弈城',
#  '棋盘',
#  '秀行',
#  '风格',
#  '亚军',
#  '业围',
#  '手数',
#  '官方',
#  '国棋院',
#  '黑方',
#  '業餘',
#  '個角',
#  '王世',
#  '崔精',
#  '国围',
#  '機會',
#  '陳耀燁',
#  '職業棋',
#  '范胤',
#  '芮乃伟',
#  '官子',
#  '李昌鎬',
#  '演算法',
#  '浙江省',
#  '阿含',
#  '決賽',
#  '赵治勋',
#  '本年度',
#  '终局',
#  '棋局',
#  '情况',
#  '全局',
#  '林家',
#  '交叉',
#  '木谷',
#  '內容',
#  '日本棋院',
#  '國際',
#  '广西',
#  '曹大元',
#  '职业棋',
#  '冠亚军',
#  '織田',
#  '藤泽',
#  '广东',
#  '海峰棋院',
#  '局面',
#  '年围',
#  '西洋棋',
#  '富士通杯',
#  '董彦',
#  '韓國棋院',
#  '帳號',
#  '棋协会',
#  '關西棋院',
#  '職業圍',
#  '中盤',
#  '中日韩',
#  '杭州市',
#  '將棋',
#  '棋具',
#  '棋協會',
#  '陈祖德',
#  '严欢',
#  '李康',
#  '結果',
#  '活棋',
#  '决赛',
#  '胡耀宇',
#  '國際賽',
#  '應氏',
#  '传统',
#  '城市',
#  '国家体',
#  '掛角',
#  '奖金',
#  '局部',
#  '棋战',
#  '古灵益',
#  '階段',
#  '地區',
#  '兒子',
#  '秀甫',
#  '公司',
#  '黑貼',
#  '张璇',
#  '本局',
#  '職業棋手',
#  '技术',
#  '中国',
#  '李世石',
#  '云南',
#  '安冬旭',
#  '奧林匹亞',
#  '安井家',
#  '韩国',
#  '形態',
#  '大学',
#  '北京',
#  '周泓余',
#  '范廷鈺',
#  '勝率',
#  '頭銜',
#  '参赛',
#  '佟禹林',
#  '時候',
#  '金志锡',
#  '實力',
#  '連勝',
#  '人民',
#  '關西',
#  '成績',
#  '職業棋士',
#  '網路',
#  '黑棋',
#  '孔杰',
#  '宋容慧',
#  '棋形',
#  '遊戲',
#  '野狐',
#  '蔡竞',
#  '丁伟',
#  '日文',
#  '模樣',
#  '彭荃',
#  '價值',
#  '王磊',
#  '国队',
#  '常昊',
#  '坂田',
#  '本賽',
#  '棋界',
#  '電腦',
#  '战胜',
#  '游戏',
#  '卞相',
#  '电脑',
#  '論文',
#  '罗洗河',
#  '世本',
#  '規則',
#  '過程',
#  '布局',
#  '行棋',
#  '台灣棋',
#  '范蕴若',
#  '朴廷桓',
#  '財團法人',
#  '曹薰铉',
#  '賽事',
#  '人赛',
#  '朴永训',
#  '檀啸',
#  '目数',
#  '俞斌',
#  '时间',
#  '',
#  '英文',
#  '刘星',
#  '獎金',
#  '姜东润',
#  '韓國',
#  '冠軍',
#  '国家',
#  '棋王',
#  '中央',
#  '時間',
#  '棋譜',
#  '刘昌赫',
#  '雙方',
#  '日本棋',
#  '優勢',
#  '原本',
#  '胜者',
#  '昭和',
#  '世紀',
#  '柯洁',
#  '党毅飞',
#  '女棋手',
#  '',
#  '台灣棋院',
#  '棋院',
#  '连笑',
#  '江维杰',
#  '陈耀烨',
#  '谢赫',
#  '周鹤洋',
#  '中國',
#  '優勝',
#  '棋手',
#  '业余',
#  '范廷钰',
#  '情況',
#  '棋力',
#  '棋子',
#  '棋士',
#  '',
#  '棋盤',
#  '女子',
#  '',
#  '台灣',
#  '唐韦星',
#  '職業',
#  '国际',
#  '古力',
#  '',
#  '冠军',
#  '本赛',
#  '日本',
#  '世界']

# %%
filtered_lst2=[]
for i in range(len(filtered_lst)):
    if filtered_lst[i]=='':
        pass
    else:
        filtered_lst2.append(filtered_lst[i])
filtered_lst2
# Out:
# ['定段',
#  '江流儿',
#  '雷凌云',
#  '云子',
#  '江流',
#  '劫材',
#  '唐韋星',
#  '方圓社',
#  '棋鬼王',
#  '天元战',
#  '時代',
#  '方胜',
#  '廣島',
#  '挑战者',
#  '黑嘉嘉',
#  '天台',
#  '聂卫平',
#  '山城宏',
#  '贴目',
#  '岩本',
#  '甘肃',
#  '白昕卉',
#  '張凱馨',
#  '晋级',
#  '丹朱',
#  '瀨越',
#  '楊子',
#  '刘小光',
#  '区',
#  '男子组',
#  '韩元',
#  '女子组',
#  '小林觉',
#  '擂台赛',
#  '赛棋手',
#  '女子棋',
#  '楊子萱',
#  '專案',
#  '俘子',
#  '柯潔',
#  '本戰',
#  '橋本',
#  '城围',
#  '绝艺',
#  '王座',
#  '邱峻',
#  '灵杯',
#  '棋圣',
#  '女流名人',
#  '黄龙士',
#  '颗子',
#  '赵南哲',
#  '新布石',
#  '應昌',
#  '玩家',
#  '黑子',
#  '外勢',
#  '胜率',
#  '收官',
#  '位棋',
#  '资格赛',
#  '方棋子',
#  '全国性',
#  '白方',
#  '人戰',
#  '亚洲',
#  '名誉',
#  '理光',
#  '霸王',
#  '飛刀',
#  '聂卫',
#  '正夫',
#  '半决赛',
#  '妖刀',
#  '雙人',
#  '家康',
#  '网棋',
#  '主将',
#  '國流',
#  '中华台北',
#  '腾讯',
#  '李昌镐',
#  '中盘',
#  '國手',
#  '江戶',
#  '国女子',
#  '金明训',
#  '团体赛',
#  '朴志恩',
#  '开局',
#  '职业',
#  '吴清源',
#  '海峰',
#  '级分',
#  '衢州市',
#  '王晨星',
#  '段胜',
#  '視台',
#  '產生',
#  '聖戰',
#  '王戰',
#  '賽制',
#  '金荣',
#  '国手',
#  '豐田',
#  '武汉',
#  '聯盟',
#  '成绩',
#  '單敗',
#  '重庆',
#  '項目',
#  '手棋',
#  '棋王赛',
#  '歐洲',
#  '黑龙江',
#  '晏天章',
#  '提子',
#  '江苏',
#  '白子',
#  '棋經',
#  '黄龙',
#  '男棋手',
#  '背景',
#  '国际象',
#  '人類',
#  '围棋赛',
#  '崔哲瀚',
#  '连胜',
#  '名人战',
#  '亞軍',
#  '步棋',
#  '个人',
#  '王积薪',
#  '预选赛',
#  '对局',
#  '黃士',
#  '姜堰',
#  '数据',
#  '人围',
#  '交流',
#  '軟體',
#  '方圓',
#  '跡目',
#  '衢州',
#  '关东',
#  '團隊',
#  '棋品',
#  '道策',
#  '弈秋',
#  '小飛',
#  '数学',
#  '对抗赛',
#  '棋世界',
#  '服务器',
#  '国家队',
#  '淘汰赛',
#  '重要性',
#  '个人赛',
#  '刀定式',
#  '俱乐部',
#  '赵晨宇',
#  '电王战',
#  '桐山杯',
#  '方式',
#  '名单',
#  '方用时',
#  '规则',
#  '制度',
#  '工智',
#  '業圍',
#  '因坊',
#  '国棋',
#  '氏杯',
#  '国业',
#  '酒店',
#  '單位',
#  '定式',
#  '全國',
#  '本学',
#  '传说',
#  '網站',
#  '实业',
#  '国职',
#  '南京',
#  '政府',
#  '能力',
#  '表团',
#  '国流',
#  '棋牌',
#  '參數',
#  '全部',
#  '团队',
#  '元老',
#  '实际',
#  '中学',
#  '卫平',
#  '顶尖',
#  '原因',
#  '国象',
#  '计数',
#  '李东勋',
#  '貼目',
#  '富士',
#  '圣战',
#  '读秒',
#  '程度',
#  '台赛',
#  '棋協',
#  '实力',
#  '安節',
#  '陕西',
#  '全运',
#  '智能',
#  '网格',
#  '棋艺',
#  '日程',
#  '東京',
#  '专家',
#  '规定',
#  '方一',
#  '江维',
#  '佛乘',
#  '德川',
#  '利益',
#  '东京',
#  '歷史',
#  '坊門',
#  '利用',
#  '台北',
#  '成员',
#  '领域',
#  '己方',
#  '马晓春',
#  '外卡',
#  '高校',
#  '小组',
#  '出场',
#  '分數',
#  '局',
#  '距離',
#  '挑战赛',
#  '李小溪',
#  '周俊勳',
#  '定石',
#  '赛制',
#  '种子',
#  '香港',
#  '腾讯野',
#  '获胜者',
#  '复杂性',
#  '职业棋手',
#  '棋戰',
#  '人数',
#  '技巧',
#  '女流',
#  '际象',
#  '平面',
#  '直线',
#  '阶段',
#  '意思',
#  '段位制',
#  '正官庄杯',
#  '世纪',
#  '樊麾',
#  '范西屏',
#  '国手战',
#  '互联网',
#  '豐田杯',
#  '手合',
#  '国棋手',
#  '周俊',
#  '中環',
#  '数子',
#  '周俊勋',
#  '數子法',
#  '杭州',
#  '資料',
#  '棋赛',
#  '工程',
#  '棋賽',
#  '赛事',
#  '广州',
#  '厚勢',
#  '生涯',
#  '宇宙流',
#  '上海',
#  '名将',
#  '专业',
#  '快棋',
#  '立於',
#  '山东',
#  '方可',
#  '同名',
#  '罗玄',
#  '方捷',
#  '局棋',
#  '陈浩',
#  '男子',
#  '结果',
#  '丁烈',
#  '林海峰',
#  '人机',
#  '加藤',
#  '小林光',
#  '錦標賽',
#  '丁明君',
#  '赛冠军',
#  '伺服器',
#  '国务',
#  '年度',
#  '无锡市',
#  '出线',
#  '棋水平',
#  '公開賽',
#  '數子',
#  '分散式',
#  '围棋队',
#  '网络',
#  '国规则',
#  '使用者',
#  '关西',
#  '目的',
#  '優勝者',
#  '版本',
#  '团体',
#  '段位',
#  '落子',
#  '資源',
#  '程式',
#  '电视',
#  '弟子',
#  '小光',
#  '家督',
#  '白棋',
#  '券杯',
#  '實利',
#  '晚报',
#  '安井',
#  '名譽',
#  '蒙地',
#  '大赛',
#  '武宮',
#  '協會',
#  '團體',
#  '守角',
#  '浙江',
#  '赛区',
#  '例子',
#  '高目',
#  '棋圣战',
#  '日本队',
#  '郭闻潮',
#  '方先',
#  '小时',
#  '棋坛',
#  '策略',
#  '曹薰',
#  '男女',
#  '星位',
#  '丁浩',
#  '全国',
#  '征子',
#  '原子',
#  '目數',
#  '秀策',
#  '方用',
#  '弈城',
#  '棋盘',
#  '秀行',
#  '风格',
#  '亚军',
#  '业围',
#  '手数',
#  '官方',
#  '国棋院',
#  '黑方',
#  '業餘',
#  '個角',
#  '王世',
#  '崔精',
#  '国围',
#  '機會',
#  '陳耀燁',
#  '職業棋',
#  '范胤',
#  '芮乃伟',
#  '官子',
#  '李昌鎬',
#  '演算法',
#  '浙江省',
#  '阿含',
#  '決賽',
#  '赵治勋',
#  '本年度',
#  '终局',
#  '棋局',
#  '情况',
#  '全局',
#  '林家',
#  '交叉',
#  '木谷',
#  '內容',
#  '日本棋院',
#  '國際',
#  '广西',
#  '曹大元',
#  '职业棋',
#  '冠亚军',
#  '織田',
#  '藤泽',
#  '广东',
#  '海峰棋院',
#  '局面',
#  '年围',
#  '西洋棋',
#  '富士通杯',
#  '董彦',
#  '韓國棋院',
#  '帳號',
#  '棋协会',
#  '關西棋院',
#  '職業圍',
#  '中盤',
#  '中日韩',
#  '杭州市',
#  '將棋',
#  '棋具',
#  '棋協會',
#  '陈祖德',
#  '严欢',
#  '李康',
#  '結果',
#  '活棋',
#  '决赛',
#  '胡耀宇',
#  '國際賽',
#  '應氏',
#  '传统',
#  '城市',
#  '国家体',
#  '掛角',
#  '奖金',
#  '局部',
#  '棋战',
#  '古灵益',
#  '階段',
#  '地區',
#  '兒子',
#  '秀甫',
#  '公司',
#  '黑貼',
#  '张璇',
#  '本局',
#  '職業棋手',
#  '技术',
#  '中国',
#  '李世石',
#  '云南',
#  '安冬旭',
#  '奧林匹亞',
#  '安井家',
#  '韩国',
#  '形態',
#  '大学',
#  '北京',
#  '周泓余',
#  '范廷鈺',
#  '勝率',
#  '頭銜',
#  '参赛',
#  '佟禹林',
#  '時候',
#  '金志锡',
#  '實力',
#  '連勝',
#  '人民',
#  '關西',
#  '成績',
#  '職業棋士',
#  '網路',
#  '黑棋',
#  '孔杰',
#  '宋容慧',
#  '棋形',
#  '遊戲',
#  '野狐',
#  '蔡竞',
#  '丁伟',
#  '日文',
#  '模樣',
#  '彭荃',
#  '價值',
#  '王磊',
#  '国队',
#  '常昊',
#  '坂田',
#  '本賽',
#  '棋界',
#  '電腦',
#  '战胜',
#  '游戏',
#  '卞相',
#  '电脑',
#  '論文',
#  '罗洗河',
#  '世本',
#  '規則',
#  '過程',
#  '布局',
#  '行棋',
#  '台灣棋',
#  '范蕴若',
#  '朴廷桓',
#  '財團法人',
#  '曹薰铉',
#  '賽事',
#  '人赛',
#  '朴永训',
#  '檀啸',
#  '目数',
#  '俞斌',
#  '时间',
#  '英文',
#  '刘星',
#  '獎金',
#  '姜东润',
#  '韓國',
#  '冠軍',
#  '国家',
#  '棋王',
#  '中央',
#  '時間',
#  '棋譜',
#  '刘昌赫',
#  '雙方',
#  '日本棋',
#  '優勢',
#  '原本',
#  '胜者',
#  '昭和',
#  '世紀',
#  '柯洁',
#  '党毅飞',
#  '女棋手',
#  '台灣棋院',
#  '棋院',
#  '连笑',
#  '江维杰',
#  '陈耀烨',
#  '谢赫',
#  '周鹤洋',
#  '中國',
#  '優勝',
#  '棋手',
#  '业余',
#  '范廷钰',
#  '情況',
#  '棋力',
#  '棋子',
#  '棋士',
#  '棋盤',
#  '女子',
#  '台灣',
#  '唐韦星',
#  '職業',
#  '国际',
#  '古力',
#  '冠军',
#  '本赛',
#  '日本',
#  '世界']

# %%
import jieba.posseg as pseg

def grade_term(lst):
    anotherlst=[]
    for i in range(len(lst)):
        score=0
        sentence=pseg.cut(lst[i][0])
        for w in sentence:
            if w.flag in ['n','nz','nt','nr','ns','nw']:
                score+=1
        anotherlst.append(score)
    newlst=[]
    for  i in range(len(anotherlst)):
        newlst.append([lst[i][0],lst[i][-1],anotherlst[i]])
    return newlst
grade_term(lst)
# Out:
# [['定段', '14', 1],
#  ['江流儿', '30', 2],
#  ['雷凌云', '21', 2],
#  ['云子', '26', 1],
#  ['雙人圍', '12', 1],
#  ['江流', '28', 1],
#  ['劫材', '11', 1],
#  ['对局者', '21', 1],
#  ['唐韋星', '8', 1],
#  ['方圓社', '39', 2],
#  ['棋鬼王', '11', 2],
#  ['定段赛', '8', 1],
#  ['轮于', '13', 0],
#  ['天元战', '11', 1],
#  ['本届', '9', 0],
#  ['循环圈', '8', 0],
#  ['預選', '7', 0],
#  ['齐鲁晚', '10', 1],
#  ['本身劫', '8', 0],
#  ['碁聖', '7', 0],
#  ['强败者', '8', 1],
#  ['deepmind', '10', 0],
#  ['御城棋', '11', 2],
#  ['杯冠军', '13', 1],
#  ['時代', '10', 1],
#  ['年道', '9', 0],
#  ['方胜', '14', 1],
#  ['廣島', '7', 1],
#  ['上届', '6', 0],
#  ['免选', '7', 0],
#  ['挑战者', '8', 1],
#  ['黑嘉嘉', '9', 1],
#  ['淡路修', '7', 1],
#  ['天台', '8', 1],
#  ['聂卫平', '6', 1],
#  ['任中', '9', 0],
#  ['山城宏', '9', 2],
#  ['等级分', '6', 0],
#  ['贴目', '6', 1],
#  ['臺北市', '6', 1],
#  ['岩本', '8', 1],
#  ['甘肃', '7', 1],
#  ['白昕卉', '11', 1],
#  ['張凱馨', '8', 1],
#  ['丈和', '23', 0],
#  ['晋级', '6', 1],
#  ['丹朱', '8', 1],
#  ['瀨越', '6', 1],
#  ['楊子', '7', 1],
#  ['因碩', '8', 1],
#  ['刘小光', '7', 1],
#  ['轮败者', '10', 1],
#  ['1轮', '8', 1],
#  ['区', '16', 1],
#  ['男子组', '8', 1],
#  ['劫爭', '13', 0],
#  ['韩元', '19', 1],
#  ['女子组', '9', 1],
#  ['小林觉', '9', 1],
#  ['擂台赛', '8', 1],
#  ['赛棋手', '6', 2],
#  ['黄河杯', '8', 1],
#  ['女子棋', '7', 2],
#  ['訓練', '6', 0],
#  ['楊子萱', '6', 2],
#  ['荒木氏', '6', 1],
#  ['擂台', '6', 0],
#  ['决赛第', '6', 1],
#  ['强败者获', '6', 1],
#  ['專案', '6', 1],
#  ['俘子', '6', 1],
#  ['柯潔', '6', 1],
#  ['分至', '6', 0],
#  ['本戰', '6', 1],
#  ['过惕生', '7', 0],
#  ['联棋', '11', 0],
#  ['橋本', '7', 1],
#  ['复赛', '9', 0],
#  ['圍棋界', '7', 1],
#  ['城围', '7', 1],
#  ['俞俐均', '10', 1],
#  ['届中', '6', 0],
#  ['通算', '12', 0],
#  ['codice', '6', 0],
#  ['聯', '9', 0],
#  ['朝日新', '7', 1],
#  ['绝艺', '6', 1],
#  ['天元', '7', 0],
#  ['王座', '6', 1],
#  ['邱峻', '7', 1],
#  ['灵杯', '8', 1],
#  ['棋圣', '13', 1],
#  ['女流名人', '6', 2],
#  ['黄龙士', '9', 2],
#  ['队获得', '7', 1],
#  ['謝依旻', '7', 0],
#  ['颗子', '12', 1],
#  ['挑戰者', '7', 1],
#  ['組織', '13', 0],
#  ['中環盃', '8', 0],
#  ['农心杯', '6', 1],
#  ['赵南哲', '7', 1],
#  ['新布石', '6', 1],
#  ['應昌', '6', 1],
#  ['玩家', '7', 1],
#  ['黑子', '8', 1],
#  ['外勢', '9', 1],
#  ['學習', '9', 0],
#  ['深入', '8', 0],
#  ['胜率', '9', 1],
#  ['收官', '6', 1],
#  ['位棋', '6', 1],
#  ['资格赛', '8', 1],
#  ['方棋子', '10', 2],
#  ['全国性', '9', 1],
#  ['白方', '6', 1],
#  ['际象棋', '9', 0],
#  ['李世乭', '7', 1],
#  ['年為', '8', 0],
#  ['人戰', '10', 1],
#  ['亚洲', '6', 1],
#  ['队和', '10', 1],
#  ['名誉', '7', 1],
#  ['打劫', '10', 0],
#  ['理光', '9', 1],
#  ['霸王', '7', 1],
#  ['飛刀', '9', 1],
#  ['得到', '8', 0],
#  ['聂卫', '10', 1],
#  ['正夫', '8', 1],
#  ['本选赛', '6', 0],
#  ['只棋子', '6', 1],
#  ['半决赛', '8', 1],
#  ['妖刀', '12', 1],
#  ['雙人', '7', 1],
#  ['家康', '7', 1],
#  ['网棋', '7', 1],
#  ['十一', '7', 0],
#  ['執白', '6', 0],
#  ['主将', '6', 1],
#  ['國流', '8', 1],
#  ['目外', '8', 0],
#  ['经过', '10', 0],
#  ['更具', '6', 0],
#  ['负', '9', 0],
#  ['中华台北', '8', 2],
#  ['腾讯', '10', 1],
#  ['李昌镐', '6', 1],
#  ['中盘', '8', 1],
#  ['頭銜者', '10', 1],
#  ['年代表', '6', 1],
#  ['王座戰', '9', 1],
#  ['棋聖', '8', 1],
#  ['南韓首爾', '6', 1],
#  ['碁聖戰', '6', 0],
#  ['國手', '9', 1],
#  ['混双赛', '6', 1],
#  ['江戶', '6', 1],
#  ['奖金为', '8', 1],
#  ['賽進行', '7', 0],
#  ['国女子', '6', 2],
#  ['決定戰', '7', 1],
#  ['網路圍', '6', 1],
#  ['金明训', '7', 1],
#  ['余棋手', '6', 1],
#  ['团体赛', '7', 1],
#  ['10万', '7', 0],
#  ['圍棋高', '6', 0],
#  ['朴志恩', '6', 1],
#  ['开局', '6', 1],
#  ['职业', '6', 1],
#  ['吴清源', '10', 1],
#  ['海峰', '7', 1],
#  ['级分', '8', 1],
#  ['衢州市', '6', 1],
#  ['王晨星', '8', 2],
#  ['段胜', '6', 1],
#  ['視台', '9', 1],
#  ['產生', '6', 1],
#  ['正式', '7', 0],
#  ['聖戰', '10', 1],
#  ['王戰', '11', 2],
#  ['排名', '7', 0],
#  ['賽制', '10', 1],
#  ['抽签', '6', 0],
#  ['金荣', '6', 1],
#  ['国手', '8', 1],
#  ['分先', '6', 0],
#  ['最強', '6', 0],
#  ['中方', '7', 0],
#  ['导致', '8', 0],
#  ['曾经', '7', 0],
#  ['担任', '6', 0],
#  ['9日', '7', 0],
#  ['當作', '6', 1],
#  ['豐田', '6', 1],
#  ['座戰', '6', 1],
#  ['屆本', '6', 0],
#  ['击败', '6', 0],
#  ['组合', '7', 0],
#  ['来自', '6', 0],
#  ['下棋', '6', 0],
#  ['武汉', '6', 1],
#  ['聯盟', '10', 1],
#  ['成绩', '8', 1],
#  ['引起', '6', 0],
#  ['只能', '6', 0],
#  ['负李', '6', 1],
#  ['年底', '7', 0],
#  ['下午', '9', 0],
#  ['單敗', '6', 1],
#  ['耀烨', '6', 1],
#  ['重庆', '8', 1],
#  ['項目', '12', 1],
#  ['手棋', '7', 1],
#  ['棋王赛', '7', 1],
#  ['禁止', '6', 0],
#  ['為日本', '7', 1],
#  ['歐洲', '11', 1],
#  ['黑龙江', '8', 1],
#  ['羋昱廷', '6', 0],
#  ['晏天章', '8', 1],
#  ['提子', '12', 1],
#  ['江苏', '6', 1],
#  ['混双', '8', 0],
#  ['白子', '6', 1],
#  ['棋經', '6', 1],
#  ['选手', '7', 0],
#  ['黄龙', '7', 1],
#  ['男棋手', '6', 2],
#  ['背景', '8', 1],
#  ['循环', '6', 0],
#  ['日', '9', 0],
#  ['国际象', '7', 2],
#  ['杯世界', '6', 1],
#  ['国参加', '6', 1],
#  ['獲勝者', '6', 0],
#  ['预选', '13', 0],
#  ['人類', '6', 1],
#  ['着法', '7', 0],
#  ['主办', '8', 0],
#  ['围棋赛', '8', 1],
#  ['申旻埈', '8', 0],
#  ['崔哲瀚', '9', 1],
#  ['连胜', '11', 1],
#  ['名人战', '7', 1],
#  ['亞軍', '9', 1],
#  ['步棋', '10', 1],
#  ['镇围棋', '6', 1],
#  ['个人', '6', 1],
#  ['组', '36', 0],
#  ['王积薪', '8', 1],
#  ['家家督', '6', 1],
#  ['目半', '8', 0],
#  ['為名人', '10', 1],
#  ['还棋头', '7', 1],
#  ['vs', '10', 0],
#  ['预选赛', '7', 1],
#  ['对局', '8', 1],
#  ['黃士', '9', 1],
#  ['推广', '9', 0],
#  ['挑战', '6', 0],
#  ['人以', '7', 1],
#  ['姜堰', '7', 1],
#  ['数据', '8', 1],
#  ['分析', '7', 0],
#  ['人围', '6', 1],
#  ['交流', '10', 1],
#  ['軟體', '6', 1],
#  ['方圓', '16', 1],
#  ['跡目', '8', 1],
#  ['年日本', '10', 1],
#  ['衢州', '6', 1],
#  ['亞藝盃', '6', 0],
#  ['其它', '11', 0],
#  ['网选', '8', 1],
#  ['负于', '8', 0],
#  ['勝制', '8', 0],
#  ['獲得', '8', 0],
#  ['此頭銜', '6', 1],
#  ['杯本赛', '6', 1],
#  ['名人賽', '11', 1],
#  ['关东', '6', 1],
#  ['團隊', '6', 1],
#  ['棋品', '6', 1],
#  ['道策', '9', 1],
#  ['则是', '6', 0],
#  ['弈秋', '8', 1],
#  ['複雜', '8', 0],
#  ['小飛', '7', 1],
#  ['透過', '9', 0],
#  ['杯围棋', '6', 0],
#  ['数学', '6', 1],
#  ['围棋最', '6', 0],
#  ['基金會', '8', 1],
#  ['中國圍', '6', 1],
#  ['对抗赛', '11', 1],
#  ['际围棋', '6', 0],
#  ['棋世界', '6', 2],
#  ['本棋院', '6', 1],
#  ['服务器', '6', 1],
#  ['国家队', '7', 1],
#  ['是围棋', '8', 0],
#  ['围棋网', '6', 0],
#  ['自我訓練', '7', 0],
#  ['淘汰赛', '6', 1],
#  ['棋院和', '6', 1],
#  ['内围棋', '6', 1],
#  ['重要性', '6', 1],
#  ['世本因', '6', 1],
#  ['个人赛', '8', 1],
#  ['為本因', '6', 0],
#  ['選拔賽', '8', 1],
#  ['段位的', '6', 1],
#  ['输给了', '6', 0],
#  ['市围棋', '6', 1],
#  ['刀定式', '7', 2],
#  ['组成的', '6', 0],
#  ['俱乐部', '6', 1],
#  ['被视为', '6', 0],
#  ['研究的', '7', 0],
#  ['將棋界', '6', 1],
#  ['赵晨宇', '6', 1],
#  ['被叫做', '6', 0],
#  ['电王战', '6', 2],
#  ['假眼活', '6', 1],
#  ['段以', '7', 0],
#  ['桐山杯', '11', 2],
#  ['方式', '7', 1],
#  ['之一', '31', 0],
#  ['体育', '9', 0],
#  ['名单', '13', 1],
#  ['位提白', '6', 0],
#  ['朴鋕恩', '6', 2],
#  ['方用时', '6', 2],
#  ['规则', '9', 1],
#  ['元战', '6', 1],
#  ['制度', '14', 1],
#  ['工智', '7', 1],
#  ['業圍', '6', 1],
#  ['因坊', '8', 1],
#  ['国棋', '7', 1],
#  ['之间', '6', 0],
#  ['氏杯', '8', 1],
#  ['国业', '10', 1],
#  ['酒店', '6', 1],
#  ['運算', '9', 0],
#  ['單位', '7', 1],
#  ['定式', '10', 1],
#  ['最高', '10', 0],
#  ['全國', '6', 1],
#  ['本学', '6', 1],
#  ['传说', '7', 1],
#  ['網站', '7', 1],
#  ['最佳', '7', 0],
#  ['实业', '6', 1],
#  ['国职', '7', 1],
#  ['院和', '6', 1],
#  ['南京', '6', 1],
#  ['高段', '7', 0],
#  ['支援', '6', 0],
#  ['政府', '7', 1],
#  ['同樣', '6', 0],
#  ['能力', '8', 1],
#  ['表团', '10', 1],
#  ['国流', '11', 1],
#  ['棋牌', '7', 1],
#  ['參數', '7', 1],
#  ['全部', '7', 1],
#  ['模仿', '6', 0],
#  ['团队', '6', 1],
#  ['三轮', '6', 0],
#  ['佔角', '6', 1],
#  ['對戰', '8', 1],
#  ['讀賣', '7', 0],
#  ['元老', '8', 1],
#  ['應用', '11', 0],
#  ['实际', '7', 1],
#  ['再次', '6', 0],
#  ['中学', '6', 1],
#  ['网上', '6', 0],
#  ['卫平', '12', 1],
#  ['則因', '6', 0],
#  ['中部', '7', 0],
#  ['顶尖', '8', 1],
#  ['系列', '6', 0],
#  ['原因', '6', 1],
#  ['国象', '8', 1],
#  ['这种', '9', 0],
#  ['邀请', '8', 0],
#  ['赛于', '18', 0],
#  ['计数', '7', 1],
#  ['九段', '7', 0],
#  ['設定', '8', 0],
#  ['各地', '7', 0],
#  ['為台', '6', 1],
#  ['李东勋', '6', 1],
#  ['预赛', '6', 0],
#  ['长期', '6', 0],
#  ['卡斯', '6', 0],
#  ['貼目', '8', 1],
#  ['比對', '6', 0],
#  ['真眼', '10', 0],
#  ['之莹', '6', 1],
#  ['工作', '8', 0],
#  ['富士', '6', 1],
#  ['通过', '12', 0],
#  ['執黑', '6', 0],
#  ['圣战', '9', 1],
#  ['大小', '6', 0],
#  ['读秒', '9', 1],
#  ['世代', '6', 0],
#  ['裁判', '6', 0],
#  ['程度', '6', 1],
#  ['卡尔', '6', 0],
#  ['台赛', '7', 1],
#  ['棋協', '6', 2],
#  ['日本圍', '7', 1],
#  ['12万', '6', 0],
#  ['实力', '7', 1],
#  ['安節', '9', 1],
#  ['陕西', '6', 1],
#  ['全运', '6', 1],
#  ['显著', '9', 0],
#  ['智能', '8', 1],
#  ['參考', '6', 0],
#  ['当时', '7', 0],
#  ['宣布', '8', 0],
#  ['网格', '8', 1],
#  ['坐标', '8', 0],
#  ['棋艺', '7', 1],
#  ['循環', '6', 0],
#  ['極其', '6', 0],
#  ['世襲', '6', 0],
#  ['達成', '8', 0],
#  ['日程', '6', 1],
#  ['每年', '9', 0],
#  ['東京', '6', 1],
#  ['专家', '9', 1],
#  ['规定', '6', 1],
#  ['方一', '6', 1],
#  ['本薰', '6', 0],
#  ['提升', '9', 0],
#  ['之子', '7', 0],
#  ['占据', '7', 0],
#  ['1月1日', '7', 0],
#  ['江维', '6', 1],
#  ['升降', '6', 0],
#  ['连续', '8', 0],
#  ['佛乘', '6', 1],
#  ['德川', '6', 1],
#  ['报名', '6', 0],
#  ['利益', '8', 1],
#  ['赛前', '6', 0],
#  ['连接', '6', 0],
#  ['先前', '6', 0],
#  ['东京', '6', 1],
#  ['创办', '11', 0],
#  ['手割', '6', 0],
#  ['打算', '6', 0],
#  ['實做', '7', 0],
#  ['可能', '10', 0],
#  ['变得', '10', 0],
#  ['歷史', '6', 1],
#  ['坊門', '6', 1],
#  ['利用', '6', 1],
#  ['十二', '6', 0],
#  ['台北', '6', 1],
#  ['成员', '6', 1],
#  ['消劫', '9', 0],
#  ['领域', '7', 1],
#  ['之父', '6', 1],
#  ['争夺', '6', 0],
#  ['2万', '7', 0],
#  ['得第', '6', 0],
#  ['开发', '13', 0],
#  ['佐為', '10', 0],
#  ['己方', '6', 1],
#  ['马晓春', '8', 1],
#  ['外卡', '6', 1],
#  ['後黑', '7', 1],
#  ['29日', '6', 0],
#  ['加以', '6', 0],
#  ['知得', '9', 0],
#  ['高校', '6', 1],
#  ['很多', '6', 0],
#  ['受到', '8', 0],
#  ['相鄰', '6', 0],
#  ['小组', '6', 1],
#  ['打入', '8', 0],
#  ['出场', '9', 1],
#  ['彼此', '8', 0],
#  ['分數', '6', 1],
#  ['停止', '6', 0],
#  ['胜出', '8', 0],
#  ['局', '8', 1],
#  ['为', '9', 0],
#  ['距離', '7', 1],
#  ['挑战赛', '9', 1],
#  ['点', '6', 0],
#  ['李小溪', '6', 2],
#  ['周俊勳', '7', 1],
#  ['月', '7', 0],
#  ['3日', '6', 0],
#  ['6日', '8', 0],
#  ['将于', '6', 0],
#  ['聞社', '7', 0],
#  ['創立', '7', 0],
#  ['4日', '6', 0],
#  ['定石', '6', 1],
#  ['下到', '6', 0],
#  ['棋以', '6', 1],
#  ['釋出', '8', 0],
#  ['赛制', '10', 1],
#  ['种子', '7', 1],
#  ['香港', '6', 1],
#  ['腾讯野', '6', 2],
#  ['思考', '6', 0],
#  ['小時', '8', 0],
#  ['单败淘', '6', 1],
#  ['放送', '6', 0],
#  ['获胜者', '7', 1],
#  ['复杂性', '10', 1],
#  ['同时', '8', 0],
#  ['互相', '8', 0],
#  ['方各', '6', 0],
#  ['职业棋手', '7', 2],
#  ['棋戰', '7', 1],
#  ['人数', '7', 1],
#  ['技巧', '8', 1],
#  ['附近', '7', 0],
#  ['則是', '6', 0],
#  ['女流', '6', 1],
#  ['际象', '6', 1],
#  ['平面', '6', 1],
#  ['这样', '8', 0],
#  ['直线', '6', 1],
#  ['阶段', '6', 1],
#  ['虽然', '7', 0],
#  ['夺得', '6', 0],
#  ['名棋手', '7', 1],
#  ['意思', '7', 1],
#  ['包圍', '9', 0],
#  ['段位制', '10', 1],
#  ['超過', '6', 0],
#  ['改稱', '6', 0],
#  ['正官庄杯', '7', 2],
#  ['世纪', '9', 1],
#  ['圍棋賽', '7', 1],
#  ['强战', '6', 0],
#  ['樊麾', '11', 2],
#  ['必須', '6', 0],
#  ['formula', '6', 0],
#  ['范西屏', '7', 1],
#  ['国手战', '6', 2],
#  ['互联网', '9', 1],
#  ['扇興杯', '6', 1],
#  ['名人戰', '6', 1],
#  ['对围棋', '6', 0],
#  ['豐田杯', '6', 1],
#  ['通常', '9', 0],
#  ['舉辦', '9', 0],
#  ['主要', '8', 0],
#  ['手合', '7', 1],
#  ['国棋手', '7', 2],
#  ['周俊', '7', 1],
#  ['真露杯', '7', 0],
#  ['中環', '7', 1],
#  ['数子', '9', 1],
#  ['得天元', '6', 0],
#  ['赞助商', '6', 0],
#  ['3月4日', '6', 0],
#  ['周俊勋', '7', 1],
#  ['數子法', '6', 2],
#  ['杭州', '8', 1],
#  ['世乭', '6', 0],
#  ['資料', '6', 1],
#  ['棋赛', '6', 1],
#  ['工程', '6', 1],
#  ['淘汰', '6', 0],
#  ['棋賽', '8', 1],
#  ['赛事', '10', 1],
#  ['广州', '9', 1],
#  ['對弈中', '7', 0],
#  ['厚勢', '10', 1],
#  ['安排', '8', 0],
#  ['生涯', '7', 1],
#  ['2轮', '8', 1],
#  ['宇宙流', '7', 2],
#  ['上海', '6', 1],
#  ['对于', '9', 0],
#  ['胜负', '8', 0],
#  ['名将', '7', 1],
#  ['专业', '6', 1],
#  ['快棋', '6', 1],
#  ['获得', '6', 0],
#  ['存在', '6', 0],
#  ['立於', '6', 1],
#  ['举办的', '6', 0],
#  ['年間', '7', 0],
#  ['年年', '6', 0],
#  ['山东', '6', 1],
#  ['方可', '7', 1],
#  ['元和', '7', 0],
#  ['辜梓豪', '9', 1],
#  ['同名', '6', 1],
#  ['罗玄', '7', 1],
#  ['方捷', '7', 1],
#  ['淘汰賽', '9', 0],
#  ['局棋', '6', 1],
#  ['陈浩', '9', 1],
#  ['男子', '7', 1],
#  ['结果', '6', 1],
#  ['位', '6', 0],
#  ['丁烈', '6', 1],
#  ['運用', '11', 0],
#  ['围棋名人战', '6', 1],
#  ['林海峰', '7', 1],
#  ['贊助', '10', 0],
#  ['人机', '6', 1],
#  ['世界第', '7', 1],
#  ['加藤', '6', 1],
#  ['日和', '6', 0],
#  ['年獲', '6', 0],
#  ['选拔', '6', 0],
#  ['讀賣新聞', '6', 1],
#  ['職業圍棋', '7', 1],
#  ['小林光', '17', 2],
#  ['年日', '9', 0],
#  ['計算', '6', 0],
#  ['日围棋', '6', 0],
#  ['围棋大', '6', 0],
#  ['对弈', '12', 0],
#  ['錦標賽', '6', 1],
#  ['丁明君', '6', 1],
#  ['赛冠军', '14', 2],
#  ['伺服器', '6', 1],
#  ['届比', '7', 0],
#  ['综合', '9', 0],
#  ['業棋士', '7', 1],
#  ['国务', '7', 1],
#  ['为围棋', '6', 0],
#  ['张馨月', '6', 1],
#  ['女子围', '7', 1],
#  ['年度', '9', 1],
#  ['无锡市', '6', 1],
#  ['程式碼', '7', 1],
#  ['顾水如', '6', 1],
#  ['出线', '12', 1],
#  ['棋水平', '6', 2],
#  ['公開賽', '8', 1],
#  ['年取', '6', 0],
#  ['數子', '6', 1],
#  ['本赛第', '7', 1],
#  ['分散式', '6', 1],
#  ['指围棋', '7', 1],
#  ['围棋队', '8', 1],
#  ['网络', '9', 1],
#  ['對弈', '8', 0],
#  ['国规则', '6', 2],
#  ['為台灣', '8', 1],
#  ['使用者', '6', 1],
#  ['关西', '10', 1],
#  ['目的', '10', 1],
#  ['改名為', '7', 0],
#  ['優勝者', '7', 1],
#  ['為了', '9', 0],
#  ['版本', '7', 1],
#  ['团体', '6', 1],
#  ['段位', '7', 1],
#  ['周睿', '13', 0],
#  ['决赛中', '6', 1],
#  ['落子', '8', 1],
#  ['資源', '7', 1],
#  ['程式', '6', 1],
#  ['电视', '6', 1],
#  ['弟子', '11', 1],
#  ['為圍棋', '6', 0],
#  ['小光', '19', 1],
#  ['抗賽', '6', 0],
#  ['家督', '6', 1],
#  ['白棋', '6', 1],
#  ['券杯', '7', 1],
#  ['實利', '6', 1],
#  ['晚报', '6', 1],
#  ['安井', '6', 1],
#  ['秀和', '14', 0],
#  ['限公', '8', 1],
#  ['名譽', '7', 1],
#  ['發行', '9', 0],
#  ['挑戰', '7', 0],
#  ['蒙地', '8', 1],
#  ['新布局', '6', 1],
#  ['大赛', '6', 1],
#  ['武宮', '7', 1],
#  ['报道', '6', 0],
#  ['直播', '9', 0],
#  ['獲勝', '7', 0],
#  ['和韩', '7', 1],
#  ['協會', '6', 1],
#  ['團體', '6', 1],
#  ['采取', '6', 0],
#  ['中日', '10', 0],
#  ['才能', '11', 0],
#  ['守角', '9', 1],
#  ['现代', '6', 0],
#  ['浙江', '9', 1],
#  ['之間', '10', 0],
#  ['赛区', '10', 1],
#  ['已經', '6', 0],
#  ['造成', '7', 0],
#  ['例子', '6', 1],
#  ['当今', '6', 0],
#  ['高目', '7', 1],
#  ['棋圣战', '9', 1],
#  ['日本队', '6', 1],
#  ['郭闻潮', '6', 1],
#  ['方先', '7', 1],
#  ['小时', '7', 1],
#  ['棋坛', '6', 1],
#  ['策略', '6', 1],
#  ['曹薰', '6', 1],
#  ['本身', '6', 0],
#  ['男女', '6', 1],
#  ['星位', '7', 1],
#  ['丁浩', '7', 1],
#  ['全国', '8', 1],
#  ['征子', '6', 1],
#  ['原子', '6', 1],
#  ['发生', '8', 0],
#  ['整個', '7', 0],
#  ['參加', '9', 0],
#  ['目數', '7', 1],
#  ['個黑', '6', 0],
#  ['秀策', '6', 1],
#  ['方用', '6', 1],
#  ['弈城', '7', 1],
#  ['棋盘', '17', 1],
#  ['首次', '9', 0],
#  ['长考', '7', 0],
#  ['秀行', '6', 1],
#  ['风格', '6', 1],
#  ['電腦圍', '8', 1],
#  ['亚军', '7', 1],
#  ['业围', '7', 1],
#  ['比目法', '11', 1],
#  ['日本的', '6', 1],
#  ['9x9', '8', 0],
#  ['类似', '9', 0],
#  ['三三', '7', 0],
#  ['手数', '6', 1],
#  ['連接', '6', 0],
#  ['官方', '6', 1],
#  ['繼承', '7', 0],
#  ['作戰', '6', 0],
#  ['国棋院', '10', 2],
#  ['黑方', '7', 1],
#  ['業餘', '6', 1],
#  ['個角', '7', 1],
#  ['许嘉阳', '6', 1],
#  ['分為', '6', 0],
#  ['王世', '6', 1],
#  ['國內', '8', 0],
#  ['崔精', '8', 1],
#  ['国围', '6', 1],
#  ['機會', '7', 1],
#  ['陳耀燁', '7', 1],
#  ['職業棋', '6', 2],
#  ['职业围棋', '7', 1],
#  ['范胤', '6', 1],
#  ['世界最', '6', 1],
#  ['芮乃伟', '7', 1],
#  ['官子', '6', 1],
#  ['李昌鎬', '8', 1],
#  ['演算法', '8', 1],
#  ['朴文垚', '7', 1],
#  ['浙江省', '8', 1],
#  ['屆起', '11', 0],
#  ['阿含', '9', 1],
#  ['決賽', '9', 1],
#  ['按照', '11', 0],
#  ['少年', '6', 0],
#  ['赵治勋', '6', 1],
#  ['本年度', '6', 1],
#  ['终局', '6', 1],
#  ['決定', '6', 0],
#  ['情況下', '6', 1],
#  ['棋局', '7', 1],
#  ['情况', '10', 1],
#  ['處理', '7', 0],
#  ['全局', '7', 1],
#  ['执黑', '8', 0],
#  ['林家', '7', 1],
#  ['交叉', '7', 1],
#  ['擊敗', '11', 0],
#  ['變成', '6', 0],
#  ['木谷', '6', 1],
#  ['强赛', '7', 0],
#  ['戰鬥', '7', 0],
#  ['任何', '8', 0],
#  ['內容', '6', 1],
#  ['日本棋院', '6', 2],
#  ['日至', '6', 0],
#  ['國際', '6', 1],
#  ['广西', '6', 1],
#  ['曹大元', '6', 1],
#  ['應對', '7', 0],
#  ['尤其', '6', 0],
#  ['整个', '10', 0],
#  ['职业棋', '8', 2],
#  ['国内', '6', 0],
#  ['改名', '6', 0],
#  ['發生', '7', 0],
#  ['叫吃', '10', 0],
#  ['冠亚军', '6', 1],
#  ['全日本', '7', 1],
#  ['織田', '6', 1],
#  ['藤泽', '8', 1],
#  ['广东', '6', 1],
#  ['海峰棋院', '10', 2],
#  ['三子', '8', 0],
#  ['局面', '9', 1],
#  ['重要', '7', 0],
#  ['年围', '6', 1],
#  ['西洋棋', '6', 1],
#  ['棋聖戰', '7', 2],
#  ['富士通杯', '8', 1],
#  ['非常', '8', 0],
#  ['董彦', '9', 1],
#  ['對手', '6', 0],
#  ['選手', '8', 0],
#  ['韓國棋院', '6', 2],
#  ['帳號', '7', 1],
#  ['以後', '6', 1],
#  ['公开', '6', 0],
#  ['圍棋棋', '8', 0],
#  ['棋协会', '6', 2],
#  ['關西棋院', '7', 2],
#  ['職業圍', '6', 1],
#  ['种子选', '6', 1],
#  ['中盤', '10', 1],
#  ['队以', '6', 1],
#  ['中日韩', '6', 1],
#  ['杭州市', '6', 1],
#  ['推出', '7', 0],
#  ['等级', '8', 0],
#  ['將棋', '8', 1],
#  ['變化', '6', 0],
#  ['棋具', '7', 1],
#  ['棋協會', '8', 2],
#  ['陈祖德', '13', 1],
#  ['年因', '6', 0],
#  ['严欢', '6', 1],
#  ['位置', '8', 0],
#  ['江铸久', '8', 1],
#  ['联合', '10', 0],
#  ['为世界', '7', 1],
#  ['对局费', '7', 1],
#  ['围棋规则', '6', 1],
#  ['执白', '7', 0],
#  ['李康', '6', 1],
#  ['結果', '7', 1],
#  ['活棋', '6', 1],
#  ['决赛', '12', 1],
#  ['胡耀宇', '6', 1],
#  ['國際賽', '6', 1],
#  ['了围棋', '6', 0],
#  ['應氏', '7', 1],
#  ['三段', '6', 0],
#  ['這種', '7', 0],
#  ['番棋', '6', 1],
#  ['赞助', '15', 0],
#  ['传统', '6', 1],
#  ['影响', '9', 0],
#  ['城市', '6', 1],
#  ['国家体', '6', 2],
#  ['掛角', '7', 1],
#  ['秀哉', '6', 0],
#  ['奖金', '7', 1],
#  ['特定', '6', 0],
#  ['局部', '6', 1],
#  ['年舉', '7', 0],
#  ['棋战', '7', 1],
#  ['古灵益', '6', 1],
#  ['階段', '8', 1],
#  ['年台', '6', 0],
#  ['達到', '10', 0],
#  ['地區', '6', 1],
#  ['自己的', '8', 0],
#  ['比赛中', '10', 0],
#  ['为围', '6', 0],
#  ['实战', '7', 0],
#  ['兒子', '6', 1],
#  ['停辦', '13', 0],
#  ['比賽中', '7', 0],
#  ['算砂', '6', 1],
#  ['秀甫', '6', 1],
#  ['李喆', '6', 1],
#  ['公開', '6', 0],
#  ['公司', '7', 1],
#  ['黑貼', '7', 1],
#  ['大飛', '8', 1],
#  ['张璇', '7', 1],
#  ['本局', '6', 1],
#  ['依照', '6', 0],
#  ['職業棋手', '7', 2],
#  ['技术', '10', 1],
#  ['初段', '11', 0],
#  ['读秒的', '6', 1],
#  ['類似', '6', 0],
#  ['中国', '14', 1],
#  ['发展', '8', 0],
#  ['日本围', '7', 1],
#  ['李世石', '9', 1],
#  ['云南', '6', 1],
#  ['安冬旭', '6', 1],
#  ['奧林匹亞', '6', 1],
#  ['安井家', '6', 1],
#  ['韩国', '9', 1],
#  ['形態', '6', 1],
#  ['年改', '7', 0],
#  ['年共', '6', 0],
#  ['象棋', '6', 0],
#  ['多数', '8', 0],
#  ['大学', '7', 1],
#  ['北京', '7', 1],
#  ['成為', '10', 0],
#  ['分鐘', '12', 0],
#  ['某些', '7', 0],
#  ['棋手在', '6', 1],
#  ['周泓余', '6', 1],
#  ['范廷鈺', '7', 1],
#  ['是日本', '7', 1],
#  ['重視', '6', 0],
#  ['勝率', '6', 1],
#  ['頭銜', '9', 1],
#  ['台灣圍棋', '8', 1],
#  ['届应', '6', 0],
#  ['参赛', '13', 1],
#  ['柁嘉熹', '6', 1],
#  ['年以', '6', 0],
#  ['年代', '11', 0],
#  ['佟禹林', '6', 1],
#  ['是台灣', '8', 1],
#  ['黑白', '7', 0],
#  ['時候', '6', 1],
#  ['金志锡', '6', 2],
#  ['然而', '8', 0],
#  ['保留', '10', 0],
#  ['是圍棋', '6', 0],
#  ['實力', '9', 1],
#  ['此時', '8', 0],
#  ['連勝', '6', 1],
#  ['人民', '6', 1],
#  ['關西', '6', 1],
#  ['成績', '6', 1],
#  ['職業棋士', '7', 2],
#  ['網路', '9', 1],
#  ['黑棋', '13', 1],
#  ['孔杰', '6', 1],
#  ['宋容慧', '8', 1],
#  ['出現', '6', 0],
#  ['要求', '7', 0],
#  ['围棋协会', '6', 1],
#  ['或者', '9', 0],
#  ['圍棋協', '6', 1],
#  ['棋形', '17', 1],
#  ['雖然', '6', 0],
#  ['遊戲', '6', 1],
#  ['睦镇硕', '6', 0],
#  ['抗赛', '7', 0],
#  ['三番棋', '8', 1],
#  ['先手', '11', 1],
#  ['是由', '6', 0],
#  ['野狐', '7', 1],
#  ['特殊', '6', 0],
#  ['蔡竞', '6', 1],
#  ['首轮', '11', 0],
#  ['進入', '6', 0],
#  ['丁伟', '6', 1],
#  ['日文', '7', 1],
#  ['模樣', '13', 1],
#  ['後因', '7', 1],
#  ['段和', '6', 0],
#  ['選擇', '7', 0],
#  ['木谷實', '7', 1],
#  ['讓子', '8', 0],
#  ['彭荃', '6', 1],
#  ['價值', '6', 1],
#  ['年舉辦', '7', 0],
#  ['王磊', '6', 1],
#  ['当时中', '7', 0],
#  ['届起', '7', 0],
#  ['国队', '9', 1],
#  ['职业围', '6', 1],
#  ['常昊', '7', 1],
#  ['唐奕', '8', 1],
#  ['坂田', '7', 1],
#  ['研究', '6', 0],
#  ['本賽', '6', 1],
#  ...]

# %%
len(filtered_lst2)
# Out:
# 571

# %%
len(filtered_lst)
# Out:
# 576

# %%
#filter part
import jieba.posseg as pseg
lst2=[]
for i in range(len(ruled_out)):
    sentence=pseg.cut(ruled_out[i])
    lst2.append(sentence)
for i in range(len(lst2)):
    for w in lst2[i]:
        print(w.word,w.flag)
# Out:
# 雙 m
# 人圍 n
# 对局 n
# 者 k
# 定段 n
# 赛 v
# 轮于 v
# 本届 r
# 循环 vn
# 圈 q
# 預選 v
# 齐鲁 nr
# 晚 tg
# 本身 r
# 劫 v
# 碁 yg
# 聖 j
# 强 a
# 败者 n
# deepmind eng
# 御 vg
# 城 n
# 棋 n
# 杯 q
# 冠军 n
# 年 m
# 道 q
# 上届 j
# 免选 v
# 淡路 n
# 修 v
# 任中 r
# 等级分 l
# 臺 y
# 北 f
# 市 n
# 丈 q
# 和 c
# 因 p
# 碩 n
# 轮 zg
# 败者 n
# 1 m
# 轮 n
# 劫爭 vn
# 黄河 ns
# 杯 q
# 訓練 vn
# 荒木 n
# 氏 ng
# 擂台 v
# 决赛 n
# 第 m
# 强 a
# 败者 n
# 获 v
# 分 v
# 至 p
# 过惕 v
# 生 vn
# 联棋 v
# 复赛 vn
# 圍 v
# 棋界 n
# 俞俐 nr
# 均 d
# 届 m
# 中 f
# 通算 v
# codice eng
# 聯 zg
# 朝日 n
# 新 a
# 天元 q
# 队 n
# 获得 v
# 謝 v
# 依 v
# 旻 zg
# 挑 v
# 戰者 n
# 組織 v
# 中 f
# 環 v
# 盃 zg
# 农心 n
# 杯 q
# 學習 v
# 深入 v
# 际 ng
# 象棋 v
# 李 nr
# 世 ng
# 乭 zg
# 年 m
# 為 p
# 队 n
# 和 c
# 打劫 v
# 得到 v
# 本 r
# 选赛 v
# 只 d
# 棋子 n
# 十一 m
# 執白 v
# 目外 t
# 经过 p
# 更具 v
# 负 v
# 頭銜 n
# 者 k
# 年 m
# 代表 n
# 王座 nr
# 戰 zg
# 棋 n
# 聖 j
# 南 f
# 韓首爾 nr
# 碁 yg
# 聖 j
# 戰 vg
# 混 v
# 双赛 n
# 奖金 n
# 为 p
# 賽 v
# 進行 v
# 決定 v
# 戰 n
# 網路 n
# 圍 v
# 余 m
# 棋手 n
# 10 m
# 万 m
# 圍棋 v
# 高 a
# 正式 ad
# 排名 v
# 抽签 v
# 分先 d
# 最強 a
# 中方 f
# 导致 v
# 曾经 d
# 担任 v
# 9 m
# 日 m
# 當 p
# 作 n
# 座 q
# 戰 n
# 屆本 d
# 击败 v
# 组合 v
# 来自 v
# 下棋 v
# 引起 v
# 只能 v
# 负 v
# 李 nr
# 年底 t
# 下午 t
# 耀 v
# 烨 nr
# 禁止 v
# 為 zg
# 日本 ns
# 羋 o
# 昱 g
# 廷 g
# 混双 v
# 选手 v
# 循环 vn
# 日 m
# 杯 q
# 世界 n
# 国 n
# 参加 v
# 獲勝 v
# 者 k
# 预选 v
# 着 uz
# 法 j
# 主办 b
# 申 v
# 旻 x
# 埈 zg
# 镇 n
# 围棋 v
# 组 zg
# 家家 n
# 督 vg
# 目半 t
# 為 zg
# 名人 n
# 还 d
# 棋头 n
# vs eng
# 推广 v
# 挑战 vn
# 人 n
# 以 p
# 分析 vn
# 年 m
# 日本 ns
# 亞 j
# 藝 ng
# 盃 zg
# 其它 r
# 网 n
# 选 v
# 负于 v
# 勝制 vn
# 獲得 v
# 此 r
# 頭銜 n
# 杯 q
# 本赛 n
# 名人 n
# 賽 x
# 则 d
# 是 v
# 複 yg
# 雜 v
# 透過 v
# 杯 q
# 围棋 v
# 围棋 v
# 最 d
# 基金 n
# 會 zg
# 中國 ns
# 圍 v
# 际 ng
# 围棋 v
# 本 r
# 棋院 n
# 是 v
# 围棋 v
# 围棋网 i
# 自我 r
# 訓練 vn
# 棋院 n
# 和 c
# 内 n
# 围棋 v
# 世本 n
# 因 c
# 為 p
# 本 r
# 因 c
# 選拔 v
# 賽 n
# 段位 n
# 的 uj
# 输给 v
# 了 ul
# 市 n
# 围棋 v
# 组成 v
# 的 uj
# 被 p
# 视为 v
# 研究 vn
# 的 uj
# 將 d
# 棋界 n
# 被 p
# 叫做 v
# 假眼 n
# 活 vn
# 段 q
# 以 f
# 之一 r
# 体育 vn
# 位 m
# 提白 v
# 朴 nr
# 鋕 zg
# 恩 nr
# 元 m
# 战 n
# 之间 f
# 運算 vn
# 最高 a
# 最佳 z
# 院 n
# 和 c
# 高 a
# 段 q
# 支援 v
# 同樣 d
# 模仿 v
# 三轮 m
# 佔 v
# 角 n
# 對 p
# 戰 n
# 讀賣 v
# 應用 v
# 再次 d
# 网上 s
# 則 d
# 因 p
# 中部 f
# 系列 q
# 这种 r
# 邀请 v
# 赛于 v
# 九段 m
# 設定 v
# 各地 r
# 為 p
# 台 ns
# 预赛 vn
# 长期 d
# 卡斯 nrt
# 比對 d
# 真眼 d
# 之 u
# 莹 nr
# 工作 vn
# 通过 p
# 執黑 v
# 大小 b
# 世代 t
# 裁判 vn
# 卡尔 nrt
# 日本 ns
# 圍 x
# 12 m
# 万 m
# 显著 a
# 參考 v
# 当时 t
# 宣布 v
# 坐标 v
# 循環 vn
# 極其 d
# 世襲 vn
# 達成 v
# 每年 r
# 本 r
# 薰 v
# 提升 v
# 之 u
# 子 ng
# 占据 v
# 1 m
# 月 m
# 1 m
# 日 m
# 升降 v
# 连续 a
# 报名 v
# 赛前 t
# 连接 v
# 先前 t
# 创办 v
# 手割 v
# 打算 v
# 實做 v
# 可能 v
# 变得 v
# 十二 m
# 消劫 v
# 之 u
# 父 n
# 争夺 v
# 2 m
# 万 m
# 得 ud
# 第 m
# 开发 v
# 佐 vg
# 為 p
# 後 nr
# 黑 a
# 29 m
# 日 m
# 加以 v
# 知得 v
# 很多 m
# 受到 v
# 相鄰 v
# 打入 v
# 彼此 r
# 停止 v
# 胜出 v
# 为 p
# 点 m
# 月 m
# 3 m
# 日 m
# 6 m
# 日 m
# 将 d
# 于 p
# 聞社 l
# 創立 v
# 4 m
# 日 m
# 下 f
# 到 v
# 棋 n
# 以 p
# 釋出 v
# 思考 v
# 小 a
# 時 ng
# 单败 n
# 淘 v
# 放送 v
# 同时 c
# 互相 d
# 方 q
# 各 r
# 附近 f
# 則 d
# 是 v
# 这样 r
# 虽然 c
# 夺得 v
# 名 q
# 棋手 n
# 包圍 v
# 超過 v
# 改稱 v
# 圍 v
# 棋賽 n
# 强战 v
# 必須 d
# formula eng
# 扇 q
# 興杯 n
# 名人 n
# 戰 zg
# 对 p
# 围棋 v
# 通常 d
# 舉辦 v
# 主要 b
# 真 d
# 露 v
# 杯 q
# 得 ud
# 天元 q
# 赞助商 v
# 3 m
# 月 m
# 4 m
# 日 m
# 世 ng
# 乭 zg
# 淘汰 v
# 對弈 vn
# 中 f
# 安排 v
# 2 m
# 轮 n
# 对于 p
# 胜负 v
# 获得 v
# 存在 v
# 举办 v
# 的 uj
# 年間 t
# 年 m
# 年 m
# 元 m
# 和 c
# 辜梓 nr
# 豪 ag
# 淘汰 v
# 賽 x
# 位 q
# 運用 vn
# 围棋 v
# 名人战 n
# 贊助 v
# 世界 n
# 第 m
# 日 m
# 和 c
# 年 m
# 獲 v
# 选拔 v
# 讀賣 v
# 新聞 n
# 職業 n
# 圍棋 v
# 年 m
# 日 m
# 計算 v
# 日 m
# 围棋 v
# 围棋 v
# 大 a
# 对弈 v
# 届 m
# 比 p
# 综合 vn
# 業 x
# 棋士 n
# 为 p
# 围棋 v
# 张馨 nr
# 月 m
# 女子 n
# 围 v
# 程式 n
# 碼 x
# 顾水 nr
# 如 v
# 年 m
# 取 v
# 本赛 n
# 第 m
# 指 n
# 围棋 v
# 對弈 v
# 為 p
# 台灣 ns
# 改名 v
# 為 zg
# 為了 p
# 周睿 nrfg
# 决赛 n
# 中 f
# 為 p
# 圍棋 v
# 抗賽 vn
# 秀 ag
# 和 c
# 限 v
# 公 n
# 發行 v
# 挑戰 vn
# 新 a
# 布局 n
# 报道 v
# 直播 vn
# 獲勝 v
# 和 c
# 韩 nr
# 采取 v
# 中日 t
# 才能 v
# 现代 t
# 之間 f
# 已經 d
# 造成 v
# 当今 t
# 本身 r
# 发生 v
# 整個 b
# 參加 v
# 個 m
# 黑 a
# 首次 m
# 长 a
# 考 v
# 電腦 n
# 圍 v
# 比目 n
# 法 j
# 日本 ns
# 的 uj
# 9 m
# x9 eng
# 类似 v
# 三 m
# 三 m
# 連接 v
# 繼承 v
# 作戰 v
# 许 m
# 嘉阳 ns
# 分為 v
# 國內 s
# 职业 n
# 围棋 v
# 世界 n
# 最 d
# 朴 nr
# 文 ng
# 垚 zg
# 屆 m
# 起 v
# 按照 p
# 少年 m
# 決定 v
# 情況 n
# 下 f
# 處理 v
# 执黑 v
# 擊敗 v
# 變成 v
# 强赛 vn
# 戰鬥 vn
# 任何 r
# 日 m
# 至 p
# 應 v
# 對 p
# 尤其 d
# 整个 b
# 国内 s
# 改名 v
# 發生 v
# 叫 v
# 吃 v
# 全 a
# 日本 ns
# 三子 m
# 重要 a
# 棋 n
# 聖 j
# 戰 n
# 非常 d
# 對 p
# 手 s
# 選手 v
# 以 p
# 後 nr
# 公开 ad
# 圍棋棋 i
# 种子 n
# 选 zg
# 队 n
# 以 p
# 推出 v
# 等级 b
# 變化 vn
# 年 m
# 因 c
# 位置 v
# 江铸 nr
# 久 a
# 联合 v
# 为 p
# 世界 n
# 对局 n
# 费 v
# 围棋 v
# 规则 n
# 执白 v
# 了 ul
# 围棋 v
# 三段 m
# 這種 r
# 番 q
# 棋 n
# 赞助 v
# 影响 vn
# 秀 ag
# 哉 y
# 特定 d
# 年 m
# 舉 v
# 年 m
# 台 q
# 達到 v
# 自己 r
# 的 uj
# 比赛 vn
# 中 f
# 为 p
# 围 v
# 实战 v
# 停辦 v
# 比賽 vn
# 中 f
# 算 v
# 砂 n
# 李 nr
# 喆 zg
# 公開 ad
# 大 a
# 飛 n
# 依照 p
# 初段 t
# 读秒 n
# 的 uj
# 類似 v
# 发展 vn
# 日本 ns
# 围 v
# 年 m
# 改 v
# 年 m
# 共 d
# 象棋 v
# 多数 m
# 成為 v
# 分鐘 q
# 某些 r
# 棋手 n
# 在 p
# 是 v
# 日本 ns
# 重視 v
# 台灣 ns
# 圍棋 v
# 届 m
# 应 v
# 柁 g
# 嘉熹 nr
# 年 m
# 以 f
# 年代 t
# 是 v
# 台灣 ns
# 黑白 z
# 然而 c
# 保留 v
# 是 v
# 圍棋 v
# 此時 c
# 出現 v
# 要求 v
# 围棋 v
# 协会 n
# 或者 c
# 圍棋 v
# 協 n
# 雖然 c
# 睦 ag
# 镇硕 nrt
# 抗赛 vn
# 三番 m
# 棋 n
# 先 d
# 手 n
# 是 v
# 由 p
# 特殊 a
# 首轮 m
# 進入 v
# 後 nr
# 因 p
# 段 q
# 和 c
# 選擇 v
# 木谷 n
# 實 v
# 讓 v
# 子 ng
# 年 m
# 舉辦 v
# 当时 t
# 中 f
# 届 m
# 起 v
# 职业 n
# 围 v
# 唐 nr
# 奕 z
# 研究 vn
# 以下 f
# 始于 d
# 進行 v
# 目前 t
# 攻擊 v
# 李轩 nr
# 豪 ag
# 吳 x
# 清源 n
# 稱作 v
# 年才 t
# 年间 t
# 黄奕中 i
# 棋盤 n
# 上 f
# 申真 nr
# 谞 zg
# 這個 r
# 国际 n
# 围 v
# 首届 m
# 小 a
# 目 t
# 至 p
# 第 m
# 这些 r
# 年 m
# 全 n
# 限 v
# 公司 n
# 陶 nr
# 欣然 d
# 国 n
# 围棋 v
# 周睿羊 l
# 比較 d
# 井山裕 nr
# 太 d
# 名 m
# 為 p
# 年 m
# 获 v
# 年 m
# 至 p
# 年 m
# 和 c
# 元 m
# 晟 g
# 溱 g
# 杨 nr
# 鼎新 d
# 改為 v
# 用 p
# 时 n
# 年 m
# 到 v
# 年 m
# 由 p
# 采用 v
# 認為 v
# 開始 v
# 特別 d
# 规则 n
# 与 p
# 後 nr
# 來 v
# 年 m
# 开 v
# 由 p
# 於 nr
# 年 m
# 中 f
# 下 f
# 法 j
# 其他 r
# 佈 yg
# 局 n
# 對 p
# 方 n
# 稱為 v
# 對 p
# 局 n
# 採用 v
# 以上 f
# 位 q
# 棋手 n
# 年 m
# 開 v
# 這些 r
# 开始 v
# 芈 o
# 昱 g
# 廷 g
# 时 ng
# 越 d
# 同時 c
# 如果 c
# 根据 p
# 中國 ns
# 圍棋 v
# 發展 vn
# 4 m
# 子 nr
# 元 m
# 人 n
# 以及 c
# 當時 t
# 之 u
# 後 nr
# 比賽 vn
# 年 m
# 起 v
# 主辦 b
# 本 r
# 因 c
# 使用 v
# 每方 r
# 本 r
# 因坊 n
# 比赛 vn
# 其中 r
# 年 m
# 第 m
# 圍棋 v
# 围棋 v
