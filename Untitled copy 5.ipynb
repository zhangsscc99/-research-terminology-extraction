# %%
#!/usr/bin/env python3
import re
import sys

word_processed_by_av=[]
def main(all_terms,conll):
    # open unfiltered file list (first argument)
    #围棋.all_terms
    #input_file  = sys.argv[1]
    input_file  = all_terms
    
    # list of files in CoNLL format
    #BIO data: conll
    #conll_filelist = sys.argv[2]
    conll_filelist = conll
    #print(conll_filelist)
    with open(conll_filelist, "r") as filenames:
        conll_files = filenames.readlines()
    
        
    with open(input_file, "r") as f:

    
        unfiltered = f.readlines()
    for term in unfiltered:
        left_context = []
        left_count = 0
        right_context = []
        right_count = 0
        term_word = term.split("\t")
        current_term = []
        for i in range(0, len(term_word) - 1):
            current_term. append(term_word[i])

        for conll_file in conll_files:
            # modify according to where the conll format files are
            conll_file = conll_file.strip("\n")
            with open(conll_file, "r") as f2:
                conll = f2.readlines()
                current_term_vec = current_term[0].split(" ")
                #print(current_term[0])
                for token in range(0, len(conll)):
                    word2_tag_BIO = conll[token].split("\t")
                    # term matched
                    if current_term[0] == word2_tag_BIO[0]:
                        left = conll[token-1].split("\t")[0]
                        # if target word length 1
                                        # AM 9/11/22
                        if (len(current_term_vec) == 1) and (len(conll) > (token+1)):
                            right = conll[token+1].split("\t")[0]
                        else:
                            right = conll[token + len(current_term_vec) -1].split("\t")[0]
                        left = re.sub(r'[，。!\?\-\/\(\)\\]', '', left)
                        right = re.sub(r'[，。!\?\-\/\(\)\\"]', '', right)
                        if left != "" and left not in left_context:
                            left_context.append(left)
                        if right != "" and right not in right_context:
                            right_context.append(right)
            # check context count
            if (len(left_context) >= 3) and (len(right_context) >= 3):
                break # if reach target, no need open another file

        if len(left_context) >= 3 and len(right_context) >= 3:
            #print (term, end = "")
            
            pass
        print (term,len(left_context),len(right_context), end = "\n")
        word_processed_by_av.append([term,len(left_context),len(right_context)])
        #print([term,,end='')
            #pass

# %%
import re
import sys


def main(all_terms,conll):
    # open unfiltered file list (first argument)
    #围棋.all_terms
    #input_file  = sys.argv[1]
    input_file  = all_terms
    
    # list of files in CoNLL format
    #BIO data: conll
    #conll_filelist = sys.argv[2]
    conll_filelist = conll
    #print(conll_filelist)
    with open(conll_filelist, "r") as filenames:
        conll_files = filenames.readlines()
        print(conll_files)
    with open(input_file, "r") as f:

    
        unfiltered = f.readlines()
        print(unfiltered)

# %%
#main("/Users/mac/Desktop/ngram/summary/围棋.all_terms",'/Users/mac/Desktop/ngram/summary/test.txt')

main("/Users/mac/Desktop/ngram/summary/围棋.all_terms",'/Users/mac/Desktop/ngram/summary/tchunk_listfile2.txt')
# Out:
# ['/Users/mac/Desktop/ngram/summary/output_foreground/围棋0.txt.tchunk\n', '/Users/mac/Desktop/ngram/summary/output_foreground/围棋1.txt.tchunk\n', '/Users/mac/Desktop/ngram/summary/output_foreground/围棋10.txt.tchunk\n', '/Users/mac/Desktop/ngram/summary/output_foreground/围棋100.txt.tchunk\n', '/Users/mac/Desktop/ngram/summary/output_foreground/围棋101.txt.tchunk\n', '/Users/mac/Desktop/ngram/summary/output_foreground/围棋102.txt.tchunk\n', '/Users/mac/Desktop/ngram/summary/output_foreground/围棋103.txt.tchunk\n', '/Users/mac/Desktop/ngram/summary/output_foreground/围棋104.txt.tchunk\n', '/Users/mac/Desktop/ngram/summary/output_foreground/围棋105.txt.tchunk\n', '/Users/mac/Desktop/ngram/summary/output_foreground/围棋106.txt.tchunk\n']
# ['\ufeff3月26 日\t51.63362434856469\n', '3月26\t51.22012829507254\n', '☆队 免选\t34.32995320617754\n', '☆队\t34.09478501764429\n', '定段\t33.77389335616284\n', '5月22 日\t32.51026957227198\n', '5月22\t32.133254647051665\n', '定段 名单\t29.99556727460179\n', '江流儿\t29.827760255414745\n', '雷凌云\t28.326954853828536\n', '云子\t28.231464085451435\n', '雙人圍\t25.322550451659833\n', 'br\t23.801686148157614\n', 'master\t22.57771979887051\n', 'deepzengo\t20.473609334217038\n', '队免选\t17.72111115088585\n', '江流\t17.684440134695855\n', '劫材\t17.635460542859118\n', '对局者\t17.23174295954707\n', '本届 擂台\t16.39252286515078\n', '队外\t16.139913662378124\n', '月刊\t16.133246995711456\n', 'pspace\t16.08094453427955\n', '段 次级\t16.02736497281583\n', 'alphazero\t15.10650330423876\n', '唐韋星\t14.678756953271524\n', '本赛 名单\t14.622662884195915\n', '新民\t14.550249202387647\n', '段 正规\t14.25656780836799\n', '敗部\t14.186101252036085\n', '轮对阵\t14.083505858704598\n', '月刊 社联合\t13.422216792670742\n', '雙人圍 棋\t13.372328088757332\n', '請參見\t13.193428098942965\n', '个人第\t12.996957260144804\n', 'katago\t12.975181243407771\n', '小 组冠军\t12.956377478320372\n', '關第\t12.92324471558675\n', '挑战权\t12.861522093459069\n', '胜者组 败者组 胜者组 败者组 胜者组 败者组 胜者组 败者组\t12.541820540836621\n', '胜者组 败者组 胜者组 败者组 胜者组 败者组 胜者组\t12.483026140541142\n', '方圓社\t12.458928161513633\n', '胜者组 败者组 胜者组 败者组 胜者组 败者组\t12.414142924024791\n', '循环圈 战 挑战者 决定循 环圈战 预选赛\t12.37316988054322\n', '胜者组 败者组 胜者组 败者组 胜者组\t12.334755554746497\n', '胜者组 败者组 胜者组 败者组\t12.236783998683126\n', 'alphago\t12.229473753489593\n', '循环圈 战 挑战者 决定循 环圈战\t12.176306030040477\n', '胜者组 败者组 胜者组\t12.114529984308032\n', '届中 国围 棋天 元战\t12.109125300565669\n', '段 持白中 盤 勝\t12.071898844877932\n', '循环圈 战 挑战者 决定循\t12.01450733574261\n', '届中 国围 棋天\t11.982307628053299\n', '段 持白中 盤\t11.976659251689739\n', '胜者组 败者组\t11.944304720021268\n', '段 持白中\t11.85738381958604\n', '循环圈 战 挑战者\t11.801956584599086\n', '棋鬼王\t11.639643745607373\n', '定段赛\t11.60481482418406\n', '循环圈 战\t11.510054270647995\n', '神脑丹\t11.46549913849082\n', 'gnugo\t11.296506776902012\n', '轮于\t11.235262464191884\n', '天元战\t11.020010767046843\n', '預選 賽於\t10.849475206808762\n', '全羅南道\t10.703153413259182\n', '本届 擂台 赛中 国队以\t10.61847399400764\n', 'tw\t10.589559511744033\n', '段 持黑中 盤 勝\t10.535427620322514\n', '韓元\t10.53284364092232\n', '本届\t10.500781220979711\n', '月刊 社联合 主办\t10.490400097667235\n', '循环圈\t10.454596039151141\n', '本届 擂台 赛中\t10.45365159146437\n', '段 持黑中 盤\t10.440188027134319\n', '段 持黑中\t10.320912595030624\n', '預選\t10.318280755502213\n', '名 决赛\t10.23339079547405\n', '新民 晚报\t10.2177010170138\n', '胜者组\t10.157251763169933\n', '齐鲁晚\t10.083823120261227\n', '本身劫\t10.068343599628644\n', '勝部\t9.95531536937735\n', '无锡人\t9.929027913935403\n', '碁聖\t9.480074683417948\n', 'lg\t9.45597267331591\n', 'zh\t9.111319743186714\n', 'kgs\t9.083160937656846\n', '雷蒙\t9.040822090263408\n', '强败者\t8.98733668268088\n', 'deepmind\t8.961162865009241\n', '队外 卡李 昌镐\t8.9295325373887\n', '单淘汰选\t8.91927260052966\n', '轮 对阵\t8.91927260052966\n', '届中 国围\t8.911949469957143\n', '御城棋\t8.842864894524894\n', 'lg 杯冠军\t8.787117304459585\n', '队外 卡李\t8.755312863643422\n', '上届 终结者\t8.699225196567477\n', '強雙敗 淘\t8.68512899059198\n', '杯冠军\t8.576798741934919\n', '多胜者\t8.552674813676349\n', '秀策數\t8.502919211643048\n', '年紀\t8.499776929007295\n', '時代\t8.489580850575923\n', '年道\t8.488110262340628\n', '王元均\t8.464220410061593\n', '強雙敗\t8.464220410061593\n', '方胜\t8.459305388487891\n', '廣島\t8.455967405197772\n', '上届\t8.455967405197772\n', '免选\t8.413110262340629\n', '棋走\t8.413110262340629\n', '发阳论\t8.386822806898682\n', '此為\t8.313110262340627\n', '吴侑珍\t8.292589110134257\n', '挑战者\t7.967202117643071\n', '年全 国围 棋升 段赛由\t7.898963978348732\n', '黑嘉嘉\t7.890481056676411\n', '本届 比赛\t7.795124757018211\n', '淡路修\t7.712158350596804\n', '等级分前30名及 特邀棋 手 聂卫平\t7.666829469848267\n', '最高 棋士 決定戰\t7.633755230105813\n', '等级分前30名及 特邀棋 手\t7.599929208256827\n', '年全 国围 棋升\t7.573920095710436\n', '等级分前30名及 特邀棋\t7.52704862136452\n', '年全 国围棋 段位赛于\t7.497753393595978\n', '天台\t7.491724846862164\n', '聂卫平\t7.47979743277189\n', ' ...
